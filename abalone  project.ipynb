# %% [markdown]
# # ABALONE

# %% [markdown]
# Problem Statement:
# The age of abalone is determined by cutting the shell through the cone, staining it, and counting the number of rings through a microscope -- a boring and time-consuming task. Other measurements, which are easier to obtain, are used to predict the age. Further information, such as weather patterns and location (hence food availability) may be required to solve the problem.

# %% [markdown]
# You have to predict the rings of each abalone which will lead us to the age of that abalone.

# %%
import pandas as pd

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset1/master/abalone.csv')

# %%
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
df.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %%
df.shape
# Out:
# (4177, 9)

# %% [markdown]
# Dataset df have 4177 rows and 9 columns including the target one.

# %%
df.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %% [markdown]
# ABOUT THE COLUMNS
#
# Sex / nominal / -- / M, F, and I (infant)
#
# Length / continuous / mm / Longest shell measurement
#
# Diameter / continuous / mm / perpendicular to length
#
# Height / continuous / mm / with meat in shell
#
# Whole weight / continuous / grams / whole abalone
#
# Shucked weight / continuous / grams / weight of meat
#
# Viscera weight / continuous / grams / gut weight (after bleeding)
#
# Shell weight / continuous / grams / after being dried
#
# Rings / integer / -- / +1.5 gives the age in years.

# %% [markdown]
# # checking duplicate values in the table

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# there are total 0 duplicate values present in the table.

# %% [markdown]
# # Checking for the unique values.

# %%
df['Rings'].nunique()
# Out:
# 28

# %%
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
df.tail()
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12

# %%
df.sample()
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 3429   I    0.28      0.21   0.065         0.111          0.0425
#
#       Viscera weight  Shell weight  Rings
# 3429          0.0285          0.03      6

# %% [markdown]
# # Checking for the Null Values

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
sns.heatmap(df.isnull())
plt.title('null values')
# Out:
# Text(0.5, 1.0, 'null values')

# %% [markdown]
# since we can see in the heatmap we don't have any null values present in the data.

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %% [markdown]
# Since there are no null values present in the data set so, there is no need to do imputation of null values.

# %% [markdown]
# # EDA

# %% [markdown]
# # Visualization Of The Data

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
sns.pairplot(df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.hist(bins=10,figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'Length'}>,
#         <AxesSubplot:title={'center':'Diameter'}>,
#         <AxesSubplot:title={'center':'Height'}>],
#        [<AxesSubplot:title={'center':'Whole weight'}>,
#         <AxesSubplot:title={'center':'Shucked weight'}>,
#         <AxesSubplot:title={'center':'Viscera weight'}>],
#        [<AxesSubplot:title={'center':'Shell weight'}>,
#         <AxesSubplot:title={'center':'Rings'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
sns.scatterplot(x='Length',y='Rings',data=df)
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Rings'>

# %%
sns.scatterplot(x='Diameter',y='Rings',data=df)
# Out:
# <AxesSubplot:xlabel='Diameter', ylabel='Rings'>

# %%
sns.scatterplot(x='Height',y='Rings',data=df)
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Rings'>

# %%
sns.scatterplot(x='Whole weight',y='Rings',data=df)
# Out:
# <AxesSubplot:xlabel='Whole weight', ylabel='Rings'>

# %%
sns.scatterplot(x='Shucked weight',y='Rings',data=df)
# Out:
# <AxesSubplot:xlabel='Shucked weight', ylabel='Rings'>

# %%
sns.scatterplot(x='Viscera weight',y='Rings',data=df)
# Out:
# <AxesSubplot:xlabel='Viscera weight', ylabel='Rings'>

# %%
sns.scatterplot(x='Shell weight',y='Rings',data=df)
# Out:
# <AxesSubplot:xlabel='Shell weight', ylabel='Rings'>

# %%
sns.displot(df['Rings'],kde=True)

# %%
sns.displot(df['Length'],kde=True)

# %%
sns.displot(df['Diameter'],kde=True)

# %%
sns.displot(df['Height'],kde=True)

# %%
sns.displot(df['Whole weight'],kde=True)

# %%
sns.displot(df['Shucked weight'],kde=True)

# %%
sns.displot(df['Shucked weight'],kde=True)

# %%
sns.displot(df['Viscera weight'],kde=True)

# %%
sns.displot(df['Shell weight'],kde=True)

# %% [markdown]
# # Describing Data

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# 25%          0.093500      0.130000     8.000000
# 50%          0.171000      0.234000     9.000000
# 75%          0.253000      0.329000    11.000000
# max          0.760000      1.005000    29.000000

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,10))
sns.heatmap(df.describe(),annot=True,linewidths=4,linecolor='white',fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Checking correlation of columns with the target variable.

# %%
df.corr()
# Out:
#                   Length  Diameter    Height  Whole weight  Shucked weight  \
# Length          1.000000  0.986812  0.827554      0.925261        0.897914
# Diameter        0.986812  1.000000  0.833684      0.925452        0.893162
# Height          0.827554  0.833684  1.000000      0.819221        0.774972
# Whole weight    0.925261  0.925452  0.819221      1.000000        0.969405
# Shucked weight  0.897914  0.893162  0.774972      0.969405        1.000000
# Viscera weight  0.903018  0.899724  0.798319      0.966375        0.931961
# Shell weight    0.897706  0.905330  0.817338      0.955355        0.882617
# Rings           0.556720  0.574660  0.557467      0.540390        0.420884
#
#                 Viscera weight  Shell weight     Rings
# Length                0.903018      0.897706  0.556720
# Diameter              0.899724      0.905330  0.574660
# Height                0.798319      0.817338  0.557467
# Whole weight          0.966375      0.955355  0.540390
# Shucked weight        0.931961      0.882617  0.420884
# Viscera weight        1.000000      0.907656  0.503819
# Shell weight          0.907656      1.000000  0.627574
# Rings                 0.503819      0.627574  1.000000

# %%
df.corr()['Rings'].sort_values(ascending=False)
# Out:
# Rings             1.000000
# Shell weight      0.627574
# Diameter          0.574660
# Height            0.557467
# Length            0.556720
# Whole weight      0.540390
# Viscera weight    0.503819
# Shucked weight    0.420884
# Name: Rings, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(),annot=True,linewidths=4,linecolor='Black',fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the data and it's visual representation we get that

# %% [markdown]
# Shell weight is 0.627574 correlated. It is with the highest correlation.
#
# Diameter has this much correlation 0.574660. It is not highest but it is also good in correlation
#
# Height has this much correlation 0.557467 It is not highest but it is also good in correlation
#
# Length has this much correlation 0.556720.It is mildly correlated .
#
# Whole weight has this much correlation 0.540390. It is also good in correlation
#
# Viscera weight has this much correlation 0.503819. It is second last in correlation compared to all other features.
#
# Shucked weight has this much correlation 0.420884.It is the least correlated column as compared to all other features.

# %% [markdown]
# # checking the columns which are positively and negatively correlated to the target variable.

# %%
plt.figure(figsize=(12,10))
df.corr()['Rings'].sort_values(ascending=False).drop(['Rings']).plot(kind='bar',color='g')
plt.xlabel('features',fontsize=12)
plt.ylabel('column with target names',fontsize=12)
plt.show()

# %% [markdown]
# # Outliers Checking

# %% [markdown]
# Using label encoder to deal with the categorical column before checking for the outliers.

# %%
from sklearn import preprocessing

# %%
le= preprocessing.LabelEncoder()

# %%
df['Sex']= le.fit_transform(df['Sex'])

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
collist=df.columns.values
ncol=30
nrow=14

# %%
collist
# Out:
# array(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight',
#        'Shucked weight', 'Viscera weight', 'Shell weight', 'Rings'],
#       dtype=object)

# %%
for i in range(0,len(collist)):
    print(collist[i])
    break
# Out:
# Sex

# %%
plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(data = df[collist[i]],color='red',orient='v')
    plt.tight_layout()

# %%
from scipy.stats import zscore
import numpy as np

# %%
(np.abs(zscore(df))<3).all().all()
# Out:
# False

# %% [markdown]
# As the result is false so there are outliers present in the data set which will be treated at later stages.

# %% [markdown]
# # Processing the Data

# %% [markdown]
# # Removing Outliers

# %%
from scipy.stats import zscore
import numpy as np

# %%
(np.abs(zscore(df))<3).all().all()
# Out:
# False

# %% [markdown]
# zscore Technique

# %%
z=np.abs(zscore(df))
threshold=3
np.where(z>3)
# Out:
# (array([   6,   72,   81,   83,  129,  163,  164,  165,  165,  165,  166,
#          166,  167,  168,  170,  181,  232,  236,  236,  236,  237,  237,
#          238,  238,  239,  270,  275,  277,  278,  294,  310,  313,  314,
#          334,  351,  355,  358,  358,  362,  375,  416,  417,  428,  431,
#          433,  469,  478,  480,  501,  526,  526,  530,  572,  628,  673,
#          674,  675,  678,  694,  696,  696,  719,  719,  720,  720,  744,
#          754,  756,  811,  891,  891,  891, 1048, 1051, 1051, 1052, 1193,
#         1197, 1199, 1202, 1204, 1206, 1206, 1207, 1207, 1207, 1207, 1209,
#         1209, 1257, 1417, 1417, 1418, 1422, 1426, 1427, 1427, 1427, 1428,
#         1429, 1429, 1528, 1754, 1756, 1757, 1759, 1761, 1762, 1762, 1762,
#         1763, 1763, 1763, 1821, 1982, 1986, 1987, 1987, 2051, 2090, 2108,
#         2108, 2114, 2114, 2157, 2161, 2176, 2180, 2199, 2201, 2208, 2209,
#         2274, 2275, 2305, 2334, 2334, 2334, 2335, 2344, 2358, 2368, 2381,
#         2436, 2459, 2471, 2544, 2623, 2624, 2624, 2624, 2625, 2709, 2710,
#         2710, 2810, 2810, 2811, 2811, 2811, 2862, 2863, 2863, 2863, 3007,
#         3008, 3140, 3148, 3149, 3149, 3151, 3151, 3188, 3193, 3280, 3359,
#         3427, 3427, 3427, 3599, 3599, 3628, 3713, 3715, 3715, 3715, 3715,
#         3800, 3837, 3899, 3899, 3902, 3924, 3930, 3944, 3961, 3962, 3996,
#         4145, 4148], dtype=int64),
#  array([8, 8, 7, 8, 7, 7, 7, 4, 5, 7, 7, 8, 8, 7, 6, 8, 8, 1, 2, 3, 1, 2,
#         1, 2, 1, 8, 8, 7, 8, 8, 8, 8, 8, 7, 8, 8, 4, 7, 8, 8, 8, 8, 8, 8,
#         8, 8, 8, 8, 8, 1, 2, 8, 8, 8, 8, 8, 8, 8, 2, 1, 2, 1, 2, 1, 2, 8,
#         8, 8, 8, 4, 5, 7, 6, 4, 5, 4, 5, 5, 5, 5, 6, 5, 6, 4, 5, 6, 7, 4,
#         5, 3, 3, 5, 5, 6, 5, 4, 5, 6, 7, 1, 2, 5, 5, 5, 6, 6, 5, 4, 5, 6,
#         4, 5, 6, 5, 5, 1, 1, 2, 3, 7, 7, 8, 1, 2, 7, 7, 8, 8, 8, 8, 7, 8,
#         7, 8, 8, 4, 6, 8, 8, 8, 8, 7, 1, 8, 8, 8, 5, 4, 4, 5, 6, 5, 6, 5,
#         6, 5, 6, 4, 5, 6, 5, 4, 5, 6, 5, 7, 8, 7, 7, 8, 7, 8, 7, 8, 8, 8,
#         4, 5, 6, 4, 5, 6, 5, 4, 5, 6, 7, 4, 2, 1, 2, 1, 8, 8, 8, 5, 5, 3,
#         7, 6], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df_new
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4027 rows x 9 columns]

# %%
df_new.shape
# Out:
# (4027, 9)

# %%
data_loss=((4177-4027)/4177)*100

# %%
data_loss
# Out:
# 3.5910940866650707

# %% [markdown]
# This is the percentage of data lost

# %% [markdown]
# OUTLIERS HAS BEEN REMOVED FROM THE DATA.

# %% [markdown]
# # seperating features and the target variable

# %%
features=df_new.drop('Rings',axis=1)
target=df_new['Rings']

# %%
features.value_counts()
# Out:
# Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  Shell weight
# 0    0.275   0.195     0.070   0.0800        0.0310          0.0215          0.0250          1
# 2    0.400   0.290     0.115   0.2795        0.1115          0.0575          0.0750          1
#      0.385   0.275     0.115   0.2685        0.0975          0.0825          0.0850          1
#              0.285     0.105   0.2905        0.1215          0.0685          0.0875          1
#              0.295     0.095   0.3350        0.1470          0.0940          0.0900          1
#                                                                                             ..
# 1    0.270   0.190     0.080   0.0810        0.0265          0.0195          0.0300          1
#              0.195     0.060   0.0730        0.0285          0.0235          0.0300          1
#                        0.065   0.1065        0.0475          0.0225          0.0285          1
#                        0.070   0.1020        0.0450          0.0135          0.0340          1
# 2    0.760   0.605     0.215   2.1730        0.8010          0.4915          0.6460          1
# Length: 4027, dtype: int64

# %%
target.value_counts()
# Out:
# 9     686
# 10    625
# 8     566
# 11    472
# 7     391
# 6     258
# 12    251
# 13    199
# 14    119
# 5     113
# 15    102
# 16     62
# 17     53
# 4      49
# 18     39
# 19     32
# 3      10
# Name: Rings, dtype: int64

# %% [markdown]
# # checking skewness in Data and Removing it

# %%
features.skew()
# Out:
# Sex              -0.094886
# Length           -0.623076
# Diameter         -0.598650
# Height           -0.244251
# Whole weight      0.334204
# Shucked weight    0.458295
# Viscera weight    0.437116
# Shell weight      0.349471
# dtype: float64

# %% [markdown]
# keeping -/+0.5 as the range of skewness. Here are the columns that are not in range.

# %% [markdown]
# sex , length

# %%
features.plot(kind='density',subplots=True,layout=(6,11),sharex=False,legend=False,fontsize=1,figsize=(15,13))
plt.show()

# %% [markdown]
# These diagrams shows that there is skewness present in the data in multiple columns.

# %%
from sklearn.preprocessing import power_transform

# %%
features.skew().sort_values(ascending=False)
# Out:
# Shucked weight    0.458295
# Viscera weight    0.437116
# Shell weight      0.349471
# Whole weight      0.334204
# Sex              -0.094886
# Height           -0.244251
# Diameter         -0.598650
# Length           -0.623076
# dtype: float64

# %%
features_n=power_transform(features,method='yeo-johnson')

# %%
pd.DataFrame(features_n,columns=features.columns).skew().sort_values(ascending=False)
# Out:
# Viscera weight    0.035902
# Shucked weight    0.021815
# Shell weight      0.016660
# Height           -0.015962
# Whole weight     -0.016797
# Diameter         -0.080956
# Length           -0.082985
# Sex              -0.174523
# dtype: float64

# %% [markdown]
# range is +0.1 to -0.1

# %%
type(features_n)
# Out:
# numpy.ndarray

# %%
features.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight'],
#       dtype='object')

# %%
features=pd.DataFrame(features_n,columns=features.columns)

# %%
features.skew().sort_values(ascending=False)
# Out:
# Viscera weight    0.035902
# Shucked weight    0.021815
# Shell weight      0.016660
# Height           -0.015962
# Whole weight     -0.016797
# Diameter         -0.080956
# Length           -0.082985
# Sex              -0.174523
# dtype: float64

# %% [markdown]
# SKEWNESS HAS BEEN REMOVED FROM THE DATA

# %% [markdown]
# # Training Process Begins

# %% [markdown]
# # scaling the data using min max scaler

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
for i in range(0,100):
    features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=i)
    lr.fit(features_train,target_train)
    pre_train=lr.predict(features_train)
    pre_test=lr.predict(features_test)
    print(f"at random state {i},the train accuracy is:- {r2_score(target_train,pre_train)}")
    print(f"at random state {i},the testing accuracy is:- {r2_score(target_test,pre_test)}")
    print('\n')
# Out:
# at random state 0,the train accuracy is:- 0.5195108833501347
# at random state 0,the testing accuracy is:- 0.48183605896319703
#
#
# at random state 1,the train accuracy is:- 0.5179027944575052
# at random state 1,the testing accuracy is:- 0.4865592651102042
#
#
# at random state 2,the train accuracy is:- 0.5140224849697634
# at random state 2,the testing accuracy is:- 0.5057483545747372
#
#
# at random state 3,the train accuracy is:- 0.5136923265043163
# at random state 3,the testing accuracy is:- 0.5063758216840379
#
#
# at random state 4,the train accuracy is:- 0.5111441814205953
# at random state 4,the testing accuracy is:- 0.5168489528080418
#
#
# at random state 5,the train accuracy is:- 0.5174560761050806
# at random state 5,the testing accuracy is:- 0.4915279175423848
#
#
# at random state 6,the train accuracy is:- 0.5104557722242221
# at random state 6,the testing accuracy is:- 0.5187831895305177
#
#
# at random state 7,the train accuracy is:- 0.5212460609189256
# at random state 7,the testing accuracy is:- 0.4756770429059344
#
#
# at random state 8,the train accuracy is:- 0.5103823611539045
# at random state 8,the testing accuracy is:- 0.5202203872500786
#
#
# at random state 9,the train accuracy is:- 0.5084950034156792
# at random state 9,the testing accuracy is:- 0.5273296689949054
#
#
# at random state 10,the train accuracy is:- 0.506878920994865
# at random state 10,the testing accuracy is:- 0.5319185649742416
#
#
# at random state 11,the train accuracy is:- 0.5053244063958048
# at random state 11,the testing accuracy is:- 0.5420037302955801
#
#
# at random state 12,the train accuracy is:- 0.5055584460781682
# at random state 12,the testing accuracy is:- 0.5389086306907754
#
#
# at random state 13,the train accuracy is:- 0.5102994465576827
# at random state 13,the testing accuracy is:- 0.5197009041481749
#
#
# at random state 14,the train accuracy is:- 0.5126612512425093
# at random state 14,the testing accuracy is:- 0.5093269441505074
#
#
# at random state 15,the train accuracy is:- 0.5102232818353871
# at random state 15,the testing accuracy is:- 0.5210516439923976
#
#
# at random state 16,the train accuracy is:- 0.5058262614869643
# at random state 16,the testing accuracy is:- 0.5365503953232793
#
#
# at random state 17,the train accuracy is:- 0.518132328767665
# at random state 17,the testing accuracy is:- 0.4903245422517023
#
#
# at random state 18,the train accuracy is:- 0.5051059877806249
# at random state 18,the testing accuracy is:- 0.5419720609427661
#
#
# at random state 19,the train accuracy is:- 0.5253127192958644
# at random state 19,the testing accuracy is:- 0.46427118883915697
#
#
# at random state 20,the train accuracy is:- 0.5084211153480764
# at random state 20,the testing accuracy is:- 0.5264221930345327
#
#
# at random state 21,the train accuracy is:- 0.5122148224231932
# at random state 21,the testing accuracy is:- 0.512442015106513
#
#
# at random state 22,the train accuracy is:- 0.5070331438802302
# at random state 22,the testing accuracy is:- 0.5296286125632116
#
#
# at random state 23,the train accuracy is:- 0.5097946672302718
# at random state 23,the testing accuracy is:- 0.5217417277431253
#
#
# at random state 24,the train accuracy is:- 0.513030962042847
# at random state 24,the testing accuracy is:- 0.5090826922255619
#
#
# at random state 25,the train accuracy is:- 0.5176030233876812
# at random state 25,the testing accuracy is:- 0.4941279623027469
#
#
# at random state 26,the train accuracy is:- 0.5156485021551658
# at random state 26,the testing accuracy is:- 0.49867131557622923
#
#
# at random state 27,the train accuracy is:- 0.5150039798861461
# at random state 27,the testing accuracy is:- 0.49907934065300186
#
#
# at random state 28,the train accuracy is:- 0.5083970901815579
# at random state 28,the testing accuracy is:- 0.5272519184468014
#
#
# at random state 29,the train accuracy is:- 0.5073124581730892
# at random state 29,the testing accuracy is:- 0.5323082962907639
#
#
# at random state 30,the train accuracy is:- 0.5122369746986075
# at random state 30,the testing accuracy is:- 0.5110851469041299
#
#
# at random state 31,the train accuracy is:- 0.5147915630465413
# at random state 31,the testing accuracy is:- 0.5007196289455919
#
#
# at random state 32,the train accuracy is:- 0.5107289316499983
# at random state 32,the testing accuracy is:- 0.5160098307928813
#
#
# at random state 33,the train accuracy is:- 0.5182341221826342
# at random state 33,the testing accuracy is:- 0.48947257008143474
#
#
# at random state 34,the train accuracy is:- 0.5121454294332999
# at random state 34,the testing accuracy is:- 0.5133635834340498
#
#
# at random state 35,the train accuracy is:- 0.5094882742934566
# at random state 35,the testing accuracy is:- 0.5195638798492265
#
#
# at random state 36,the train accuracy is:- 0.5165420567368473
# at random state 36,the testing accuracy is:- 0.495418662739901
#
#
# at random state 37,the train accuracy is:- 0.5118295917273787
# at random state 37,the testing accuracy is:- 0.5147134695407045
#
#
# at random state 38,the train accuracy is:- 0.5087326751629504
# at random state 38,the testing accuracy is:- 0.5264635764587295
#
#
# at random state 39,the train accuracy is:- 0.5159710836751423
# at random state 39,the testing accuracy is:- 0.49602862916348756
#
#
# at random state 40,the train accuracy is:- 0.5058098638098633
# at random state 40,the testing accuracy is:- 0.5381502464622707
#
#
# at random state 41,the train accuracy is:- 0.5078179204773792
# at random state 41,the testing accuracy is:- 0.5294336792143082
#
#
# at random state 42,the train accuracy is:- 0.5112265412158388
# at random state 42,the testing accuracy is:- 0.5135704003631603
#
#
# at random state 43,the train accuracy is:- 0.5149637541435583
# at random state 43,the testing accuracy is:- 0.5018168897107169
#
#
# at random state 44,the train accuracy is:- 0.5131534064210241
# at random state 44,the testing accuracy is:- 0.5061806171906573
#
#
# at random state 45,the train accuracy is:- 0.5002586874503447
# at random state 45,the testing accuracy is:- 0.5571505087791118
#
#
# at random state 46,the train accuracy is:- 0.5111053457341688
# at random state 46,the testing accuracy is:- 0.5160996797484838
#
#
# at random state 47,the train accuracy is:- 0.5107763452913033
# at random state 47,the testing accuracy is:- 0.5179338700920693
#
#
# at random state 48,the train accuracy is:- 0.5175084446921486
# at random state 48,the testing accuracy is:- 0.48978777422097974
#
#
# at random state 49,the train accuracy is:- 0.5091714306467418
# at random state 49,the testing accuracy is:- 0.5249061533057651
#
#
# at random state 50,the train accuracy is:- 0.5097531085572784
# at random state 50,the testing accuracy is:- 0.5229049928204053
#
#
# at random state 51,the train accuracy is:- 0.5040720257356943
# at random state 51,the testing accuracy is:- 0.5383036847094489
#
#
# at random state 52,the train accuracy is:- 0.5136581315496012
# at random state 52,the testing accuracy is:- 0.5031483612778729
#
#
# at random state 53,the train accuracy is:- 0.531563140992801
# at random state 53,the testing accuracy is:- 0.41272472584463493
#
#
# at random state 54,the train accuracy is:- 0.5216600154573761
# at random state 54,the testing accuracy is:- 0.47564564218298266
#
#
# at random state 55,the train accuracy is:- 0.5073167466295074
# at random state 55,the testing accuracy is:- 0.5323943852354796
#
#
# at random state 56,the train accuracy is:- 0.5178903893835888
# at random state 56,the testing accuracy is:- 0.4878864803289539
#
#
# at random state 57,the train accuracy is:- 0.5086275054822096
# at random state 57,the testing accuracy is:- 0.5265785728886041
#
#
# at random state 58,the train accuracy is:- 0.5031357291513749
# at random state 58,the testing accuracy is:- 0.5465175223311249
#
#
# at random state 59,the train accuracy is:- 0.5110014722918443
# at random state 59,the testing accuracy is:- 0.5152570876802729
#
#
# at random state 60,the train accuracy is:- 0.505257833605754
# at random state 60,the testing accuracy is:- 0.5409468945807436
#
#
# at random state 61,the train accuracy is:- 0.5190125072804392
# at random state 61,the testing accuracy is:- 0.48741901264627085
#
#
# at random state 62,the train accuracy is:- 0.4998368817665042
# at random state 62,the testing accuracy is:- 0.563441326282595
#
#
# at random state 63,the train accuracy is:- 0.5206480655089887
# at random state 63,the testing accuracy is:- 0.4768627248183015
#
#
# at random state 64,the train accuracy is:- 0.5115095305105359
# at random state 64,the testing accuracy is:- 0.5161320387007229
#
#
# at random state 65,the train accuracy is:- 0.5075481256764058
# at random state 65,the testing accuracy is:- 0.5281853274460698
#
#
# at random state 66,the train accuracy is:- 0.5080153302768148
# at random state 66,the testing accuracy is:- 0.5294227150084426
#
#
# at random state 67,the train accuracy is:- 0.5148774800626887
# at random state 67,the testing accuracy is:- 0.5029719518740696
#
#
# at random state 68,the train accuracy is:- 0.5148037945789532
# at random state 68,the testing accuracy is:- 0.5003671628924453
#
#
# at random state 69,the train accuracy is:- 0.512381336826373
# at random state 69,the testing accuracy is:- 0.5111507625396106
#
#
# at random state 70,the train accuracy is:- 0.5125171625861016
# at random state 70,the testing accuracy is:- 0.5109244359916787
#
#
# at random state 71,the train accuracy is:- 0.5065634620372803
# at random state 71,the testing accuracy is:- 0.5363121745317891
#
#
# at random state 72,the train accuracy is:- 0.5039655531269365
# at random state 72,the testing accuracy is:- 0.5403507770231037
#
#
# at random state 73,the train accuracy is:- 0.5084339830483829
# at random state 73,the testing accuracy is:- 0.5240689211353633
#
#
# at random state 74,the train accuracy is:- 0.5123533769829041
# at random state 74,the testing accuracy is:- 0.5108714927315448
#
#
# at random state 75,the train accuracy is:- 0.5179671399609672
# at random state 75,the testing accuracy is:- 0.4905572799757647
#
#
# at random state 76,the train accuracy is:- 0.5110821055746864
# at random state 76,the testing accuracy is:- 0.5181510189905372
#
#
# at random state 77,the train accuracy is:- 0.5125359509771754
# at random state 77,the testing accuracy is:- 0.511844641224052
#
#
# at random state 78,the train accuracy is:- 0.5105197657646737
# at random state 78,the testing accuracy is:- 0.5201890812449452
#
#
# at random state 79,the train accuracy is:- 0.5055525159130823
# at random state 79,the testing accuracy is:- 0.5388810006406861
#
#
# at random state 80,the train accuracy is:- 0.509089290965548
# at random state 80,the testing accuracy is:- 0.5246312802640841
#
#
# at random state 81,the train accuracy is:- 0.5093629317577268
# at random state 81,the testing accuracy is:- 0.5239130649140836
#
#
# at random state 82,the train accuracy is:- 0.4991441975878257
# at random state 82,the testing accuracy is:- 0.5587279577675535
#
#
# at random state 83,the train accuracy is:- 0.5166224183458623
# at random state 83,the testing accuracy is:- 0.4962773733122249
#
#
# at random state 84,the train accuracy is:- 0.5165017525121836
# at random state 84,the testing accuracy is:- 0.4955001309350918
#
#
# at random state 85,the train accuracy is:- 0.5157531602588812
# at random state 85,the testing accuracy is:- 0.49735322519571834
#
#
# at random state 86,the train accuracy is:- 0.5083139836086918
# at random state 86,the testing accuracy is:- 0.5304330177716827
#
#
# at random state 87,the train accuracy is:- 0.514118157881898
# at random state 87,the testing accuracy is:- 0.5052005911534101
#
#
# at random state 88,the train accuracy is:- 0.512451457907419
# at random state 88,the testing accuracy is:- 0.511415503576623
#
#
# at random state 89,the train accuracy is:- 0.5095997626711747
# at random state 89,the testing accuracy is:- 0.5240509307483705
#
#
# at random state 90,the train accuracy is:- 0.5057350964240304
# at random state 90,the testing accuracy is:- 0.5384205103870413
#
#
# at random state 91,the train accuracy is:- 0.51745883881124
# at random state 91,the testing accuracy is:- 0.48794335875381833
#
#
# at random state 92,the train accuracy is:- 0.5028099876758108
# at random state 92,the testing accuracy is:- 0.542792412023576
#
#
# at random state 93,the train accuracy is:- 0.5217235616085987
# at random state 93,the testing accuracy is:- 0.4751622198598805
#
#
# at random state 94,the train accuracy is:- 0.5120697925339455
# at random state 94,the testing accuracy is:- 0.5108501248575785
#
#
# at random state 95,the train accuracy is:- 0.5081387436284132
# at random state 95,the testing accuracy is:- 0.527052458089634
#
#
# at random state 96,the train accuracy is:- 0.5179744237966135
# at random state 96,the testing accuracy is:- 0.48989445493223205
#
#
# at random state 97,the train accuracy is:- 0.5066257669258425
# at random state 97,the testing accuracy is:- 0.5347493944568126
#
#
# at random state 98,the train accuracy is:- 0.5083110825055406
# at random state 98,the testing accuracy is:- 0.5249595880743555
#
#
# at random state 99,the train accuracy is:- 0.5115767427100432
# at random state 99,the testing accuracy is:- 0.5144935814996288

# %%
features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=82)

# %%
lr.fit(features_train,target_train)
# Out:
# LinearRegression()

# %%
test accuracy
# Out:
#   Input In [197]
#     test accuracy
#          ^
# SyntaxError: invalid syntax

# %%
pre_test=lr.predict(features_test)

# %%
 print(r2_score(target_test,pre_test))
# Out:
# 0.5587279577675535

# %% [markdown]
#  train accuracy

# %%
 pre_train=lr.predict(features_train)

# %%
print(r2_score(target_train,pre_train))
# Out:
# 0.4991441975878257

# %%
train_accuracy=r2_score(target_train,pre_train)
testing_accuracy=r2_score(target_test,pre_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,features,target,cv=j)
    cv_mean=cv_score.mean()
    print(f"at cross fold {j} the cv score is {cv_mean} and accuracy score for training is {train_accuracy} and accuracy score for testing is {testing_accuracy}")
    print('\n')
# Out:
# at cross fold 2 the cv score is 0.508684291378207 and accuracy score for training is 0.4991441975878257 and accuracy score for testing is 0.5587279577675535
#
#
# at cross fold 3 the cv score is 0.49735943601139093 and accuracy score for training is 0.4991441975878257 and accuracy score for testing is 0.5587279577675535
#
#
# at cross fold 4 the cv score is 0.4323472464254726 and accuracy score for training is 0.4991441975878257 and accuracy score for testing is 0.5587279577675535
#
#
# at cross fold 5 the cv score is 0.4231197726508821 and accuracy score for training is 0.4991441975878257 and accuracy score for testing is 0.5587279577675535
#
#
# at cross fold 6 the cv score is 0.4332174773880347 and accuracy score for training is 0.4991441975878257 and accuracy score for testing is 0.5587279577675535
#
#
# at cross fold 7 the cv score is 0.44431719188543406 and accuracy score for training is 0.4991441975878257 and accuracy score for testing is 0.5587279577675535
#
#
# at cross fold 8 the cv score is 0.40945364369007 and accuracy score for training is 0.4991441975878257 and accuracy score for testing is 0.5587279577675535
#
#
# at cross fold 9 the cv score is 0.4305676293699574 and accuracy score for training is 0.4991441975878257 and accuracy score for testing is 0.5587279577675535

# %% [markdown]
# since the number of fold don't have such impact on accuracy and cv score so cv=2 is selected.

# %% [markdown]
# we have to handle the problem of overfitting and underfitting by checking training and testing score.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,4))
plt.scatter(x=target_test, y=pre_test, color='r')
plt.plot(target_test,target_test,color='b')
plt.xlabel('actual charges',fontsize=12)
plt.ylabel('predict charges',fontsize=12)
plt.title('linear regression',fontsize=18)
plt.savefig('lr.png')
plt.show()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import Lasso
parameters ={'alpha':[.0001,.001,.01,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf = GridSearchCV(ls,parameters)
clf.fit(features_train,target_train)
print(clf.best_params_)
# Out:
# {'alpha': 0.001, 'random_state': 0}

# %% [markdown]
# # final model training

# %%
ls=Lasso(alpha=1,random_state=0)
ls.fit(features_train,target_train)
ls_score_training=ls.score(features_train,target_train)
pred_ls=ls.predict(features_test)
ls_score_training*100
# Out:
# 27.41284753734954

# %%
pred_ls=ls.predict(features_test)

# %%
lss=r2_score(target_test,pred_ls)
lss*100
# Out:
# 28.35567162749555

# %%
cv_score=cross_val_score(ls,features,target,cv=2)
cv_mean=cv_score.mean()
cv_mean*100
# Out:
# 28.09087465336495

# %% [markdown]
# # ensemble technique

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
parameters={'criterion':['mse','mae'],'max_features':['auto','sqrt','log2']}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(features_train,target_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'sqrt'}

# %%
rf=RandomForestRegressor(criterion='mae',max_features='auto')
rf.fit(features_train,target_train)
rf.score(features_train,target_train)
prediction_decision=rf.predict(features_test)

rfs=r2_score(target_test,prediction_decision)
print('r2_score is',rfs*100)

rfscore=cross_val_score(rf,features,target,cv=6)
rfc=rfscore.mean()
print('cross val score',rfc*100)
# Out:
# r2_score is 59.01825036038313
# cross val score 46.04817411605495

# %%
import pickle
filename='abalone.pkl'
pickle.dump(rf,open(filename,'wb'))

# %%
l_model=pickle.load(open('abalone.pkl','rb'))
result=l_model.score(features_test,target_test)
print(result*100)
# Out:
# 59.01825036038313
