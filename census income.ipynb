# %% [markdown]
# # Census Income Project

# %%
#importing essential libraries that would be required.
import pandas as pd 
import numpy as np

# %%
#reading the csv file and creating dataset in df variable.
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset1/master/census_income.csv')

# %%
#this could helps to get the information about the data set in the variable named df.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
#this code tells the data type of the columns present in dataset.
df.dtypes
# Out:
# Age                int64
# Workclass         object
# Fnlwgt             int64
# Education         object
# Education_num      int64
# Marital_status    object
# Occupation        object
# Relationship      object
# Race              object
# Sex               object
# Capital_gain       int64
# Capital_loss       int64
# Hours_per_week     int64
# Native_country    object
# Income            object
# dtype: object

# %%
#this code tells the no of rows and columns present in the dataset.
df.shape
# Out:
# (32560, 15)

# %%
#this gives the column name from the dataset
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %%
df
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
df.head()
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 0             0             0              13   United-States   <=50K
# ...

# %%
df.tail()
# Out:
#        Age      Workclass  Fnlwgt    Education  Education_num  \
# 32555   27        Private  257302   Assoc-acdm             12
# 32556   40        Private  154374      HS-grad              9
# 32557   58        Private  151910      HS-grad              9
# 32558   22        Private  201490      HS-grad              9
# 32559   52   Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation Relationship    Race      Sex  \
# 32555   Married-civ-spouse        Tech-support         Wife   White   Female
# 32556   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 32557              Widowed        Adm-clerical    Unmarried   White   Female
# 32558        Never-married        Adm-clerical    Own-child   White     Male
# 32559   Married-civ-spouse     Exec-managerial         Wife   White   Female
#
#        Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# ...

# %%
df.sample()
# Out:
#        Age Workclass  Fnlwgt   Education  Education_num  Marital_status  \
# 13349   32   Private  187901   Assoc-voc             11   Never-married
#
#              Occupation    Relationship    Race      Sex  Capital_gain  \
# 13349   Exec-managerial   Not-in-family   White   Female             0
#
#        Capital_loss  Hours_per_week  Native_country  Income
# 13349             0              23   United-States   <=50K

# %% [markdown]
# # CHECKING FOR THE DUPLICATED VALUES IN THE TABLE OR DATASET

# %%
df.duplicated().sum()
# Out:
# 24

# %% [markdown]
# there are 24 duplicated values in the dataset

# %% [markdown]
# # CHECKING FOR THE UNIQUE VALUES IN THE TABLE OR DATASET

# %%
df['Age'].nunique()
# Out:
# 73

# %%
df['Workclass'].nunique()
# Out:
# 9

# %%
df['Fnlwgt'].nunique()
# Out:
# 21647

# %%
df['Education'].nunique()
# Out:
# 16

# %%
df['Education_num'].nunique()
# Out:
# 16

# %%
df['Marital_status'].nunique()
# Out:
# 7

# %%
df['Occupation'].nunique()
# Out:
# 15

# %%
df['Relationship'].nunique()
# Out:
# 6

# %%
df['Race'].nunique()
# Out:
# 5

# %%
df['Sex'].nunique()
# Out:
# 2

# %%
df['Capital_gain'].nunique()
# Out:
# 119

# %%
df['Capital_loss'].nunique()
# Out:
# 92

# %%
df['Hours_per_week'].nunique()
# Out:
# 94

# %%
df['Native_country'].nunique()
# Out:
# 42

# %%
df['Income'].nunique()
# Out:
# 2

# %% [markdown]
# # Checking for the Null Values

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
sns.heatmap(df.isnull())
plt.title('Null Values')
# Out:
# Text(0.5, 1.0, 'Null Values')

# %% [markdown]
# since we can see in the heatmap we do not have any null values present in the data so there is no need of imputation.

# %%
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %% [markdown]
# there are no null values present in the dataset so there is no need of imputation

# %% [markdown]
# # EDA

# %% [markdown]
# # Visualization Of The Data

# %% [markdown]
# important libraries required for the visualization of the data has already been imported earlier

# %% [markdown]
# # 1.Pairplot

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# # 2. Histogram

# %%
df.hist(bins=10,figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Fnlwgt'}>],
#        [<AxesSubplot:title={'center':'Education_num'}>,
#         <AxesSubplot:title={'center':'Capital_gain'}>],
#        [<AxesSubplot:title={'center':'Capital_loss'}>,
#         <AxesSubplot:title={'center':'Hours_per_week'}>]], dtype=object)

# %% [markdown]
# # 3. Countplot

# %%
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %%
sns.countplot(x='Workclass',data=df)
# Out:
# <AxesSubplot:xlabel='Workclass', ylabel='count'>

# %% [markdown]
# this graph tells that most of them are in working state
#
# then in self employed
#
# then local govt
#
# then unknown
#
# then state govt.
#
# then self employed without work
#
# then fedral govt

# %%
sns.countplot(x='Education',data=df)
# Out:
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %%
sns.countplot(x='Marital_status',data=df)
# Out:
# <AxesSubplot:xlabel='Marital_status', ylabel='count'>

# %% [markdown]
# this graph tells the marital status
#
# most of them around 14500 are married civ spouse
#
# then around 11000 are nonmarried
#
# then around 4100 are divoreced
#
# then around 1600 are widowed

# %%
sns.countplot(x='Occupation',data=df)
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='count'>

# %% [markdown]
# this tells the occupation of the individual

# %%
sns.countplot(x='Relationship',data=df)
# Out:
# <AxesSubplot:xlabel='Relationship', ylabel='count'>

# %% [markdown]
# this tells the realtionship status of the individual
#
# most of them are husband around 13000
#
# then not in family 8000
#
# then around 5000 are own child
#
# then 3800 are unmarried
#
# then 1000 are unmarried
#
# then around 800 are other relative

# %%
sns.countplot(x='Race',data=df)
# Out:
# <AxesSubplot:xlabel='Race', ylabel='count'>

# %% [markdown]
# this graph tells the race of the individual that bare in census
#
# most of them are white 23000 around
#
# then black 3000 around
#
# then asian pac island 3000 around
#
# then indian eskimothen 1500 around
#
# then other 800 around

# %%
sns.countplot(x='Sex',data=df)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %% [markdown]
# this graph tells the sex of the individual
#
# most of them are malenmore than 20000
#
# and around 10000 are female

# %%
sns.countplot(x='Native_country',data=df)
# Out:
# <AxesSubplot:xlabel='Native_country', ylabel='count'>

# %%
sns.countplot(x='Income',data=df)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='count'>

# %% [markdown]
# THIS GRAPH TELLS THAT MORE THAN INDIVIDUAL HAVE INCOME<=50K AND LESS OF THEM HAVE >50K

# %% [markdown]
# # VIOLINPLOT

# %%
sns.violinplot(x='Age',data=df)
# Out:
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# AGE IS IN THE RANGE OF 20 TO 40

# %%
sns.violinplot(x='Fnlwgt',data=df)
# Out:
# <AxesSubplot:xlabel='Fnlwgt'>

# %% [markdown]
# THIS IS IN THE RANGE OF 0.2

# %%
sns.violinplot(x='Education_num',data=df)
# Out:
# <AxesSubplot:xlabel='Education_num'>

# %%
sns.violinplot(x='Capital_gain',data=df)
# Out:
# <AxesSubplot:xlabel='Capital_gain'>

# %%
sns.violinplot(x='Capital_loss',data=df)
# Out:
# <AxesSubplot:xlabel='Capital_loss'>

# %%
sns.violinplot(x='Hours_per_week',data=df)
# Out:
# <AxesSubplot:xlabel='Hours_per_week'>

# %% [markdown]
# HOURSN OF WEEK IS IN THE RANGE OF 40

# %% [markdown]
# # DISPLOT

# %%
sns.displot(x='Age',data=df)

# %%
sns.displot(x='Workclass',data=df)

# %%
sns.displot(x='Fnlwgt',data=df)

# %%
sns.displot(x='Education',data=df)

# %%
sns.displot(x='Education_num',data=df)

# %%
sns.displot(x='Marital_status',data=df)

# %%
sns.displot(x='Occupation',data=df)

# %%
sns.displot(x='Relationship',data=df)

# %%
sns.displot(x='Race',data=df)

# %%
sns.displot(x='Sex',data=df)

# %%
sns.displot(x='Capital_gain',data=df)

# %%
sns.displot(x='Capital_loss',data=df)

# %%
sns.displot(x='Hours_per_week',data=df)

# %%
sns.displot(x='Native_country',data=df)

# %%
sns.displot(x='Income',data=df)

# %% [markdown]
# # Describing Data

# %%
df.describe()
# Out:
#                 Age        Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# count  32560.000000  3.256000e+04   32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05      10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05       2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours_per_week
# count    32560.000000
# mean        40.437469
# std         12.347618
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.describe(include='all')
# Out:
#                  Age Workclass        Fnlwgt Education  Education_num  \
# count   32560.000000     32560  3.256000e+04     32560   32560.000000
# unique           NaN         9           NaN        16            NaN
# top              NaN   Private           NaN   HS-grad            NaN
# freq             NaN     22696           NaN     10501            NaN
# mean       38.581634       NaN  1.897818e+05       NaN      10.080590
# std        13.640642       NaN  1.055498e+05       NaN       2.572709
# min        17.000000       NaN  1.228500e+04       NaN       1.000000
# 25%        28.000000       NaN  1.178315e+05       NaN       9.000000
# 50%        37.000000       NaN  1.783630e+05       NaN      10.000000
# 75%        48.000000       NaN  2.370545e+05       NaN      12.000000
# max        90.000000       NaN  1.484705e+06       NaN      16.000000
#
#              Marital_status       Occupation Relationship    Race    Sex  \
# ...

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df.describe(),annot=True,linewidths=4,linecolor='white',fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Checking correlation

# %%
df.corr()
# Out:
#                      Age    Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# Age             1.000000 -0.076646       0.036527      0.077674      0.057775
# Fnlwgt         -0.076646  1.000000      -0.043159      0.000437     -0.010259
# Education_num   0.036527 -0.043159       1.000000      0.122627      0.079932
# Capital_gain    0.077674  0.000437       0.122627      1.000000     -0.031614
# Capital_loss    0.057775 -0.010259       0.079932     -0.031614      1.000000
# Hours_per_week  0.068756 -0.018770       0.148127      0.078409      0.054256
#
#                 Hours_per_week
# Age                   0.068756
# Fnlwgt               -0.018770
# Education_num         0.148127
# Capital_gain          0.078409
# Capital_loss          0.054256
# Hours_per_week        1.000000

# %% [markdown]
# # Checking correlation of columns with the target variable.

# %%
from sklearn import preprocessing

# %%
le= preprocessing.LabelEncoder()

# %%
df['Income']=le.fit_transform(df['Income'])

# %%
df['Workclass']=le.fit_transform(df['Workclass'])

# %%
df['Education']=le.fit_transform(df['Education'])

# %%
df['Marital_status']=le.fit_transform(df['Marital_status'])

# %%
df['Occupation']=le.fit_transform(df['Occupation'])

# %%
df['Relationship']=le.fit_transform(df['Relationship'])

# %%
df['Race']=le.fit_transform(df['Race'])

# %%
df['Sex']=le.fit_transform(df['Sex'])

# %%
df['Native_country']=le.fit_transform(df['Native_country'])

# %%
df.corr()['Income'].sort_values(ascending=False)
# Out:
# Income            1.000000
# Education_num     0.335182
# Age               0.234039
# Hours_per_week    0.229690
# Capital_gain      0.223333
# Sex               0.215995
# Capital_loss      0.150523
# Education         0.079311
# Occupation        0.075448
# Race              0.071853
# Workclass         0.051645
# Native_country    0.015845
# Fnlwgt           -0.009481
# Marital_status   -0.199295
# Relationship     -0.250924
# Name: Income, dtype: float64

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(),annot=True,linewidths=4,linecolor='white',fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Checking the columns which are positively and negatively correlated to the target variable.

# %%
plt.figure(figsize=(12,10))
df.corr()['Income'].sort_values(ascending=False).drop(['Income']).plot(kind='bar',color='r')
plt.xlabel('features',fontsize=12)
plt.ylabel('column with target names',fontsize=12)
plt.show()

# %% [markdown]
# # Outliers Checking

# %%
collist=df.columns.values
ncol=30
nrow=14

# %%
collist
# Out:
# array(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'], dtype=object)

# %%
for i in range(0,len(collist)):
    print(collist[i])
    break
# Out:
# Age

# %%
plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(data = df[collist[i]],color='blue',orient='v')
    plt.tight_layout()

# %%
from scipy.stats import zscore
import numpy as np

# %%
(np.abs(zscore(df))<3).all().all()
# Out:
# False

# %% [markdown]
# As the result is false so there are outliers present in the data set which will be treated.

# %% [markdown]
# # Removing Outliers

# %% [markdown]
# zscore Technique

# %%
z=np.abs(zscore(df))
threshold=3
np.where(z>3)
# Out:
# (array([    3,     9,    10, ..., 32532, 32550, 32552], dtype=int64),
#  array([13, 12,  8, ...,  8,  8,  8], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df_new
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       50          6   83311          9             13               2
# 1       38          4  215646         11              9               0
# 2       53          4  234721          1              7               2
# 4       37          4  284582         12             14               2
# 5       49          4  160187          6              5               3
# ...    ...        ...     ...        ...            ...             ...
# 32555   27          4  257302          7             12               2
# 32556   40          4  154374         11              9               2
# 32557   58          4  151910         11              9               6
# 32558   22          4  201490         11              9               4
# 32559   52          5  287927         11              9               2
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# ...

# %%
df_new.shape
# Out:
# (27417, 15)

# %%
data_loss=((32560-27417)/32560)*100

# %%
data_loss
# Out:
# 15.795454545454547

# %% [markdown]
# This is the percentage of data lost

# %% [markdown]
# OUTLIERS HAS BEEN REMOVED FROM THE DATA.

# %% [markdown]
# Since the percentage of data loss is more the 10.0 so we won't be removing the outliers from the data while preprocessing as it can hinder the performance of the model that we create so we will be using df data set instead of df_new

# %% [markdown]
# # Seperating features and the target variable

# %%
features=df.drop('Income',axis=1)
target=df['Income']

# %%
features
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       50          6   83311          9             13               2
# 1       38          4  215646         11              9               0
# 2       53          4  234721          1              7               2
# 3       28          4  338409          9             13               2
# 4       37          4  284582         12             14               2
# ...    ...        ...     ...        ...            ...             ...
# 32555   27          4  257302          7             12               2
# 32556   40          4  154374         11              9               2
# 32557   58          4  151910         11              9               6
# 32558   22          4  201490         11              9               4
# 32559   52          5  287927         11              9               2
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# ...

# %%
target
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 32555    0
# 32556    1
# 32557    0
# 32558    0
# 32559    1
# Name: Income, Length: 32560, dtype: int32

# %% [markdown]
# # Checking skewness

# %%
features.skew()
# Out:
# Age                0.558738
# Workclass         -0.752280
# Fnlwgt             1.446972
# Education         -0.934063
# Education_num     -0.311630
# Marital_status    -0.013448
# Occupation         0.114540
# Relationship       0.786784
# Race              -2.435332
# Sex               -0.719244
# Capital_gain      11.953690
# Capital_loss       4.594549
# Hours_per_week     0.227636
# Native_country    -3.658235
# dtype: float64

# %% [markdown]
# keeping -/+0.7 as the range of skewness. Here are the columns that are not in range

# %%
features.plot(kind='density',subplots=True,layout=(6,11),sharex=False,legend=False,fontsize=2,figsize=(15,13))
plt.show()

# %% [markdown]
# # Removing skewness

# %% [markdown]
# CUBE ROOT METHOD

# %%
features_n=np.cbrt(features['Age'])

# %%
features_n=np.cbrt(features['Workclass'])

# %%
features_n=np.cbrt(features['Fnlwgt'])

# %%
features_n=np.cbrt(features['Education'])

# %%
features_n=np.cbrt(features['Education_num'])

# %%
features_n=np.cbrt(features['Marital_status'])

# %%
features_n=np.cbrt(features['Occupation'])

# %%
features_n=np.cbrt(features['Relationship'])

# %%
features_n=np.cbrt(features['Race'])

# %%
features_n=np.cbrt(features['Sex'])

# %%
features_n=np.cbrt(features['Capital_gain'])

# %%
features_n=np.cbrt(features['Capital_loss'])

# %%
features_n=np.cbrt(features['Hours_per_week'])

# %%
features_n=np.cbrt(features['Native_country'])

# %%
pd.DataFrame(features_n,columns=features.columns).skew().sort_values(ascending=False)
# Out:
# Native_country   -6.190178
# Age                    NaN
# Workclass              NaN
# Fnlwgt                 NaN
# Education              NaN
# Education_num          NaN
# Marital_status         NaN
# Occupation             NaN
# Relationship           NaN
# Race                   NaN
# Sex                    NaN
# Capital_gain           NaN
# Capital_loss           NaN
# Hours_per_week         NaN
# dtype: float64

# %% [markdown]
# cuberoot is not working

# %% [markdown]
# SQUARE ROOT METHOD

# %%
features['Age']=np.sqrt(features['Age'])

# %%
features['Native_country']=np.sqrt(features['Native_country'])

# %%
features['Workclass']=np.sqrt(features['Workclass'])

# %%
features['Fnlwgt']=np.sqrt(features['Fnlwgt'])

# %%
features['Education']=np.sqrt(features['Education'])

# %%
features['Education_num']=np.sqrt(features['Education_num'])

# %%
features['Marital_status']=np.sqrt(features['Marital_status'])

# %%
features['Occupation']=np.sqrt(features['Occupation'])

# %%
features['Relationship']=np.sqrt(features['Relationship'])

# %%
features['Race']=np.sqrt(features['Race'])

# %%
features['Sex']=np.sqrt(features['Sex'])

# %%
features['Capital_gain']=np.sqrt(features['Capital_gain'])

# %%
features['Capital_loss']=np.sqrt(features['Capital_loss'])

# %%
features['Hours_per_week']=np.sqrt(features['Hours_per_week'])

# %%
pd.DataFrame(features,columns=features.columns).skew().sort_values(ascending=False)
# Out:
# Capital_loss      4.322084
# Capital_gain      3.556495
# Age              -0.049118
# Relationship     -0.215173
# Fnlwgt           -0.336166
# Sex              -0.719244
# Education_num    -1.502270
# Hours_per_week   -1.708866
# Occupation       -1.838556
# Marital_status   -1.843562
# Workclass        -3.247017
# Education        -3.409062
# Native_country   -5.553596
# Race             -5.888456
# dtype: float64

# %% [markdown]
# there is still skewness in some columns so we will use another one

# %% [markdown]
# We are using YEO JOHNSON method

# %%
from sklearn.preprocessing import power_transform

# %%
features.skew().sort_values(ascending=False)
# Out:
# Capital_gain      11.953690
# Capital_loss       4.594549
# Fnlwgt             1.446972
# Relationship       0.786784
# Age                0.558738
# Hours_per_week     0.227636
# Occupation         0.114540
# Marital_status    -0.013448
# Education_num     -0.311630
# Sex               -0.719244
# Workclass         -0.752280
# Education         -0.934063
# Race              -2.435332
# Native_country    -3.658235
# dtype: float64

# %%
features_n=power_transform(features,method='yeo-johnson')

# %%
pd.DataFrame(features_n,columns=features.columns).skew().sort_values(ascending=False)
# Out:
# Capital_loss      4.299511
# Capital_gain      3.016951
# Hours_per_week    0.229556
# Relationship      0.122917
# Workclass         0.061629
# Education_num     0.023885
# Fnlwgt            0.016914
# Age              -0.013897
# Marital_status   -0.114201
# Occupation       -0.187152
# Education        -0.309431
# Sex              -0.719244
# Race             -2.010817
# Native_country   -2.725467
# dtype: float64

# %%
type(features_n)
# Out:
# numpy.ndarray

# %%
features.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country'],
#       dtype='object')

# %%
features=pd.DataFrame(features_n,columns=features.columns)

# %%
features.skew().sort_values(ascending=False)
# Out:
# Capital_loss      4.299511
# Capital_gain      3.016951
# Hours_per_week    0.229556
# Relationship      0.122917
# Workclass         0.061629
# Education_num     0.023885
# Fnlwgt            0.016914
# Age              -0.013897
# Marital_status   -0.114201
# Occupation       -0.187152
# Education        -0.309431
# Sex              -0.719244
# Race             -2.010817
# Native_country   -2.725467
# dtype: float64

# %% [markdown]
# skewness from the data has been removed

# %% [markdown]
# # Training Process Begins

# %% [markdown]
# # Balancing The Data

# %%
from imblearn.over_sampling import SMOTE

# %%
sm=SMOTE()
fea_res,tar_res=sm.fit_resample(features,target)

# %%
fea_res.value_counts()
# Out:
# Age        Workclass  Fnlwgt     Education  Education_num  Marital_status  Occupation  Relationship  Race       Sex        Capital_gain  Capital_loss  Hours_per_week  Native_country
# -1.029685  0.011864    0.220938  -1.792489  -2.733071       0.919719        0.631713    0.134511      0.412893  -1.422298  -0.30137      -0.221213     -0.035570       -3.221223         3
#  0.386185  0.011864    0.296705   1.387031  -0.075517      -0.383427        0.829763   -1.094635      0.412893   0.703087  -0.30137      -0.221213     -0.035570        0.329074         3
# -1.029685  0.011864    1.129692  -0.477012   1.164793       0.919719       -0.775241    0.134511      0.412893   0.703087  -0.30137      -0.221213     -0.035570       -2.954932         2
# -1.725471  0.011864   -0.276760   1.387031  -0.075517       0.919719       -0.502825    1.091081     -2.431920   0.703087  -0.30137      -0.221213     -0.845396        0.329074         2
# ...

# %%
tar_res.value_counts()
# Out:
# 0    24719
# 1    24719
# Name: Income, dtype: int64

# %% [markdown]
# # Finding Best Random State

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.model_selection import train_test_split

# %%
maxaccu=0
maxRs=0
for i in range(0,200):
    fea_res_train,fea_res_test,tar_res_train,tar_res_test=train_test_split(fea_res,tar_res,test_size=.20,random_state=i)
    dt.fit(fea_res_train,tar_res_train)
    pre_train=dt.predict(fea_res_test)
    acc=accuracy_score(tar_res_test,pre_train)
    print('accuracy',acc,'random_state',i)
    
    if acc>maxaccu:
        maxaccu=acc
        maxRs=i
        print('maximum accuracy',maxaccu,'maximum random state',maxRs)
# Out:
# accuracy 0.8556836569579288 random_state 0
# maximum accuracy 0.8556836569579288 maximum random state 0
# accuracy 0.8478964401294499 random_state 1
# accuracy 0.8538632686084142 random_state 2
# accuracy 0.8568972491909385 random_state 3
# maximum accuracy 0.8568972491909385 maximum random state 3
# accuracy 0.8475930420711975 random_state 4
# accuracy 0.8545711974110033 random_state 5
# accuracy 0.8540655339805825 random_state 6
# accuracy 0.8480987055016181 random_state 7
# accuracy 0.8471885113268608 random_state 8
# accuracy 0.8538632686084142 random_state 9
# accuracy 0.8489077669902912 random_state 10
# accuracy 0.8545711974110033 random_state 11
# accuracy 0.852245145631068 random_state 12
# accuracy 0.8562904530744336 random_state 13
# accuracy 0.85082928802589 random_state 14
# accuracy 0.8580097087378641 random_state 15
# maximum accuracy 0.8580097087378641 maximum random state 15
# accuracy 0.8488066343042071 random_state 16
# accuracy 0.8495145631067961 random_state 17
# ...

# %%
print('best accuracy score',maxaccu ,'on random state',maxRs)
# Out:
# best accuracy score 0.8606391585760518 on random state 68

# %% [markdown]
# # Create train test split

# %%
fea_res_train,fea_res_test,tar_res_train,tar_res_test=train_test_split(fea_res,tar_res,test_size=.20,random_state=60)

# %%
fea_res_train.shape
# Out:
# (39550, 14)

# %%
fea_res_test.shape
# Out:
# (9888, 14)

# %%
tar_res_train.shape
# Out:
# (39550,)

# %%
tar_res_test.shape
# Out:
# (9888,)

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(fea_res_train,tar_res_train)
pre_train=dt.predict(fea_res_test)
print('accuracy',accuracy_score(tar_res_test,pre_train)*100)
print(confusion_matrix(tar_res_test,pre_train))
print(classification_report(tar_res_test,pre_train))
# Out:
# accuracy 86.02346278317152
# [[4270  708]
#  [ 674 4236]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86      4978
#            1       0.86      0.86      0.86      4910
#
#     accuracy                           0.86      9888
#    macro avg       0.86      0.86      0.86      9888
# weighted avg       0.86      0.86      0.86      9888

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=300)
rf.fit(fea_res_train,tar_res_train)
pre_train=rf.predict(fea_res_test)
print('accuracy',accuracy_score(tar_res_test,pre_train)*100)
print(confusion_matrix(tar_res_test,pre_train))
print(classification_report(tar_res_test,pre_train))
# Out:
# accuracy 90.36205501618123
# [[4443  535]
#  [ 418 4492]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.89      0.90      4978
#            1       0.89      0.91      0.90      4910
#
#     accuracy                           0.90      9888
#    macro avg       0.90      0.90      0.90      9888
# weighted avg       0.90      0.90      0.90      9888

# %% [markdown]
# # K Neighbors classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(fea_res_train,tar_res_train)
pre_train=knn.predict(fea_res_test)
print('accuracy',accuracy_score(tar_res_test,pre_train)*100)
print(confusion_matrix(tar_res_test,pre_train))
print(classification_report(tar_res_test,pre_train))
# Out:
# accuracy 85.49757281553399
# [[3885 1093]
#  [ 341 4569]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.78      0.84      4978
#            1       0.81      0.93      0.86      4910
#
#     accuracy                           0.85      9888
#    macro avg       0.86      0.86      0.85      9888
# weighted avg       0.86      0.85      0.85      9888

# %% [markdown]
# # support vector classifier

# %%
from sklearn.svm import SVC
svc=SVC()
svc.fit(fea_res_train,tar_res_train)
pre_train=svc.predict(fea_res_test)
print('accuracy',accuracy_score(tar_res_test,pre_train)*100)
print(confusion_matrix(tar_res_test,pre_train))
print(classification_report(tar_res_test,pre_train))
# Out:
# accuracy 83.48503236245955
# [[3859 1119]
#  [ 514 4396]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.78      0.83      4978
#            1       0.80      0.90      0.84      4910
#
#     accuracy                           0.83      9888
#    macro avg       0.84      0.84      0.83      9888
# weighted avg       0.84      0.83      0.83      9888

# %% [markdown]
# # AdaBoost Classifier

# %%
from sklearn.ensemble import AdaBoostClassifier
ad=AdaBoostClassifier()
ad.fit(fea_res_train,tar_res_train)
pre_train=ad.predict(fea_res_test)
print('accuracy',accuracy_score(tar_res_test,pre_train)*100)
print(confusion_matrix(tar_res_test,pre_train))
print(classification_report(tar_res_test,pre_train))
# Out:
# accuracy 85.66949838187702
# [[4169  809]
#  [ 608 4302]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.84      0.85      4978
#            1       0.84      0.88      0.86      4910
#
#     accuracy                           0.86      9888
#    macro avg       0.86      0.86      0.86      9888
# weighted avg       0.86      0.86      0.86      9888

# %% [markdown]
# # Cross Validation

# %%
from sklearn.model_selection import cross_val_score
scr=cross_val_score(dt,fea_res,tar_res,cv=9)
print('cross validation score for Decision tree model =', scr.mean())
# Out:
# cross validation score for Decision tree model = 0.8519981957157948

# %%
from sklearn.model_selection import cross_val_score
scr=cross_val_score(rf,fea_res,tar_res,cv=9)
print('cross validation score for Random Forest Classifier  model =', scr.mean())
# Out:
# cross validation score for Random Forest Classifier  model = 0.9015751508325205

# %%
from sklearn.model_selection import cross_val_score
scr=cross_val_score(knn,fea_res,tar_res,cv=9)
print('cross validation score for K Neighbors classifiermodel =', scr.mean())
# Out:
# cross validation score for K Neighbors classifiermodel = 0.8570335505273913

# %%
from sklearn.model_selection import cross_val_score
scr=cross_val_score(svc,fea_res,tar_res,cv=9)
print('cross validation score for Support Vector classifiermodel =', scr.mean())

# %%
from sklearn.model_selection import cross_val_score
scr=cross_val_score(ad,fea_res,tar_res,cv=9)
print('cross validation score for ada Boost classifiermodel =', scr.mean())

# %% [markdown]
# among all random forest is working best so we will go with random forest

# %% [markdown]
# # Hyper parameter tunning

# %%
RandomForestClassifier()
# Out:
# RandomForestClassifier()

# %%
#these are the parameters.
from sklearn.model_selection import GridSearchCV
parameters={'max_features':['auto','sqrt','log2'], 'max_depth':[4,5,6,7,8],'criterion':['ginni','entropy'],
           'n_estimators':[100,200,300,400,500]}

# %% [markdown]
# # Using GridsearchCV

# %%
#usng gridsearch cv and random forest parameters.
gcv=GridSearchCV(RandomForestClassifier(),parameters,cv=9,scoring="accuracy")
gcv.fit(fea_res_train,tar_res_train)
gcv.best_params_

# %%
#finding the best estimator using grid search cv
gcv.best_estimator_

# %%
#predicting the best one now
gcv_pred=gcv.best_estimator_.predict(fea_res_test)
accuracy_score=(tar_res_test,gcv_pred)

# %% [markdown]
# # ROC AUC curve

# %% [markdown]
# # Making ROC AUC Curve

# %%
from sklearn.metrics import plot_roc_curve
plot_roc_curve(gcv.best_estimator_,fea_res_test,tar_res_test)
plt.title('ROC AUC plot')
plt.show

# %% [markdown]
# # SAVING MODEL

# %%
import pickle
filename='CENSUS.pkl'
pickle.dump(rf,open('CENSUS.pkl','wb'))
