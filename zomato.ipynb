# %% [markdown]
# # zomato project

# %%
#importing essential libraries that would be required.
import pandas as pd
import numpy as np

# %%
#reading the csv file and creating dataset in df variable
data=pd.read_csv('zomato.csv')

# %%
data
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
df2=pd.read_excel("Country-Code.xlsx")

# %%
df2
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
df=pd.merge (data,df2)

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
#this could helps to get the information about the data set in the variable named df.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
#this code tells the no of rows and columns present in the dataset.
df.shape
# Out:
# (9551, 22)

# %%
#this code tells the data type of the columns present in dataset.
df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %%
#this code gives top five rows from the data
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
#this code give last 5 rows of the dataset.
df.tail()
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9546        5915730               Naml۱ Gurme           208  ��stanbul
# 9547        5908749              Ceviz A��ac۱           208  ��stanbul
# 9548        5915807                     Huqqa           208  ��stanbul
# 9549        5916112               A���k Kahve           208  ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208  ��stanbul
#
#                                                 Address     Locality  \
# 9546  Kemanke�� Karamustafa Pa��a Mahallesi, R۱ht۱m ...     Karak�_y
# 9547  Ko��uyolu Mahallesi, Muhittin ��st�_nda�� Cadd...    Ko��uyolu
# 9548  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...  Kuru�_e��me
# 9549  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...  Kuru�_e��me
# 9550  Cafea��a Mahallesi, Bademalt۱ Sokak, No 21/B, ...         Moda
#
#             Locality Verbose  Longitude   Latitude  \
# 9546     Karak�_y, ��stanbul  28.977392  41.022793
# ...

# %%
#this gives the sample row from the dataset
df.sample()
# Out:
#       Restaurant ID Restaurant Name  Country Code       City  \
# 7811       18390095         Foodiez             1  New Delhi
#
#                                                 Address            Locality  \
# 7811  G 24, Sunrise Vardhman Plaza, Vasundhara Encla...  Vasundhara Enclave
#
#                    Locality Verbose  Longitude   Latitude     Cuisines  ...  \
# 7811  Vasundhara Enclave, New Delhi  77.320623  28.600291  Street Food  ...
#
#       Has Table booking Has Online delivery Is delivering now  \
# 7811                 No                  No                No
#
#      Switch to order menu Price range Aggregate rating  Rating color  \
# 7811                   No           1              0.0         White
#
#       Rating text Votes Country
# 7811    Not rated     2   India
#
# [1 rows x 22 columns]

# %%
#this gives the column name from the dataset
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %% [markdown]
# # CHECKING FOR THE DUPLICATED VALUES IN THE TABLE OR DATASET

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # CHECKING FOR THE UNIQUE VALUES IN THE TABLE OR DATASET

# %% [markdown]
# # Checking unique values in the whole dataset

# %%
df.nunique()
# Out:
# Restaurant ID           9551
# Restaurant Name         7446
# Country Code              15
# City                     141
# Address                 8918
# Locality                1208
# Locality Verbose        1265
# Longitude               8120
# Latitude                8677
# Cuisines                1825
# Average Cost for two     140
# Currency                  12
# Has Table booking          2
# Has Online delivery        2
# Is delivering now          2
# Switch to order menu       1
# Price range                4
# Aggregate rating          33
# Rating color               6
# Rating text                6
# Votes                   1012
# Country                   15
# dtype: int64

# %% [markdown]
# # checking unique values in target column of part A

# %%
df['Average Cost for two'].nunique()
# Out:
# 140

# %% [markdown]
# # checking unique values in target column of part B

# %%
df['Price range'].nunique()
# Out:
# 4

# %% [markdown]
# # Checking for the Null Values

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
sns.heatmap(df.isnull())
plt.title('Null Values')
# Out:
# Text(0.5, 1.0, 'Null Values')

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %% [markdown]
# column Cuisines have null values

# %% [markdown]
# # Treating Null Values

# %% [markdown]
# Finding the mode value of the “Cuisines” column as it will have occurred the maximum number of times

# %%
df['Cuisines'].fillna(df['Cuisines'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
sns.heatmap(df.isnull())
plt.title('Null Values')
# Out:
# Text(0.5, 1.0, 'Null Values')

# %% [markdown]
# Now we can see that the null values or columns has been treated.

# %% [markdown]
# # EDA

# %% [markdown]
# # Visualization Of The Data

# %% [markdown]
# # 1.pairplot

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
sns.pairplot(df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # 2. histogarm

# %%
df.hist(bins=10,figsize=(10,10))
plt.show()

# %% [markdown]
# # COUNT PLOT

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
sns.countplot(df['Country Code'])
df['Country Code'].value_counts()
# Out:
# 1      8652
# 216     434
# 215      80
# 30       60
# 214      60
# 189      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 184      20
# 166      20
# 191      20
# 37        4
# Name: Country Code, dtype: int64

# %% [markdown]
# this tells the country code of the restaurants
#
# most of the restaurants are in the country with country cose 1
#
# least are in the country with the code 37

# %%
sns.countplot(df['City'])
df['City'].value_counts()
# Out:
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
#                 ...
# Huskisson          1
# Panchkula          1
# Forrest            1
# Flaxton            1
# Chatham-Kent       1
# Name: City, Length: 141, dtype: int64

# %% [markdown]
# most of the restaurants on zomato are in the city new delhi and the least restaurants that are on zomato are chatham-kent

# %%
sns.countplot(df['Currency'])
df['Currency'].value_counts()
# Out:
# Indian Rupees(Rs.)        8652
# Dollar($)                  482
# Pounds(��)                  80
# Brazilian Real(R$)          60
# Emirati Diram(AED)          60
# Rand(R)                     60
# NewZealand($)               40
# Turkish Lira(TL)            34
# Botswana Pula(P)            22
# Indonesian Rupiah(IDR)      21
# Qatari Rial(QR)             20
# Sri Lankan Rupee(LKR)       20
# Name: Currency, dtype: int64

# %% [markdown]
# this graph tells that most of the currency received is of Indian rupees and least is of sri lankan rupee

# %%
sns.countplot(df['Has Table booking'])
df['Has Table booking'].value_counts()
# Out:
# No     8393
# Yes    1158
# Name: Has Table booking, dtype: int64

# %% [markdown]
# this graph tells that how many of the restaurants on zomato have table booking and how many of them don't have
#
# No     8393
#
# Yes    1158

# %%
sns.countplot(df['Has Online delivery'])
df['Has Online delivery'].value_counts()
# Out:
# No     7100
# Yes    2451
# Name: Has Online delivery, dtype: int64

# %% [markdown]
# this graph tells that how many of the restaurants on zomato Has Online delivery and how many of them don't have
#
# No 7100
#
# Yes 2451

# %%
sns.countplot(df['Is delivering now'])
df['Is delivering now'].value_counts()
# Out:
# No     9517
# Yes      34
# Name: Is delivering now, dtype: int64

# %% [markdown]
# this graph tells that how many of the restaurants on zomato Is delivering now and how many of them don't have
#
# No 9517
#
# Yes 34

# %%
sns.countplot(df['Aggregate rating'])
df['Aggregate rating'].value_counts()
# Out:
# 0.0    2148
# 3.2     522
# 3.1     519
# 3.4     498
# 3.3     483
# 3.5     480
# 3.0     468
# 3.6     458
# 3.7     427
# 3.8     400
# 2.9     381
# 3.9     335
# 2.8     315
# 4.1     274
# 4.0     266
# 2.7     250
# 4.2     221
# 2.6     191
# 4.3     174
# 4.4     144
# 2.5     110
# 4.5      95
# 2.4      87
# 4.6      78
# 4.9      61
# 2.3      47
# 4.7      42
# 2.2      27
# 4.8      25
# 2.1      15
# 2.0       7
# 1.9       2
# 1.8       1
# Name: Aggregate rating, dtype: int64

# %% [markdown]
# this graph tells what rating which restaurant has received
#
#  most of the restaurants have rating of 0.0 i.e people don't give rating =   2148
#
# least of the restaurants have rating of 1.8       1

# %%
sns.countplot(df['Rating color'])
df['Rating color'].value_counts()
# Out:
# Orange        3737
# White         2148
# Yellow        2100
# Green         1079
# Dark Green     301
# Red            186
# Name: Rating color, dtype: int64

# %% [markdown]
# this graph tells the rating color givin to the restaurants on zomato
#
# Orange        3737
#
# White         2148
#
# Yellow        2100
#
# Green         1079
#
# Dark Green     301
#
# Red            186

# %%
sns.countplot(df['Rating text'])
df['Rating text'].value_counts()
# Out:
# Average      3737
# Not rated    2148
# Good         2100
# Very Good    1079
# Excellent     301
# Poor          186
# Name: Rating text, dtype: int64

# %% [markdown]
# this graph tells the rating text received by the restaurants on zomato
#
# Average      3737
#
# Not rated    2148
#
# Good         2100
#
# Very Good    1079
#
# Excellent     301
#
# Poor          186

# %%
sns.countplot(df['Country'])
df['Country'].value_counts()
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %% [markdown]
# this graph tells which country serves most
# restaurants.
#
# top country is India
#
# last is the canada

# %%
sns.countplot(df['Locality'])
df['Locality'].value_counts()
# Out:
# Connaught Place                                122
# Rajouri Garden                                  99
# Shahdara                                        87
# Defence Colony                                  86
# Pitampura                                       85
#                                               ...
# Lemon Tree Premier, Sector 29                    1
# Omaxe Celebration Mall, Sohna Road, Gurgaon      1
# Park Inn, Sector 15, Gurgaon                     1
# Plaza Mall, MG Road                              1
# Moda                                             1
# Name: Locality, Length: 1208, dtype: int64

# %% [markdown]
# this graph tells which locality of that country serves that cuisines with maximum number of restaurants in India
#
# on the top comes the Connaught Place
#
# and the last is the moda

# %%
sns.countplot(df['Longitude'])
df['Longitude'].value_counts()
# Out:
# 0.000000     498
# 77.353663     19
# 77.230412     12
# 77.088688     10
# 77.251426      9
#             ...
# 77.227294      1
# 77.225420      1
# 77.230347      1
# 77.230578      1
# 29.026016      1
# Name: Longitude, Length: 8120, dtype: int64

# %%
sns.countplot(df['Cuisines'])
df['Cuisines'].value_counts()
# Out:
# North Indian                                             936
# North Indian, Chinese                                    511
# Chinese                                                  354
# Fast Food                                                354
# North Indian, Mughlai                                    334
#                                                         ...
# Bengali, Fast Food                                         1
# North Indian, Rajasthani, Asian                            1
# Chinese, Thai, Malaysian, Indonesian                       1
# Bakery, Desserts, North Indian, Bengali, South Indian      1
# Italian, World Cuisine                                     1
# Name: Cuisines, Length: 1825, dtype: int64

# %% [markdown]
# this graph tells which type of cuisine is sold in most restaurants most
#
# top comes the north indian
#
# last is the italian world cuisine

# %%
sns.countplot(df['Locality Verbose'])
df['Locality Verbose'].value_counts()
# Out:
# Connaught Place, New Delhi                    122
# Rajouri Garden, New Delhi                      99
# Shahdara, New Delhi                            87
# Defence Colony, New Delhi                      86
# Pitampura, New Delhi                           85
#                                              ...
# Ramada Gurgaon Central, Sector 44, Gurgaon      1
# Sector 5, Gurgaon                               1
# Sector 53, Gurgaon                              1
# The Claremont, MG Road, Gurgaon                 1
# Moda, ��stanbul                                 1
# Name: Locality Verbose, Length: 1265, dtype: int64

# %%
this graph tells which Locality Verbose serves that cuisines with maximum number of restaurants in India

on the top comes the Connaught Place

and the last is the mod

# %% [markdown]
# # violin plot

# %%
sns.violinplot(x='Latitude',data=df)
# Out:
# <AxesSubplot:xlabel='Latitude'>

# %%
sns.violinplot(x='Longitude',data=df)
# Out:
# <AxesSubplot:xlabel='Longitude'>

# %%
sns.violinplot(x='Average Cost for two',data=df)
# Out:
# <AxesSubplot:xlabel='Average Cost for two'>

# %%
sns.violinplot(x='Aggregate rating',data=df)
# Out:
# <AxesSubplot:xlabel='Aggregate rating'>

# %% [markdown]
# most of the agg rating is in the range of 3 to 4

# %%
sns.violinplot(x='Price range',data=df)
# Out:
# <AxesSubplot:xlabel='Price range'>

# %%
sns.violinplot(x='Votes',data=df)
# Out:
# <AxesSubplot:xlabel='Votes'>

# %% [markdown]
# # Displot

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
sns.displot(df['Country Code'])

# %%
sns.displot(df['City'])

# %%
sns.displot(df['Latitude'])

# %%
sns.displot(df['Longitude'])

# %%
sns.displot(df['Average Cost for two'])

# %%
sns.displot(df['Aggregate rating'])

# %%
sns.displot(df['Price range'])

# %%
sns.displot(df['Votes'])

# %% [markdown]
# # Describing Data

# %%
df.describe(include='all')
# Out:
#         Restaurant ID  Restaurant Name  Country Code       City  \
# count    9.551000e+03             9551   9551.000000       9551
# unique            NaN             7446           NaN        141
# top               NaN  Cafe Coffee Day           NaN  New Delhi
# freq              NaN               83           NaN       5473
# mean     9.051128e+06              NaN     18.365616        NaN
# std      8.791521e+06              NaN     56.750546        NaN
# min      5.300000e+01              NaN      1.000000        NaN
# 25%      3.019625e+05              NaN      1.000000        NaN
# 50%      6.004089e+06              NaN      1.000000        NaN
# 75%      1.835229e+07              NaN      1.000000        NaN
# max      1.850065e+07              NaN    216.000000        NaN
#
#                  Address         Locality            Locality Verbose  \
# count               9551             9551                        9551
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,10))
sns.heatmap(df.describe(),annot=True,linewidths=2,linecolor='Black',fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Encoding Data

# %% [markdown]
# Encoding the categorical columns for furthe processing and model building

# %%
from sklearn import preprocessing

# %%
le= preprocessing.LabelEncoder()

# %%
df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %%
df['Restaurant Name']= le.fit_transform(df['Restaurant Name'])

# %%
df['City']= le.fit_transform(df['City'])

# %%
df['Address']= le.fit_transform(df['Address'])

# %%
df['Locality']= le.fit_transform(df['Locality'])

# %%
df['Locality Verbose']= le.fit_transform(df['Locality Verbose'])

# %%
df['Cuisines']= le.fit_transform(df['Cuisines'])

# %%
df['Currency']= le.fit_transform(df['Currency'])

# %%
df['Has Table booking']= le.fit_transform(df['Has Table booking'])

# %%
df['Has Online delivery']= le.fit_transform(df['Has Online delivery'])

# %%
df['Is delivering now']= le.fit_transform(df['Is delivering now'])

# %%
df['Switch to order menu']= le.fit_transform(df['Switch to order menu'])

# %%
df['Rating color']= le.fit_transform(df['Rating color'])

# %%
df['Rating text']= le.fit_transform(df['Rating text'])

# %%
df['Country']= le.fit_transform(df['Country'])

# %% [markdown]
# # Checking correlation of columns

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(),annot=True,linewidths=2,linecolor='Black',fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#                       Restaurant ID  Restaurant Name  Country Code      City  \
# Restaurant ID              1.000000         0.003999      0.148471 -0.005844
# Restaurant Name            0.003999         1.000000      0.020013 -0.001400
# Country Code               0.148471         0.020013      1.000000 -0.181728
# City                      -0.005844        -0.001400     -0.181728  1.000000
# Address                    0.080615         0.000764     -0.220342 -0.019763
# Locality                   0.069511         0.004322     -0.120076  0.096443
# Locality Verbose           0.070102         0.004281     -0.117543  0.093141
# Longitude                 -0.226081        -0.001920     -0.698299  0.117391
# Latitude                  -0.052081         0.009922      0.019792 -0.004301
# Cuisines                  -0.078644         0.051680     -0.132902  0.026614
# Average Cost for two      -0.001693         0.019241      0.043225 -0.028838
# ...

# %% [markdown]
# # checking correlation of columns with target variable in part A

# %%
df.corr()['Average Cost for two'].sort_values(ascending=False)
# Out:
# Average Cost for two    1.000000
# Price range             0.075083
# Votes                   0.067783
# Aggregate rating        0.051792
# Longitude               0.045891
# Currency                0.045615
# Country Code            0.043225
# Rating text             0.031439
# Address                 0.022749
# Restaurant Name         0.019241
# Has Table booking       0.007758
# Cuisines                0.005831
# Restaurant ID          -0.001693
# Is delivering now      -0.001862
# Country                -0.004034
# Locality Verbose       -0.011852
# Locality               -0.012136
# Has Online delivery    -0.018974
# City                   -0.028838
# Rating color           -0.049970
# Latitude               -0.111088
# Switch to order menu         NaN
# Name: Average Cost for two, dtype: float64

# %% [markdown]
# # checking the columns which are positively and negatively correlated to the target variable of part A.

# %%
plt.figure(figsize=(12,10))
df.corr()['Average Cost for two'].sort_values(ascending=False).drop(['Average Cost for two']).plot(kind='bar',color='g')
plt.xlabel('features',fontsize=12)
plt.ylabel('column with target names',fontsize=12)
plt.show()

# %% [markdown]
# # checking correlation of columns with target variable in part B

# %%
df.corr()['Price range'].sort_values(ascending=False)
# Out:
# Price range             1.000000
# Has Table booking       0.501925
# Aggregate rating        0.437944
# Votes                   0.309444
# Country Code            0.243327
# Country                 0.178035
# Rating text             0.164242
# Has Online delivery     0.077918
# Currency                0.075179
# Average Cost for two    0.075083
# Restaurant Name         0.061275
# Is delivering now       0.010940
# Cuisines               -0.005350
# Address                -0.034952
# Longitude              -0.078939
# City                   -0.105759
# Locality Verbose       -0.112311
# Locality               -0.114457
# Restaurant ID          -0.134540
# Rating color           -0.140468
# Latitude               -0.166688
# Switch to order menu         NaN
# Name: Price range, dtype: float64

# %% [markdown]
# # checking the columns which are positively and negatively correlated to the target variable of part B.

# %%
plt.figure(figsize=(12,10))
df.corr()['Price range'].sort_values(ascending=False).drop(['Price range']).plot(kind='bar',color='g')
plt.xlabel('features',fontsize=12)
plt.ylabel('column with target names',fontsize=12)
plt.show()

# %% [markdown]
# # Outliers Checking

# %%
collist=df.columns.values
ncol=30
nrow=14

# %%
collist
# Out:
# array(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City',
#        'Address', 'Locality', 'Locality Verbose', 'Longitude', 'Latitude',
#        'Cuisines', 'Average Cost for two', 'Currency',
#        'Has Table booking', 'Has Online delivery', 'Is delivering now',
#        'Switch to order menu', 'Price range', 'Aggregate rating',
#        'Rating color', 'Rating text', 'Votes', 'Country'], dtype=object)

# %%
for i in range(0,len(collist)):
    print(collist[i])
    break
# Out:
# Restaurant ID

# %%
plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(data = df[collist[i]],color='red',orient='v')
    plt.tight_layout()

# %%
from scipy.stats import zscore
import numpy as np

# %%
(np.abs(zscore(df))<3).all().all()
# Out:
# False

# %% [markdown]
# As the result is false so there are outliers present in the data set which will be treated.

# %% [markdown]
# # seperating features and the target variable

# %% [markdown]
# # part A target variable is Average Cost for two

# %%
features=df.drop('Average Cost for two',axis=1)
target=df['Average Cost for two']

# %% [markdown]
# # checking skewness in Data and Removing it

# %%
features.skew()
# Out:
# Restaurant ID            0.061570
# Restaurant Name          0.044637
# Country Code             3.043965
# City                    -1.193777
# Address                 -0.040407
# Locality                -0.253550
# Locality Verbose        -0.183059
# Longitude               -2.807328
# Latitude                -3.081635
# Cuisines                -0.307425
# Currency                 2.858093
# Has Table booking        2.321100
# Has Online delivery      1.114620
# Is delivering now       16.673412
# Switch to order menu     0.000000
# Price range              0.889618
# Aggregate rating        -0.954130
# Rating color             0.046009
# Rating text              0.431408
# Votes                    8.807637
# Country                  3.312721
# dtype: float64

# %% [markdown]
# keeping -/+0.7 as the range of skewness. Here are the columns that are not in range.

# %%
from sklearn.preprocessing import power_transform

# %%
features.skew().sort_values(ascending=False)
# Out:
# Is delivering now       16.673412
# Votes                    8.807637
# Country                  3.312721
# Country Code             3.043965
# Currency                 2.858093
# Has Table booking        2.321100
# Has Online delivery      1.114620
# Price range              0.889618
# Rating text              0.431408
# Restaurant ID            0.061570
# Rating color             0.046009
# Restaurant Name          0.044637
# Switch to order menu     0.000000
# Address                 -0.040407
# Locality Verbose        -0.183059
# Locality                -0.253550
# Cuisines                -0.307425
# Aggregate rating        -0.954130
# City                    -1.193777
# Longitude               -2.807328
# Latitude                -3.081635
# dtype: float64

# %% [markdown]
#  we are using YEO JOHNSON

# %%
features_n=power_transform(features,method='yeo-johnson')

# %%
pd.DataFrame(features_n,columns=features.columns).skew().sort_values(ascending=False)
# Out:
# Is delivering now       16.673412
# Country Code             2.780362
# Has Table booking        2.321100
# Has Online delivery      1.114620
# Currency                 0.448602
# Price range              0.182963
# Switch to order menu     0.000000
# Votes                   -0.004029
# Rating text             -0.059959
# Rating color            -0.103780
# City                    -0.203048
# Restaurant Name         -0.271708
# Locality Verbose        -0.279298
# Latitude                -0.293200
# Address                 -0.300427
# Locality                -0.304127
# Restaurant ID           -0.339181
# Cuisines                -0.383190
# Aggregate rating        -0.610806
# Longitude               -0.803832
# Country                 -1.341627
# dtype: float64

# %%
type(features_n)
# Out:
# numpy.ndarray

# %%
features.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Currency', 'Has Table booking', 'Has Online delivery',
#        'Is delivering now', 'Switch to order menu', 'Price range',
#        'Aggregate rating', 'Rating color', 'Rating text', 'Votes', 'Country'],
#       dtype='object')

# %%
features=pd.DataFrame(features_n,columns=features.columns)

# %%
features.skew().sort_values(ascending=False)
# Out:
# Is delivering now       16.673412
# Country Code             2.780362
# Has Table booking        2.321100
# Has Online delivery      1.114620
# Currency                 0.448602
# Price range              0.182963
# Switch to order menu     0.000000
# Votes                   -0.004029
# Rating text             -0.059959
# Rating color            -0.103780
# City                    -0.203048
# Restaurant Name         -0.271708
# Locality Verbose        -0.279298
# Latitude                -0.293200
# Address                 -0.300427
# Locality                -0.304127
# Restaurant ID           -0.339181
# Cuisines                -0.383190
# Aggregate rating        -0.610806
# Longitude               -0.803832
# Country                 -1.341627
# dtype: float64

# %% [markdown]
# # Training Process Begins

# %% [markdown]
# # Finding Best Random State and using min max scaler to scale the data

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
for i in range(0,100):
    features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=i)
    lr.fit(features_train,target_train)
    pre_train=lr.predict(features_train)
    pre_test=lr.predict(features_test)
    print(f"at random state {i},the train accuracy is:- {r2_score(target_train,pre_train)}")
    print(f"at random state {i},the testing accuracy is:- {r2_score(target_test,pre_test)}")
    print('\n')
# Out:
# at random state 0,the train accuracy is:- 0.05106340092267836
# at random state 0,the testing accuracy is:- 0.0650073149984437
#
#
# at random state 1,the train accuracy is:- 0.06581789331491905
# at random state 1,the testing accuracy is:- 0.036378496442523556
#
#
# at random state 2,the train accuracy is:- 0.0602698747579673
# at random state 2,the testing accuracy is:- -0.01908689868575153
#
#
# at random state 3,the train accuracy is:- 0.060214397260462404
# at random state 3,the testing accuracy is:- -0.006593890962361071
#
#
# at random state 4,the train accuracy is:- 0.06952626657048477
# at random state 4,the testing accuracy is:- -0.4442622417171722
#
#
# at random state 5,the train accuracy is:- 0.06418560547636543
# at random state 5,the testing accuracy is:- 0.03972899536199259
#
#
# at random state 6,the train accuracy is:- 0.060814959218280173
# at random state 6,the testing accuracy is:- 0.01861604038250997
#
#
# ...

# %%
features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=.20,random_state=52)

# %%
features_train.shape
# Out:
# (7640, 21)

# %%
features_test.shape
# Out:
# (1911, 21)

# %%
target_train.shape
# Out:
# (7640,)

# %%
target_test.shape
# Out:
# (1911,)

# %% [markdown]
# # Linear regression

# %%
lr.fit(features_train,target_train)
# Out:
# LinearRegression()

# %% [markdown]
# test accuracy

# %%
pre_test=lr.predict(features_test)

# %%
 print(r2_score(target_test,pre_test))
# Out:
# 0.10441560832310637

# %% [markdown]
# train accuracy

# %%
pre_train=lr.predict(features_train)

# %%
print(r2_score(target_train,pre_train))
# Out:
# 0.052033820487601856

# %% [markdown]
# # KNeighborsRegressor

# %%
from sklearn.neighbors import KNeighborsRegressor
knr=KNeighborsRegressor()
knr.fit(features_train,target_train)
# Out:
# KNeighborsRegressor()

# %% [markdown]
# test accuracy

# %%
pre_test=knr.predict(features_test)

# %%
 print(r2_score(target_test,pre_test))
# Out:
# -0.615469745011805

# %% [markdown]
# train accuracy

# %%
pre_train=knr.predict(features_train)

# %%
print(r2_score(target_train,pre_train))
# Out:
# 0.6864859726109227

# %% [markdown]
# # support vector regression

# %%
from sklearn.svm import SVR
svr=SVR()
svr.fit(features_train,target_train)
# Out:
# SVR()

# %% [markdown]
# test accuracy

# %%
pre_train=svr.predict(features_test)

# %%
 print(r2_score(target_test,pre_test))
# Out:
# -0.615469745011805

# %% [markdown]
# train accuracy

# %%
pre_train=svr.predict(features_train)

# %%
print(r2_score(target_train,pre_train))
# Out:
# -0.0012315966898193142

# %% [markdown]
# # RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor(n_estimators=300)
rfr.fit(features_train,target_train)
# Out:
# RandomForestRegressor(n_estimators=300)

# %% [markdown]
# test accuracy

# %%
pre_test=rfr.predict(features_test)

# %%
 print(r2_score(target_test,pre_test))
# Out:
# 0.14555871967243528

# %% [markdown]
# train accuracy

# %%
pre_train=rfr.predict(features_train)

# %%
print(r2_score(target_train,pre_train))
# Out:
# 0.9305459639713781

# %% [markdown]
# # Among all of the above models the best one is Random forest regression so we will go with it.
# it is best as it is giving a train accuracy of - 0.9388585091592199
# and
# test accuracy of - 0.14366803148468843

# %% [markdown]
# # Cross Validation

# %%
train_accuracy=r2_score(target_train,pre_train)
testing_accuracy=r2_score(target_test,pre_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(rfr,features,target,cv=j)
    cv_mean=cv_score.mean()
    print(f"at cross fold {j} the cv score is {cv_mean} and accuracy score for training is {train_accuracy} and accuracy score for testing is {testing_accuracy}")
    print('\n')
# Out:
# at cross fold 2 the cv score is -1286.0640147410816 and accuracy score for training is 0.9305459639713781 and accuracy score for testing is 0.14555871967243528
#
#
# at cross fold 3 the cv score is -1171.204139109022 and accuracy score for training is 0.9305459639713781 and accuracy score for testing is 0.14555871967243528
#
#
# at cross fold 4 the cv score is -1231.557660868263 and accuracy score for training is 0.9305459639713781 and accuracy score for testing is 0.14555871967243528
#
#
# at cross fold 5 the cv score is -1324.6755047799693 and accuracy score for training is 0.9305459639713781 and accuracy score for testing is 0.14555871967243528
#
#
# at cross fold 6 the cv score is -1234.0671378622505 and accuracy score for training is 0.9305459639713781 and accuracy score for testing is 0.14555871967243528
#
#
# at cross fold 7 the cv score is -1352.989251576011 and accuracy score for training is 0.9305459639713781 and accuracy score for testing is 0.14555871967243528
#
#
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,4))
plt.scatter(x=target_test, y=pre_test, color='r')
plt.plot(target_test,target_test,color='b')
plt.xlabel('Average Cost for two',fontsize=12)
plt.ylabel('predict Average Cost for two',fontsize=12)
plt.title('Random Forest Regression Graph',fontsize=18)
plt.savefig('lr.png')
plt.show()

# %% [markdown]
# this is the RANDOM FOREST REGRESSOR graph

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Ensemble technique

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
parameters={'criterion':['mse','mae'],'max_features':['auto','sqrt','log2']}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(features_train,target_train)
print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'auto'}

# %%
rf=RandomForestRegressor(criterion='mae',max_features='auto')
rf.fit(features_train,target_train)
rf.score(features_train,target_train)
prediction_decision=rf.predict(features_test)


rfscore=cross_val_score(rf,features,target,cv=8)
rfc=rfscore.mean()
print('cross val score',rfc*100)
# Out:
# cross val score 90.64475084935046

# %%
rfs=r2_score(target_test,prediction_decision)
print('r2_score is',rfs*100)
# Out:
# r2_score is 97.56040083670624

# %% [markdown]
# # Saving the model

# %%
import pickle
filename='zomato_partA.pkl'
pickle.dump(rf,open('zomato_partA.pkl','wb'))

# %% [markdown]
# # Loading the model

# %%
l_model=pickle.load(open('zomato_partA.pkl','rb'))
result=l_model.score(features_test,target_test)
print(result*100)
# Out:
# 97.56040083670624

# %% [markdown]
# # Part 2

# %% [markdown]
# # where target column is price range

# %% [markdown]
# # seperating features and the target variable

# %%
features=df.drop('Price range',axis=1)
target=df['Price range']

# %%
features
# Out:
#       Restaurant ID  Restaurant Name  Country Code  City  Address  Locality  \
# 0           6317637             3749           162    73     8685       171
# 1           6304287             3173           162    73     6055       593
# 2           6300002             2897           162    75     4684       308
# 3           6318506             4707           162    75     8690       862
# 4           6314302             5523           162    75     8689       862
# ...             ...              ...           ...   ...      ...       ...
# 9546        5915730             4443           208   140     5926       517
# 9547        5908749             1311           208   140     5962       552
# 9548        5915807             3069           208   140     5966       554
# 9549        5916112              513           208   140     5967       554
# 9550        5927402             7240           208   140     4258       670
#
# ...

# %%
target
# Out:
# 0       3
# 1       3
# 2       4
# 3       4
# 4       4
#        ..
# 9546    3
# 9547    3
# 9548    4
# 9549    4
# 9550    2
# Name: Price range, Length: 9551, dtype: int64

# %% [markdown]
# # checking skewness in Data and Removing it

# %%
features.skew()
# Out:
# Restaurant ID            0.061570
# Restaurant Name          0.044637
# Country Code             3.043965
# City                    -1.193777
# Address                 -0.040407
# Locality                -0.253550
# Locality Verbose        -0.183059
# Longitude               -2.807328
# Latitude                -3.081635
# Cuisines                -0.307425
# Average Cost for two    35.477915
# Currency                 2.858093
# Has Table booking        2.321100
# Has Online delivery      1.114620
# Is delivering now       16.673412
# Switch to order menu     0.000000
# Aggregate rating        -0.954130
# Rating color             0.046009
# Rating text              0.431408
# Votes                    8.807637
# Country                  3.312721
# dtype: float64

# %% [markdown]
# keeping -/+0.7 as the range of skewness. Here are the columns that are not in range.

# %%
from sklearn.preprocessing import power_transform

# %%
features.skew().sort_values(ascending=False)
# Out:
# Average Cost for two    35.477915
# Is delivering now       16.673412
# Votes                    8.807637
# Country                  3.312721
# Country Code             3.043965
# Currency                 2.858093
# Has Table booking        2.321100
# Has Online delivery      1.114620
# Rating text              0.431408
# Restaurant ID            0.061570
# Rating color             0.046009
# Restaurant Name          0.044637
# Switch to order menu     0.000000
# Address                 -0.040407
# Locality Verbose        -0.183059
# Locality                -0.253550
# Cuisines                -0.307425
# Aggregate rating        -0.954130
# City                    -1.193777
# Longitude               -2.807328
# Latitude                -3.081635
# dtype: float64

# %% [markdown]
# we are using YEO JOHNSON METHOD

# %%
features_n=power_transform(features,method='yeo-johnson')

# %%
pd.DataFrame(features_n,columns=features.columns).skew().sort_values(ascending=False)
# Out:
# Is delivering now       16.673412
# Country Code             2.780362
# Has Table booking        2.321100
# Has Online delivery      1.114620
# Currency                 0.448602
# Average Cost for two     0.142365
# Switch to order menu     0.000000
# Votes                   -0.004029
# Rating text             -0.059959
# Rating color            -0.103780
# City                    -0.203048
# Restaurant Name         -0.271708
# Locality Verbose        -0.279298
# Latitude                -0.293200
# Address                 -0.300427
# Locality                -0.304127
# Restaurant ID           -0.339181
# Cuisines                -0.383190
# Aggregate rating        -0.610806
# Longitude               -0.803832
# Country                 -1.341627
# dtype: float64

# %%
type(features_n)
# Out:
# numpy.ndarray

# %%
features.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Aggregate rating', 'Rating color', 'Rating text', 'Votes', 'Country'],
#       dtype='object')

# %%
features=pd.DataFrame(features_n,columns=features.columns)

# %%
features.skew().sort_values(ascending=False)
# Out:
# Is delivering now       16.673412
# Country Code             2.780362
# Has Table booking        2.321100
# Has Online delivery      1.114620
# Currency                 0.448602
# Average Cost for two     0.142365
# Switch to order menu     0.000000
# Votes                   -0.004029
# Rating text             -0.059959
# Rating color            -0.103780
# City                    -0.203048
# Restaurant Name         -0.271708
# Locality Verbose        -0.279298
# Latitude                -0.293200
# Address                 -0.300427
# Locality                -0.304127
# Restaurant ID           -0.339181
# Cuisines                -0.383190
# Aggregate rating        -0.610806
# Longitude               -0.803832
# Country                 -1.341627
# dtype: float64

# %% [markdown]
# # Training Process Begins

# %% [markdown]
# # Finding Best Random State and using min max scaler to scale the data

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
for i in range(0,100):
    features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=i)
    lr.fit(features_train,target_train)
    pre_train=lr.predict(features_train)
    pre_test=lr.predict(features_test)
    print(f"at random state {i},the train accuracy is:- {r2_score(target_train,pre_train)}")
    print(f"at random state {i},the testing accuracy is:- {r2_score(target_test,pre_test)}")
    print('\n')
# Out:
# at random state 0,the train accuracy is:- 0.6849361546756958
# at random state 0,the testing accuracy is:- 0.6667725897261622
#
#
# at random state 1,the train accuracy is:- 0.6746348360952028
# at random state 1,the testing accuracy is:- 0.7057506991858593
#
#
# at random state 2,the train accuracy is:- 0.6790513826492759
# at random state 2,the testing accuracy is:- 0.690728227981857
#
#
# at random state 3,the train accuracy is:- 0.6777287006076118
# at random state 3,the testing accuracy is:- 0.6960428401364589
#
#
# at random state 4,the train accuracy is:- 0.6750757872696168
# at random state 4,the testing accuracy is:- 0.7058655435835997
#
#
# at random state 5,the train accuracy is:- 0.6808873927428609
# at random state 5,the testing accuracy is:- 0.683349908716368
#
#
# at random state 6,the train accuracy is:- 0.679199340216861
# at random state 6,the testing accuracy is:- 0.6908065939253835
#
#
# at random state 7,the train accuracy is:- 0.6890847317185953
# ...

# %%
features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=.20,random_state=23)

# %%
features_train.shape
# Out:
# (7640, 21)

# %%
features_test.shape
# Out:
# (1911, 21)

# %%
target_train.shape
# Out:
# (7640,)

# %%
target_test.shape
# Out:
# (1911,)

# %% [markdown]
# # Linear regression

# %%
lr.fit(features_train,target_train)
# Out:
# LinearRegression()

# %%
pre_test=lr.predict(features_test)

# %%
 print(r2_score(target_test,pre_test))
# Out:
# 0.7393255867219488

# %%
pre_train=lr.predict(features_train)

# %%
print(r2_score(target_train,pre_train))
# Out:
# 0.6666715078877551

# %% [markdown]
# # KNeighborsRegressor

# %%
from sklearn.neighbors import KNeighborsRegressor
knr=KNeighborsRegressor()
knr.fit(features_train,target_train)
# Out:
# KNeighborsRegressor()

# %%
pre_test=knr.predict(features_test)

# %%
 print(r2_score(target_test,pre_test))
# Out:
# 0.6966327675929389

# %%
pre_train=knr.predict(features_train)

# %%
print(r2_score(target_train,pre_train))
# Out:
# 0.798539523920442

# %% [markdown]
# # support vector regression

# %%
from sklearn.svm import SVR
svr=SVR()
svr.fit(features_train,target_train)
# Out:
# SVR()

# %%
pre_train=svr.predict(features_test)

# %%
 print(r2_score(target_test,pre_test))
# Out:
# 0.6966327675929389

# %%
pre_train=svr.predict(features_train)

# %%
print(r2_score(target_train,pre_train))
# Out:
# 0.9140144523507753

# %% [markdown]
# # RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor(n_estimators=300)
rfr.fit(features_train,target_train)
# Out:
# RandomForestRegressor(n_estimators=300)

# %%
pre_test=rfr.predict(features_test)

# %%
 print(r2_score(target_test,pre_test))
# Out:
# 0.9836710667437616

# %%
pre_train=rfr.predict(features_train)

# %%
print(r2_score(target_train,pre_train))
# Out:
# 0.9978859115129091

# %% [markdown]
# # Among all of the above models the best one is Random forest regression so we will go with it.
# it is best as it is giving a train accuracy of - 0.9978859115129091 and test accuracy of - 0.9836710667437616

# %% [markdown]
# # Cross Validation

# %%
train_accuracy=r2_score(target_train,pre_train)
testing_accuracy=r2_score(target_test,pre_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(rfr,features,target,cv=j)
    cv_mean=cv_score.mean()
    print(f"at cross fold {j} the cv score is {cv_mean} and accuracy score for training is {train_accuracy} and accuracy score for testing is {testing_accuracy}")
    print('\n')
# Out:
# at cross fold 2 the cv score is 0.8815483595351383 and accuracy score for training is 0.9978859115129091 and accuracy score for testing is 0.9836710667437616
#
#
# at cross fold 3 the cv score is 0.8877216313869235 and accuracy score for training is 0.9978859115129091 and accuracy score for testing is 0.9836710667437616
#
#
# at cross fold 4 the cv score is 0.8927830693369695 and accuracy score for training is 0.9978859115129091 and accuracy score for testing is 0.9836710667437616
#
#
# at cross fold 5 the cv score is 0.8937626922438051 and accuracy score for training is 0.9978859115129091 and accuracy score for testing is 0.9836710667437616
#
#
# at cross fold 6 the cv score is 0.895589523257994 and accuracy score for training is 0.9978859115129091 and accuracy score for testing is 0.9836710667437616
#
#
# at cross fold 7 the cv score is 0.8965775405143747 and accuracy score for training is 0.9978859115129091 and accuracy score for testing is 0.9836710667437616
#
#
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,4))
plt.scatter(x=target_test, y=pre_test, color='r')
plt.plot(target_test,target_test,color='b')
plt.xlabel('capacity_mw',fontsize=12)
plt.ylabel('predicted capacity_mw',fontsize=12)
plt.savefig('rfr.png')
plt.show()

# %% [markdown]
# # using Gridsearch cv

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
parameters={'criterion':['mse','mae'],'max_features':['auto','sqrt','log2']}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(features_train,target_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'auto'}

# %%
rf=RandomForestRegressor(criterion='mae',max_features='auto')
rf.fit(features_train,target_train)
rf.score(features_train,target_train)
prediction_decision=rf.predict(features_test)


rfscore=cross_val_score(rf,features,target,cv=8)
rfc=rfscore.mean()
print('cross val score',rfc*100)
# Out:
# cross val score 90.36349331412315

# %%
rfs=r2_score(target_test,prediction_decision)
print('r2_score is',rfs*100)
# Out:
# r2_score is 97.58714278425904

# %% [markdown]
# # saving the model

# %%
import pickle
filename='zomato_partB.pkl'
pickle.dump(rf,open('zomato_partB.pkl','wb'))

# %% [markdown]
# # Loading the model

# %%
l_model=pickle.load(open('zomato_partB.pkl','rb'))
result=l_model.score(features_test,target_test)
print(result*100)
# Out:
# 97.56040083670624
