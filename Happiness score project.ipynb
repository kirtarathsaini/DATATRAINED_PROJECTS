# %% [markdown]
# # WORLD HAPINESS SCORE PROJECT

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# 3                     0.88521  0.66973                        0.36503
# 4                     0.90563  0.63297                        0.32957
# ..                        ...      ...                            ...
# 153                   0.42864  0.59201                        0.55191
# 154                   0.31910  0.48450                        0.08010
# 155                   0.72193  0.15684                        0.18906
# 156                   0.22396  0.11850                        0.10062
# 157                   0.28443  0.36453                        0.10731
#
#      Generosity  Dystopia Residual
# 0       0.29678            2.51738
# 1       0.43630            2.70201
# 2       0.34139            2.49204
# 3       0.34699            2.46531
# 4       0.45811            2.45176
# ..          ...                ...
# 153     0.22628            0.67042
# 154     0.18260            1.63328
# 155     0.47179            0.32858
# 156     0.19727            1.83302
# 157     0.16681            1.56726
#
# [158 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
# ABOUT THE COLUMNS
#
# 1.COUNTRY- This shows the country name.
#
# 2.REGION- This shows the region in the country.
#
# 3.HAPPINESS RANK- This is the rank for the happiness.
#
# 4.HAPPINESS SCORE- This is the score of happiness.
#
# 5.STANDARD ERROR- This shows the standard error.
#
# 6.ECONOMY(GDP PER CAPITA)- This shows the economy rate (GDP per capita).
#
# 7.FAMILY- This column show the family.
#
# 8.HEALTH (LIFE EXPECTANCY)-This column shows the expectancy of life.
#
# 9.FREEDOM-This shows the freedom of the idividual.
#
# 10.TRUST (GOVERNMENT CORRUPTION)- This shows the trust on the government.
#
# 11.GENEROSITY-This column show the generosity.
#
# 12.DYSTOPIA RESIDUAL-This column show the residual rate

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
df.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# 154                   0.31910  0.48450                        0.08010
# 155                   0.72193  0.15684                        0.18906
# 156                   0.22396  0.11850                        0.10062
# 157                   0.28443  0.36453                        0.10731
#
#      Generosity  Dystopia Residual
# 153     0.22628            0.67042
# 154     0.18260            1.63328
# 155     0.47179            0.32858
# 156     0.19727            1.83302
# 157     0.16681            1.56726

# %%
df.sample()
# Out:
#                Country                       Region  Happiness Rank  \
# 97  Dominican Republic  Latin America and Caribbean              98
#
#     Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 97            4.885         0.07446                   0.89537  1.17202
#
#     Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 97                   0.66825  0.57672                        0.14234
#
#     Generosity  Dystopia Residual
# 97     0.21684            1.21305

# %% [markdown]
# # Checking for the null values in the dataset

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# # Visualization of the data

# %%
import seaborn as sns

# %%
sns.scatterplot(x='Happiness Rank',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Happiness Rank', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Standard Error',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Standard Error', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Economy (GDP per Capita)',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Family',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Health (Life Expectancy)',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Freedom',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Trust (Government Corruption)',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Generosity',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Happiness Score'>

# %%
sns.scatterplot(x='Dystopia Residual',y='Happiness Score',data=df)
# Out:
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Happiness Score'>

# %% [markdown]
# # Checking the distribution of continuous value of the float data type columns.

# %%
sns.displot(df['Happiness Score'],kde=True)

# %%
import matplotlib.pyplot as plt
sns.pairplot(df)
plt.savefig('pairplot.png')
plt.show()

# %% [markdown]
# # Encoding the data

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
en=OrdinalEncoder()

# %%
for i in df.columns:
    if df[i].dtype=='object':
        df[i]=en.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      135.0     9.0               1            7.587         0.03411
# 1       58.0     9.0               2            7.561         0.04884
# 2       37.0     9.0               3            7.527         0.03328
# 3      105.0     9.0               4            7.522         0.03880
# 4       24.0     5.0               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 153    118.0     8.0             154            3.465         0.03464
# 154     13.0     8.0             155            3.340         0.03656
# 155    136.0     4.0             156            3.006         0.05015
# 156     21.0     8.0             157            2.905         0.08658
# 157    141.0     8.0             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# 3                     1.45900  1.33095                   0.88521  0.66973
# 4                     1.32629  1.32261                   0.90563  0.63297
# ..                        ...      ...                       ...      ...
# 153                   0.22208  0.77370                   0.42864  0.59201
# 154                   0.28665  0.35386                   0.31910  0.48450
# 155                   0.66320  0.47489                   0.72193  0.15684
# 156                   0.01530  0.41587                   0.22396  0.11850
# 157                   0.20868  0.13995                   0.28443  0.36453
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                          0.41978     0.29678            2.51738
# 1                          0.14145     0.43630            2.70201
# 2                          0.48357     0.34139            2.49204
# 3                          0.36503     0.34699            2.46531
# 4                          0.32957     0.45811            2.45176
# ..                             ...         ...                ...
# 153                        0.55191     0.22628            0.67042
# 154                        0.08010     0.18260            1.63328
# 155                        0.18906     0.47179            0.32858
# 156                        0.10062     0.19727            1.83302
# 157                        0.10731     0.16681            1.56726
#
# [158 rows x 12 columns]

# %% [markdown]
# # Describing The Data

# %%
df.describe()
# Out:
#           Country      Region  Happiness Rank  Happiness Score  \
# count  158.000000  158.000000      158.000000       158.000000
# mean    78.500000    5.120253       79.493671         5.375734
# std     45.754781    2.993321       45.754363         1.145010
# min      0.000000    0.000000        1.000000         2.839000
# 25%     39.250000    3.000000       40.250000         4.526000
# 50%     78.500000    4.500000       79.500000         5.232500
# 75%    117.750000    8.000000      118.750000         6.243750
# max    157.000000    9.000000      158.000000         7.587000
#
#        Standard Error  Economy (GDP per Capita)      Family  \
# count      158.000000                158.000000  158.000000
# mean         0.047885                  0.846137    0.991046
# std          0.017146                  0.403121    0.272369
# min          0.018480                  0.000000    0.000000
# 25%          0.037268                  0.545808    0.856823
# 50%          0.043940                  0.910245    1.029510
# 75%          0.052300                  1.158448    1.214405
# max          0.136930                  1.690420    1.402230
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                158.000000  158.000000                     158.000000
# mean                   0.630259    0.428615                       0.143422
# std                    0.247078    0.150693                       0.120034
# min                    0.000000    0.000000                       0.000000
# 25%                    0.439185    0.328330                       0.061675
# 50%                    0.696705    0.435515                       0.107220
# 75%                    0.811013    0.549092                       0.180255
# max                    1.025250    0.669730                       0.551910
#
#        Generosity  Dystopia Residual
# count  158.000000         158.000000
# mean     0.237296           2.098977
# std      0.126685           0.553550
# min      0.000000           0.328580
# 25%      0.150553           1.759410
# 50%      0.216130           2.095415
# 75%      0.309883           2.462415
# max      0.795880           3.602140

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(df.describe(),annot=True,linewidths=2,linecolor='Black',fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Checking correlation of columns with the target variable.

# %%
df.corr()['Happiness Score'].sort_values()
# Out:
# Happiness Rank                  -0.992105
# Standard Error                  -0.177254
# Region                          -0.176791
# Country                          0.083380
# Generosity                       0.180319
# Trust (Government Corruption)    0.395199
# Dystopia Residual                0.530474
# Freedom                          0.568211
# Health (Life Expectancy)         0.724200
# Family                           0.740605
# Economy (GDP per Capita)         0.780966
# Happiness Score                  1.000000
# Name: Happiness Score, dtype: float64

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),annot=True,linewidths=2,linecolor='Black',fmt='0.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # checking the columns which are positively and negatively correlated to the target variable.

# %%
plt.figure(figsize=(10,8))
df.corr()['Happiness Score'].sort_values(ascending=False).drop(['Happiness Score']).plot(kind='bar',color='c')
plt.xlabel('features',fontsize=12)
plt.ylabel('column with target names',fontsize=12)
plt.show()

# %% [markdown]
# THIS DIAGRAM REPRESENTS THE CORRELATION

# %%
df.corr()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,12))
sns.heatmap(df.corr(),annot=True,linewidths=2,linecolor='Black',fmt='.2f')

# %%
df.corr()['Happiness Score'].sort_values()

# %% [markdown]
# # Outliers Checking

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
collist=df.columns.values
ncol=30
nrow=14

# %%
collist
# Out:
# array(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom',
#        'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual'],
#       dtype=object)

# %%
for i in range(0,len(collist)):
    print(collist[i])
    break
# Out:
# Country

# %%
plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(data = df[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %% [markdown]
# # Removing Outliers

# %%
from sklearn import preprocessing

# %%
le= preprocessing.LabelEncoder()

# %%
df['Country']= le.fit_transform(df['Country'])

# %%
df['Region']= le.fit_transform(df['Region'])

# %% [markdown]
# zscore Technique

# %%
from scipy.stats import zscore

# %%
import numpy as np
z=np.abs(zscore(df))
threshold=3
np.where(z>3)
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64),
#  array([ 9,  4,  4,  4, 10,  6,  9, 11,  6], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df_new
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      135.0     9.0               1            7.587         0.03411
# 1       58.0     9.0               2            7.561         0.04884
# 2       37.0     9.0               3            7.527         0.03328
# 3      105.0     9.0               4            7.522         0.03880
# 4       24.0     5.0               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 150     66.0     8.0             151            3.655         0.05141
# 151     20.0     8.0             152            3.587         0.04324
# 152      0.0     7.0             153            3.575         0.03084
# 154     13.0     8.0             155            3.340         0.03656
# 156     21.0     8.0             157            2.905         0.08658
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# 3                     1.45900  1.33095                   0.88521  0.66973
# 4                     1.32629  1.32261                   0.90563  0.63297
# ..                        ...      ...                       ...      ...
# 150                   0.46534  0.77115                   0.15185  0.46866
# 151                   0.25812  0.85188                   0.27125  0.39493
# 152                   0.31982  0.30285                   0.30335  0.23414
# 154                   0.28665  0.35386                   0.31910  0.48450
# 156                   0.01530  0.41587                   0.22396  0.11850
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                          0.41978     0.29678            2.51738
# 1                          0.14145     0.43630            2.70201
# 2                          0.48357     0.34139            2.49204
# 3                          0.36503     0.34699            2.46531
# 4                          0.32957     0.45811            2.45176
# ..                             ...         ...                ...
# 150                        0.17922     0.20165            1.41723
# 151                        0.12832     0.21747            1.46494
# 152                        0.09719     0.36510            1.95210
# 154                        0.08010     0.18260            1.63328
# 156                        0.10062     0.19727            1.83302
#
# [149 rows x 12 columns]

# %%
df_new.shape
# Out:
# (149, 12)

# %%
data_loss=((158-149)/158)*100

# %%
data_loss
# Out:
# 5.69620253164557

# %% [markdown]
# This is the percentage of data lost

# %% [markdown]
# # seperating features and the target variable

# %%
fea=df_new.drop('Happiness Score',axis=1)
target=df_new['Happiness Score']

# %% [markdown]
# # Checking and Removing Skewness

# %%
df_new.skew()
# Out:
# Country                          0.048701
# Region                          -0.096985
# Happiness Rank                   0.003268
# Happiness Score                  0.169740
# Standard Error                   1.243048
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)    1.272530
# Generosity                       0.654710
# Dystopia Residual               -0.021144
# dtype: float64

# %% [markdown]
# keeping -/+0.5 as the range of skewness. Here are the columns that are not in range.

# %% [markdown]
# standard error,  family , health,  trust,  generosity

# %%
from sklearn.preprocessing import power_transform

# %%
fea=power_transform(fea,method='yeo-johnson')

# %%
type(fea)
# Out:
# numpy.ndarray

# %%
fea
# Out:
# array([[ 1.19015533,  1.23451354, -2.05151352, ...,  1.81762514,
#          0.65957855,  0.75525527],
#        [-0.30048669,  1.23451354, -1.99584442, ...,  0.32967608,
#          1.56260401,  1.11116834],
#        [-0.80205671,  1.23451354, -1.94524081, ...,  1.95339957,
#          0.97722591,  0.70649452],
#        ...,
#        [-2.10537769,  0.66673577,  1.53128908, ..., -0.19284339,
#          1.13425805, -0.32711524],
#        [-1.50728158,  0.95527966,  1.56626337, ..., -0.4344978 ,
#         -0.31207994, -0.93216364],
#        [-1.24683102,  0.95527966,  1.60111233, ..., -0.14727363,
#         -0.17248608, -0.55359236]])

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
fea=sc.fit_transform(fea)
fea
# Out:
# array([[ 1.19015533,  1.23451354, -2.05151352, ...,  1.81762514,
#          0.65957855,  0.75525527],
#        [-0.30048669,  1.23451354, -1.99584442, ...,  0.32967608,
#          1.56260401,  1.11116834],
#        [-0.80205671,  1.23451354, -1.94524081, ...,  1.95339957,
#          0.97722591,  0.70649452],
#        ...,
#        [-2.10537769,  0.66673577,  1.53128908, ..., -0.19284339,
#          1.13425805, -0.32711524],
#        [-1.50728158,  0.95527966,  1.56626337, ..., -0.4344978 ,
#         -0.31207994, -0.93216364],
#        [-1.24683102,  0.95527966,  1.60111233, ..., -0.14727363,
#         -0.17248608, -0.55359236]])

# %%
fea.mean()
# Out:
# 4.3352210845643695e-18

# %% [markdown]
# # scaling the data using min max scaler

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
for i in range(0,100):
    fea_train,fea_test,target_train,target_test=train_test_split(fea,target,test_size=0.2,random_state=i)
    lr.fit(fea_train,target_train)
    pre_train=lr.predict(fea_train)
    pre_test=lr.predict(fea_test)
    print(f"at random state {i},the train accuracy is:- {r2_score(target_train,pre_train)}")
    print(f"at random state {i},the testing accuracy is:- {r2_score(target_test,pre_test)}")
    print('\n')
# Out:
# at random state 0,the train accuracy is:- 0.9999999454677223
# at random state 0,the testing accuracy is:- 0.9999999093841863
#
#
# at random state 1,the train accuracy is:- 0.9999999497788292
# at random state 1,the testing accuracy is:- 0.9999998755448307
#
#
# at random state 2,the train accuracy is:- 0.999999940934475
# at random state 2,the testing accuracy is:- 0.9999999371380033
#
#
# at random state 3,the train accuracy is:- 0.9999999432132397
# at random state 3,the testing accuracy is:- 0.9999999189560377
#
#
# at random state 4,the train accuracy is:- 0.9999999335939884
# at random state 4,the testing accuracy is:- 0.9999999420153396
#
#
# at random state 5,the train accuracy is:- 0.9999999408288874
# at random state 5,the testing accuracy is:- 0.9999999329317109
#
#
# at random state 6,the train accuracy is:- 0.9999999433598739
# at random state 6,the testing accuracy is:- 0.999999916471231
#
#
# at random state 7,the train accuracy is:- 0.9999999521511279
# at random state 7,the testing accuracy is:- 0.9999998379701049
#
#
# at random state 8,the train accuracy is:- 0.9999999305587308
# at random state 8,the testing accuracy is:- 0.9999999604368777
#
#
# at random state 9,the train accuracy is:- 0.9999999411779302
# at random state 9,the testing accuracy is:- 0.9999999253265285
#
#
# at random state 10,the train accuracy is:- 0.9999999421922693
# at random state 10,the testing accuracy is:- 0.9999999285083104
#
#
# at random state 11,the train accuracy is:- 0.9999999402742119
# at random state 11,the testing accuracy is:- 0.9999999359291699
#
#
# at random state 12,the train accuracy is:- 0.9999999361623357
# at random state 12,the testing accuracy is:- 0.9999999506363709
#
#
# at random state 13,the train accuracy is:- 0.9999999396784608
# at random state 13,the testing accuracy is:- 0.9999999339124287
#
#
# at random state 14,the train accuracy is:- 0.9999999400617491
# at random state 14,the testing accuracy is:- 0.999999927545932
#
#
# at random state 15,the train accuracy is:- 0.999999948634049
# at random state 15,the testing accuracy is:- 0.999999893401467
#
#
# at random state 16,the train accuracy is:- 0.9999999428750983
# at random state 16,the testing accuracy is:- 0.9999999254754207
#
#
# at random state 17,the train accuracy is:- 0.9999999414966384
# at random state 17,the testing accuracy is:- 0.9999999322800228
#
#
# at random state 18,the train accuracy is:- 0.9999999442273033
# at random state 18,the testing accuracy is:- 0.9999999187610299
#
#
# at random state 19,the train accuracy is:- 0.9999999407825173
# at random state 19,the testing accuracy is:- 0.9999999302569997
#
#
# at random state 20,the train accuracy is:- 0.9999999472004075
# at random state 20,the testing accuracy is:- 0.9999998985157085
#
#
# at random state 21,the train accuracy is:- 0.9999999432022696
# at random state 21,the testing accuracy is:- 0.9999999245319069
#
#
# at random state 22,the train accuracy is:- 0.9999999413153224
# at random state 22,the testing accuracy is:- 0.9999999133789799
#
#
# at random state 23,the train accuracy is:- 0.9999999411876086
# at random state 23,the testing accuracy is:- 0.9999999330104828
#
#
# at random state 24,the train accuracy is:- 0.999999949304489
# at random state 24,the testing accuracy is:- 0.9999998853042338
#
#
# at random state 25,the train accuracy is:- 0.99999994414152
# at random state 25,the testing accuracy is:- 0.9999999157352926
#
#
# at random state 26,the train accuracy is:- 0.9999999379045361
# at random state 26,the testing accuracy is:- 0.99999994289454
#
#
# at random state 27,the train accuracy is:- 0.9999999413245695
# at random state 27,the testing accuracy is:- 0.9999999245968082
#
#
# at random state 28,the train accuracy is:- 0.9999999444126721
# at random state 28,the testing accuracy is:- 0.999999916260653
#
#
# at random state 29,the train accuracy is:- 0.9999999427829299
# at random state 29,the testing accuracy is:- 0.9999999112142685
#
#
# at random state 30,the train accuracy is:- 0.9999999327817197
# at random state 30,the testing accuracy is:- 0.999999951636796
#
#
# at random state 31,the train accuracy is:- 0.9999999408831132
# at random state 31,the testing accuracy is:- 0.9999999365022174
#
#
# at random state 32,the train accuracy is:- 0.999999937384107
# at random state 32,the testing accuracy is:- 0.999999947486291
#
#
# at random state 33,the train accuracy is:- 0.9999999391164633
# at random state 33,the testing accuracy is:- 0.9999999320329601
#
#
# at random state 34,the train accuracy is:- 0.999999946116997
# at random state 34,the testing accuracy is:- 0.9999998812654327
#
#
# at random state 35,the train accuracy is:- 0.999999943598976
# at random state 35,the testing accuracy is:- 0.9999999221036755
#
#
# at random state 36,the train accuracy is:- 0.9999999438089047
# at random state 36,the testing accuracy is:- 0.9999999181212651
#
#
# at random state 37,the train accuracy is:- 0.9999999350563741
# at random state 37,the testing accuracy is:- 0.9999999513782676
#
#
# at random state 38,the train accuracy is:- 0.9999999465937033
# at random state 38,the testing accuracy is:- 0.9999998948465355
#
#
# at random state 39,the train accuracy is:- 0.9999999391800178
# at random state 39,the testing accuracy is:- 0.9999999396391722
#
#
# at random state 40,the train accuracy is:- 0.999999942425381
# at random state 40,the testing accuracy is:- 0.9999999216895935
#
#
# at random state 41,the train accuracy is:- 0.9999999421958405
# at random state 41,the testing accuracy is:- 0.9999999195787539
#
#
# at random state 42,the train accuracy is:- 0.9999999401162106
# at random state 42,the testing accuracy is:- 0.9999999400614117
#
#
# at random state 43,the train accuracy is:- 0.9999999420566921
# at random state 43,the testing accuracy is:- 0.9999999136113347
#
#
# at random state 44,the train accuracy is:- 0.999999939560782
# at random state 44,the testing accuracy is:- 0.9999999360863902
#
#
# at random state 45,the train accuracy is:- 0.9999999427810349
# at random state 45,the testing accuracy is:- 0.9999999252364407
#
#
# at random state 46,the train accuracy is:- 0.999999940204658
# at random state 46,the testing accuracy is:- 0.999999933866378
#
#
# at random state 47,the train accuracy is:- 0.9999999381887441
# at random state 47,the testing accuracy is:- 0.9999999383084985
#
#
# at random state 48,the train accuracy is:- 0.9999999447822909
# at random state 48,the testing accuracy is:- 0.9999999162906592
#
#
# at random state 49,the train accuracy is:- 0.9999999439987964
# at random state 49,the testing accuracy is:- 0.9999999150080845
#
#
# at random state 50,the train accuracy is:- 0.9999999459873735
# at random state 50,the testing accuracy is:- 0.9999999123223636
#
#
# at random state 51,the train accuracy is:- 0.9999999436465813
# at random state 51,the testing accuracy is:- 0.9999999157046682
#
#
# at random state 52,the train accuracy is:- 0.9999999486596831
# at random state 52,the testing accuracy is:- 0.9999998882304003
#
#
# at random state 53,the train accuracy is:- 0.9999999430645443
# at random state 53,the testing accuracy is:- 0.9999999198431683
#
#
# at random state 54,the train accuracy is:- 0.999999941631875
# at random state 54,the testing accuracy is:- 0.9999999267829615
#
#
# at random state 55,the train accuracy is:- 0.999999941979333
# at random state 55,the testing accuracy is:- 0.9999999188328181
#
#
# at random state 56,the train accuracy is:- 0.9999999440277112
# at random state 56,the testing accuracy is:- 0.9999999109921965
#
#
# at random state 57,the train accuracy is:- 0.9999999482841173
# at random state 57,the testing accuracy is:- 0.9999998844061275
#
#
# at random state 58,the train accuracy is:- 0.9999999465200028
# at random state 58,the testing accuracy is:- 0.9999999008172838
#
#
# at random state 59,the train accuracy is:- 0.9999999432232897
# at random state 59,the testing accuracy is:- 0.9999999206505862
#
#
# at random state 60,the train accuracy is:- 0.9999999403553478
# at random state 60,the testing accuracy is:- 0.9999999285097976
#
#
# at random state 61,the train accuracy is:- 0.9999999410688752
# at random state 61,the testing accuracy is:- 0.9999999260299872
#
#
# at random state 62,the train accuracy is:- 0.9999999432439075
# at random state 62,the testing accuracy is:- 0.9999999185067121
#
#
# at random state 63,the train accuracy is:- 0.9999999479977956
# at random state 63,the testing accuracy is:- 0.9999998748760365
#
#
# at random state 64,the train accuracy is:- 0.9999999428532
# at random state 64,the testing accuracy is:- 0.9999999247572884
#
#
# at random state 65,the train accuracy is:- 0.9999999415223225
# at random state 65,the testing accuracy is:- 0.9999999344728072
#
#
# at random state 66,the train accuracy is:- 0.999999944409476
# at random state 66,the testing accuracy is:- 0.9999999146484793
#
#
# at random state 67,the train accuracy is:- 0.9999999436766949
# at random state 67,the testing accuracy is:- 0.9999999164009672
#
#
# at random state 68,the train accuracy is:- 0.9999999406981068
# at random state 68,the testing accuracy is:- 0.9999999293723122
#
#
# at random state 69,the train accuracy is:- 0.9999999444440817
# at random state 69,the testing accuracy is:- 0.9999999207065503
#
#
# at random state 70,the train accuracy is:- 0.999999941779493
# at random state 70,the testing accuracy is:- 0.999999928159845
#
#
# at random state 71,the train accuracy is:- 0.999999941664025
# at random state 71,the testing accuracy is:- 0.9999999275327214
#
#
# at random state 72,the train accuracy is:- 0.999999930877945
# at random state 72,the testing accuracy is:- 0.999999957078408
#
#
# at random state 73,the train accuracy is:- 0.9999999419186415
# at random state 73,the testing accuracy is:- 0.9999999317658054
#
#
# at random state 74,the train accuracy is:- 0.9999999403437404
# at random state 74,the testing accuracy is:- 0.9999999360843024
#
#
# at random state 75,the train accuracy is:- 0.9999999471607023
# at random state 75,the testing accuracy is:- 0.9999998851366355
#
#
# at random state 76,the train accuracy is:- 0.9999999426066676
# at random state 76,the testing accuracy is:- 0.9999999105831863
#
#
# at random state 77,the train accuracy is:- 0.9999999431447891
# at random state 77,the testing accuracy is:- 0.9999999206218623
#
#
# at random state 78,the train accuracy is:- 0.9999999492553034
# at random state 78,the testing accuracy is:- 0.9999998810732502
#
#
# at random state 79,the train accuracy is:- 0.9999999437144333
# at random state 79,the testing accuracy is:- 0.9999999212590945
#
#
# at random state 80,the train accuracy is:- 0.9999999411600322
# at random state 80,the testing accuracy is:- 0.9999999172853548
#
#
# at random state 81,the train accuracy is:- 0.9999999430667008
# at random state 81,the testing accuracy is:- 0.999999915633119
#
#
# at random state 82,the train accuracy is:- 0.9999999428712573
# at random state 82,the testing accuracy is:- 0.9999999219955237
#
#
# at random state 83,the train accuracy is:- 0.9999999457398362
# at random state 83,the testing accuracy is:- 0.9999999076334701
#
#
# at random state 84,the train accuracy is:- 0.9999999417972654
# at random state 84,the testing accuracy is:- 0.99999993007017
#
#
# at random state 85,the train accuracy is:- 0.9999999395540234
# at random state 85,the testing accuracy is:- 0.9999999350893278
#
#
# at random state 86,the train accuracy is:- 0.9999999438966909
# at random state 86,the testing accuracy is:- 0.9999999159888974
#
#
# at random state 87,the train accuracy is:- 0.9999999398456534
# at random state 87,the testing accuracy is:- 0.9999999312622784
#
#
# at random state 88,the train accuracy is:- 0.9999999470421065
# at random state 88,the testing accuracy is:- 0.9999999018052083
#
#
# at random state 89,the train accuracy is:- 0.9999999455575241
# at random state 89,the testing accuracy is:- 0.9999999136773013
#
#
# at random state 90,the train accuracy is:- 0.9999999453335224
# at random state 90,the testing accuracy is:- 0.9999999073051826
#
#
# at random state 91,the train accuracy is:- 0.9999999453993744
# at random state 91,the testing accuracy is:- 0.9999999021730466
#
#
# at random state 92,the train accuracy is:- 0.9999999392149532
# at random state 92,the testing accuracy is:- 0.9999999410175541
#
#
# at random state 93,the train accuracy is:- 0.9999999409072807
# at random state 93,the testing accuracy is:- 0.9999999345315717
#
#
# at random state 94,the train accuracy is:- 0.9999999437870629
# at random state 94,the testing accuracy is:- 0.9999999092032007
#
#
# at random state 95,the train accuracy is:- 0.9999999422041329
# at random state 95,the testing accuracy is:- 0.9999999250438787
#
#
# at random state 96,the train accuracy is:- 0.9999999405163108
# at random state 96,the testing accuracy is:- 0.999999927652776
#
#
# at random state 97,the train accuracy is:- 0.9999999387940601
# at random state 97,the testing accuracy is:- 0.9999999416702302
#
#
# at random state 98,the train accuracy is:- 0.999999945724357
# at random state 98,the testing accuracy is:- 0.9999999045040393
#
#
# at random state 99,the train accuracy is:- 0.9999999413335661
# at random state 99,the testing accuracy is:- 0.999999934735816

# %%
fea_train,fea_test,target_train,target_test=train_test_split(fea,target,test_size=0.2,random_state=12)

# %%
lr.fit(fea_train,target_train)
# Out:
# LinearRegression()

# %% [markdown]
# test accuracy

# %%
pre_test=lr.predict(fea_test)

# %%
 print(r2_score(target_test,pre_test))
# Out:
# 0.99624175531855

# %% [markdown]
# train accuracy

# %%
 pre_train=lr.predict(fea_train)

# %%
print(r2_score(target_train,pre_train))
# Out:
# 0.99605454085184

# %%
train_accuracy=r2_score(target_train,pre_train)
testing_accuracy=r2_score(target_test,pre_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,fea,target,cv=j)
    cv_mean=cv_score.mean()
    print(f"at cross fold {j} the cv score is {cv_mean} and accuracy score for training is {train_accuracy} and accuracy score for testing is {testing_accuracy}")
    print('\n')
# Out:
# at cross fold 2 the cv score is 0.9116984620964795 and accuracy score for training is 0.99605454085184 and accuracy score for testing is 0.99624175531855
#
#
# at cross fold 3 the cv score is 0.9323146659570161 and accuracy score for training is 0.99605454085184 and accuracy score for testing is 0.99624175531855
#
#
# at cross fold 4 the cv score is 0.8915810083837662 and accuracy score for training is 0.99605454085184 and accuracy score for testing is 0.99624175531855
#
#
# at cross fold 5 the cv score is 0.8614358838761487 and accuracy score for training is 0.99605454085184 and accuracy score for testing is 0.99624175531855
#
#
# at cross fold 6 the cv score is 0.7967102693799628 and accuracy score for training is 0.99605454085184 and accuracy score for testing is 0.99624175531855
#
#
# at cross fold 7 the cv score is 0.7130860801644534 and accuracy score for training is 0.99605454085184 and accuracy score for testing is 0.99624175531855
#
#
# at cross fold 8 the cv score is 0.685661895783567 and accuracy score for training is 0.99605454085184 and accuracy score for testing is 0.99624175531855
#
#
# at cross fold 9 the cv score is 0.6379138800711063 and accuracy score for training is 0.99605454085184 and accuracy score for testing is 0.99624175531855

# %% [markdown]
# since the number of fold don't have such impact on accuracy and cv score so cv=3 is selected.

# %% [markdown]
# we have to handle the problem of overfitting and underfitting by checking training and testing score.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,4))
plt.scatter(x=target_test, y=pre_test, color='r')
plt.plot(target_test,target_test,color='b')
plt.xlabel('actual charges',fontsize=12)
plt.ylabel('predict charges',fontsize=12)
plt.savefig('lr.png')
plt.show()

# %% [markdown]
# this is the LINEAR REGRESSION

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import Lasso
parameters ={'alpha':[.0001,.001,.01,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf = GridSearchCV(ls,parameters)
clf.fit(fea_train,target_train)
print(clf.best_params_)
# Out:
# {'alpha': 0.0001, 'random_state': 0}

# %% [markdown]
# # final model training

# %%
ls=Lasso(alpha=1,random_state=0)
ls.fit(fea_train,target_train)
ls_score_training=ls.score(fea_train,target_train)
pred_ls=ls.predict(fea_test)
ls_score_training*100
# Out:
# 9.68764818383968

# %%
pred_ls=ls.predict(fea_test)

# %%
lss=r2_score(target_test,pred_ls)
lss*100
# Out:
# 9.243886402195034

# %%
cv_score=cross_val_score(ls,fea,target,cv=6)
cv_mean=cv_score.mean()
cv_mean*100
# Out:
# -2572.3580782806625

# %% [markdown]
# # ensemble technique

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
parameters={'criterion':['mse','mae'],'max_features':['auto','sqrt','log2']}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(fea_train,target_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'auto'}

# %%
rf=RandomForestRegressor(criterion='mae',max_features='auto')
rf.fit(fea_train,target_train)
rf.score(fea_train,target_train)
prediction_decision=rf.predict(fea_test)

rfs=r2(target_test,prediction_decision)
print('r2_score is'rfs*100)

rfscore=cross_val_score(rf,feature,target,cv=6)
rfc=rfscore.mean()
print('cross val score'rfc*100)
# Out:
#   File "C:\Users\HP\AppData\Local\Temp/ipykernel_29280/3528679050.py", line 7
#     print('r2_score is'rfs*100)
#                        ^
# SyntaxError: invalid syntax

# %%
import pickle
filename='salary.pkl'
pickle.dump(rf,open(filename,'wb'))

# %%
l_model=pickle.load(open('salary.pkl','rb'))
result=l_model.score(fea_test,target_test)
print(result*100)
