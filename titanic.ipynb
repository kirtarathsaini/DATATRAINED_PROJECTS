# %% [markdown]
# # TITANIC PROJECT

# %%
import pandas as pd

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset1/master/titanic_train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# Input variables:
#
# 1 - PassangerID- This tells the passanger id.
#
# 2 - Survived- This tells wether the passanger survived or not (target columns).
#
# 3 - Pclass- This tells the class of the passangers.
#
# 4 - Name- This tells the name of the passanger.
#
# 5 - Sex- this tells the sex of the passanger.
#
# 6.- Age- age of the passangers.
#
# 7.- SibSp - this shows the sibsp of the passangers.
#
# 8.- parch - this shows the parch of the passengers.
#
# 9.- ticket- this shows the details of the tickets of the passangers.
#
# 10.- fare - this shows the fare of the ticket .
#
# 11.- cabin- this shows the cabin no. of the passangers.
#
# 12.- embarked- this shows from where the passenger embarked.

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.sample()
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 281          282         0       3  Olsson, Mr. Nils Johan Goransson  male
#
#       Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 281  28.0      0      0  347464  7.8542   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# # checking duplicate values in the table

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# there are total 0 duplicate values present in the table.

# %% [markdown]
# # Checking for the unique values.

# %%
df['PassengerId'].nunique()
# Out:
# 891

# %%
df['Survived'].nunique()
# Out:
# 2

# %%
df['Pclass'].nunique()
# Out:
# 3

# %%
df['Name'].nunique()
# Out:
# 891

# %%
df['Sex'].nunique()
# Out:
# 2

# %%
df['Age'].nunique()
# Out:
# 88

# %%
df['SibSp'].nunique()
# Out:
# 7

# %%
df['Parch'].nunique()
# Out:
# 7

# %%
df['Ticket'].nunique()
# Out:
# 681

# %%
df['Fare'].nunique()
# Out:
# 248

# %%
df['Cabin'].nunique()
# Out:
# 147

# %%
df['Embarked'].nunique()
# Out:
# 3

# %% [markdown]
# # Checking for the Null Values

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
sns.heatmap(df.isnull())
plt.title('null values')
# Out:
# Text(0.5, 1.0, 'null values')

# %% [markdown]
# since we can see in the heatmap we have null values present in the data so we'll be treating them

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # Treating null values

# %% [markdown]
# Dropping  the “Cabin” column from the data set as it won’t be of much importance

# %%
df = df.drop(columns='Cabin', axis=1)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Replacing the missing values in the “Age” column with the mean value

# %%
df['Age']=df['Age'].astype(float)

# %%
df.Age.dtypes
# Out:
# dtype('float64')

# %%
import numpy as np

# %%
np.mean(df['Age'])
# Out:
# 29.69911764705882

# %%
df['Age'].fillna(df['Age'].mean(), inplace=True)

# %% [markdown]
# Finding the mode value of the “Embarked” column as it will have occurred the maximum number of times

# %%
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
sns.heatmap(df.isnull())
plt.title('null values')
# Out:
# Text(0.5, 1.0, 'null values')

# %% [markdown]
# Now we can see that the null values or columns has been treated.

# %% [markdown]
# # EDA

# %% [markdown]
# # Visualization Of The Data

# %% [markdown]
# # 1 pairplot

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
sns.pairplot(df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # 2 histogram

# %%
df.hist(bins=10,figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'PassengerId'}>,
#         <AxesSubplot:title={'center':'Survived'}>,
#         <AxesSubplot:title={'center':'Pclass'}>],
#        [<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'SibSp'}>,
#         <AxesSubplot:title={'center':'Parch'}>],
#        [<AxesSubplot:title={'center':'Fare'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# # 3- scatterplot

# %%
sns.scatterplot(x='Pclass',y='Survived',data=df)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Survived'>

# %%
sns.scatterplot(x='Age',y='Survived',data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Survived'>

# %%
sns.scatterplot(x='SibSp',y='Survived',data=df)
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='Survived'>

# %%
sns.scatterplot(x='Parch',y='Survived',data=df)
# Out:
# <AxesSubplot:xlabel='Parch', ylabel='Survived'>

# %%
sns.scatterplot(x='Fare',y='Survived',data=df)
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Survived'>

# %% [markdown]
# # 4- countplot

# %%
sns.countplot(x='Sex',data=df)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %% [markdown]
# count of males were more on the ship as compared to females

# %%
sns.countplot(x='Pclass',data=df)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %% [markdown]
#  this shows people from 3rd class were more followed by 1st class then 2nd class

# %%
sns.countplot(x='Age',data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
sns.countplot(x='SibSp',data=df)
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='count'>

# %%
sns.countplot(x='Parch',data=df)
# Out:
# <AxesSubplot:xlabel='Parch', ylabel='count'>

# %%
sns.countplot(x='Fare',data=df)
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='count'>

# %%
sns.countplot(x='Embarked',data=df)
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='count'>

# %% [markdown]
# this shows that more people embarked from s then from c then from q

# %% [markdown]
# # 5 - barplot

# %%
sns.barplot(x='Sex',y='Survived',data=df)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Survived'>

# %% [markdown]
# this shows feamales that survived were more than males on the ship

# %%
sns.barplot(x='Pclass',y='Survived',data=df)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Survived'>

# %% [markdown]
# this shows people in class 1 servived more than other classes

# %%
sns.barplot(x='Age',y='Survived',data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Survived'>

# %%
sns.barplot(x='SibSp',y='Survived',data=df)
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='Survived'>

# %% [markdown]
# this shows sibsp of 2 servived is the highest and for th 4th one is the lowest.

# %%
sns.barplot(x='Parch',y='Survived',data=df)
# Out:
# <AxesSubplot:xlabel='Parch', ylabel='Survived'>

# %% [markdown]
# this shows that 3rd parch survived the most and 5th was the lowest.

# %%
sns.barplot(x='Fare',y='Survived',data=df)
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Survived'>

# %%
sns.barplot(x='Embarked',y='Survived',data=df)
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='Survived'>

# %% [markdown]
# this shows that more people survived that embarked from c then from q then from s

# %% [markdown]
# # 6 - displot

# %%
sns.displot(df['Survived'],kde=True)

# %%
sns.displot(df['Pclass'],kde=True)

# %%
sns.displot(df['Age'],kde=True)

# %%
sns.displot(df['Sex'],kde=True)

# %%
sns.displot(df['SibSp'],kde=True)

# %%
sns.displot(df['Parch'],kde=True)

# %%
sns.displot(df['Fare'],kde=True)

# %%
sns.displot(df['Ticket'],kde=True)

# %%
sns.displot(df['Embarked'],kde=True)

# %% [markdown]
# # Describing Data

# %%
df.describe(include='all')
# Out:
#        PassengerId    Survived      Pclass        Name         Sex  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  445.000000    0.647587
# std     257.353842    0.486592    0.836071  257.353842    0.477990
# min       1.000000    0.000000    1.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  222.500000    0.000000
# 50%     446.000000    0.000000    3.000000  445.000000    1.000000
# 75%     668.500000    1.000000    3.000000  667.500000    1.000000
# max     891.000000    1.000000    3.000000  890.000000    1.000000
#
#               Age       SibSp       Parch      Ticket        Fare    Embarked
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean    29.699118    0.523008    0.381594  338.528620   32.204208    1.536476
# std     13.002015    1.102743    0.806057  200.850657   49.693429    0.791503
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,10))
sns.heatmap(df.describe(),annot=True,linewidths=2,linecolor='Black',fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Checking correlation of columns with the target variable.

# %%
df.corr
# Out:
# <bound method DataFrame.corr of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ...

# %%
df.corr()['Survived'].sort_values()
# Out:
# Sex           -0.543351
# Pclass        -0.338481
# Embarked      -0.167675
# Ticket        -0.164549
# Age           -0.069809
# Name          -0.057343
# SibSp         -0.035322
# PassengerId   -0.005007
# Parch          0.081629
# Fare           0.257307
# Survived       1.000000
# Name: Survived, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(),annot=True,linewidths=2,linecolor='Black',fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# sex is highly correlated with survived.
#
# pclass is the second thing most correlated with the class but not as much as sex.
#
# embarked is fine in correlation with survived.
#
# ticket is also fine.
#
# age,name,SibSp, passengerId and parch these columns are less correlated than others.
#
# the worst correlated column is fare.

# %% [markdown]
# # checking the columns which are positively and negatively correlated to the target variable.

# %%
plt.figure(figsize=(12,10))
df.corr()['Survived'].sort_values(ascending=False).drop(['Survived']).plot(kind='bar',color='g')
plt.xlabel('features',fontsize=12)
plt.ylabel('column with target names',fontsize=12)
plt.show()

# %% [markdown]
# # Outliers Checking

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn import preprocessing

# %%
le= preprocessing.LabelEncoder()

# %%
df['Embarked']= le.fit_transform(df['Embarked'])

# %%
df['Name']= le.fit_transform(df['Name'])

# %%
df['Ticket']= le.fit_transform(df['Ticket'])

# %%
df['Sex']= le.fit_transform(df['Sex'])

# %%
collist=df.columns.values
ncol=30
nrow=14

# %%
collist
# Out:
# array(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'], dtype=object)

# %%
for i in range(0,len(collist)):
    print(collist[i])
    break
# Out:
# PassengerId

# %%
plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(data = df[collist[i]],color='red',orient='v')
    plt.tight_layout()

# %%
from scipy.stats import zscore
import numpy as np

# %%
(np.abs(zscore(df))<3).all().all()
# Out:
# False

# %% [markdown]
# As the result is false so there are outliers present in the data set which will be treated.

# %% [markdown]
# # Removing Outliers

# %% [markdown]
# zscore Technique

# %%
z=np.abs(zscore(df))
threshold=3
np.where(z>3)
# Out:
# (array([ 13,  16,  25,  27,  50,  59,  68,  71,  86,  88,  96, 116, 118,
#         119, 159, 164, 167, 171, 180, 182, 201, 233, 258, 261, 266, 278,
#         299, 311, 324, 341, 360, 377, 380, 386, 437, 438, 438, 480, 493,
#         527, 541, 542, 557, 567, 610, 630, 638, 672, 678, 679, 683, 686,
#         689, 700, 716, 730, 736, 737, 742, 745, 774, 779, 787, 792, 813,
#         824, 846, 850, 851, 858, 863, 885], dtype=int64),
#  array([7, 6, 7, 9, 6, 6, 6, 6, 7, 9, 5, 5, 9, 6, 6, 6, 7, 6, 6, 6, 6, 6,
#         9, 6, 6, 6, 9, 9, 6, 9, 7, 9, 9, 6, 7, 7, 9, 6, 5, 9, 6, 6, 9, 7,
#         7, 5, 7, 5, 7, 9, 6, 6, 9, 9, 9, 9, 7, 9, 9, 5, 7, 9, 6, 6, 6, 6,
#         6, 6, 5, 7, 6, 7], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df_new
# Out:
#      PassengerId  Survived  Pclass  Name  Sex        Age  SibSp  Parch  \
# 0              1         0       3   108    1  22.000000      1      0
# 1              2         1       1   190    0  38.000000      1      0
# 2              3         1       3   353    0  26.000000      0      0
# 3              4         1       1   272    0  35.000000      1      0
# 4              5         0       3    15    1  35.000000      0      0
# ..           ...       ...     ...   ...  ...        ...    ...    ...
# 886          887         0       2   548    1  27.000000      0      0
# 887          888         1       1   303    0  19.000000      0      0
# 888          889         0       3   413    0  29.699118      1      2
# 889          890         1       1    81    1  26.000000      0      0
# 890          891         0       3   220    1  32.000000      0      0
#
#      Ticket     Fare  Embarked
# 0       523   7.2500         2
# 1       596  71.2833         0
# ...

# %%
df_new.shape
# Out:
# (820, 11)

# %%
data_loss=((891-827)/891)*100

# %%
data_loss
# Out:
# 7.182940516273851

# %% [markdown]
# This is the percentage of data lost

# %% [markdown]
# OUTLIERS HAS BEEN REMOVED FROM THE DATA.

# %% [markdown]
# # seperating features and the target variable

# %%
features=df_new.drop('Survived',axis=1)
target=df_new['Survived']

# %% [markdown]
# # checking skewness in Data and Removing it

# %%
features.skew()
# Out:
# PassengerId    0.003454
# Pclass        -0.632242
# Name           0.010147
# Sex           -0.664152
# Age            0.318314
# SibSp          1.979577
# Parch          2.122629
# Ticket         0.039240
# Fare           2.318761
# Embarked      -1.277386
# dtype: float64

# %% [markdown]
# keeping -/+0.7 as the range of skewness. Here are the columns that are not in range.

# %% [markdown]
# embarked , pclass , sex , SibSp , parch , Fare

# %%
features.plot(kind='density',subplots=True,layout=(6,11),sharex=False,legend=False,fontsize=1,figsize=(15,13))
plt.show()

# %%
from sklearn.preprocessing import power_transform

# %%
features.skew().sort_values(ascending=False)
# Out:
# Fare           2.318761
# Parch          2.122629
# SibSp          1.979577
# Age            0.318314
# Ticket         0.039240
# Name           0.010147
# PassengerId    0.003454
# Pclass        -0.632242
# Sex           -0.664152
# Embarked      -1.277386
# dtype: float64

# %% [markdown]
# SQUARE ROOT METHOD

# %%
features['Parch']=np.sqrt(features['Parch'])

# %%
features['Fare']=np.sqrt(features['Fare'])

# %%
features['SibSp']=np.sqrt(features['SibSp'])

# %%
features['Pclass']=np.sqrt(features['Pclass'])

# %%
features['Sex']=np.sqrt(features['Sex'])

# %%
features['Embarked']=np.sqrt(features['Embarked'])

# %%
pd.DataFrame(features,columns=features.columns).skew().sort_values(ascending=False)
# Out:
# Parch          1.723351
# Fare           1.350428
# SibSp          1.136758
# Age            0.318314
# Ticket         0.039240
# Name           0.010147
# PassengerId    0.003454
# Sex           -0.664152
# Pclass        -0.750899
# Embarked      -1.469502
# dtype: float64

# %% [markdown]
# there is still skewness in some columns so we will use another one

# %% [markdown]
# CUBE ROOT METHOD

# %%
features_n=np.cbrt(features['Parch'])

# %%
features_n=np.cbrt(features['Fare'])

# %%
features_n=np.cbrt(features['SibSp'])

# %%
features_n=np.cbrt(features['Pclass'])

# %%
features_n=np.cbrt(features['Sex'])

# %%
features_n=np.cbrt(features['Embarked'])

# %%
pd.DataFrame(features_n,columns=features.columns).skew().sort_values(ascending=False)
# Out:
# Embarked      -1.589559
# PassengerId         NaN
# Pclass              NaN
# Name                NaN
# Sex                 NaN
# Age                 NaN
# SibSp               NaN
# Parch               NaN
# Ticket              NaN
# Fare                NaN
# dtype: float64

# %% [markdown]
# cuberoot is also not working

# %% [markdown]
# so we are using YEO JOHNSON

# %%
features_n=power_transform(features,method='yeo-johnson')

# %%
pd.DataFrame(features_n,columns=features.columns).skew().sort_values(ascending=False)
# Out:
# Parch          1.581505
# SibSp          0.948944
# Age            0.071813
# Fare          -0.018602
# Name          -0.272208
# PassengerId   -0.279863
# Ticket        -0.291739
# Pclass        -0.429718
# Sex           -0.664152
# Embarked      -1.073724
# dtype: float64

# %%
pd.DataFrame(features_n,columns=features.columns).skew().sort_values(ascending=False)
# Out:
# Parch          1.581505
# SibSp          0.948944
# Age            0.071813
# Fare          -0.018602
# Name          -0.272208
# PassengerId   -0.279863
# Ticket        -0.291739
# Pclass        -0.429718
# Sex           -0.664152
# Embarked      -1.073724
# dtype: float64

# %%
type(features_n)
# Out:
# numpy.ndarray

# %%
features.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
features=pd.DataFrame(features_n,columns=features.columns)

# %%
features.skew().sort_values(ascending=False)
# Out:
# Parch          1.581505
# SibSp          0.948944
# Age            0.071813
# Fare          -0.018602
# Name          -0.272208
# PassengerId   -0.279863
# Ticket        -0.291739
# Pclass        -0.429718
# Sex           -0.664152
# Embarked      -1.073724
# dtype: float64

# %% [markdown]
# # Training Process Begins

# %% [markdown]
# # Balancing The Data

# %%
from imblearn.over_sampling import SMOTE

# %%
sm=SMOTE()
fea_res,tar_res=sm.fit_resample(features,target)

# %%
fea_res.value_counts()
# Out:
# PassengerId  Pclass     Name       Sex        Age        SibSp      Parch      Ticket     Fare       Embarked
# -2.156313     0.872830  -1.397830   0.722036  -0.618468   1.551886  -0.484693   0.934041  -0.834702   0.607787    1
#  0.610229     0.872830   0.934448   0.722036   0.447557  -0.633505  -0.484693   1.436939  -0.852487   0.607787    1
#  0.576024    -0.595500  -1.125731  -1.384973  -0.366847   1.551886   2.050905  -0.924430   0.654320   0.607787    1
#  0.579452    -1.470676   1.301816  -1.384973   0.764799   1.551886   2.050905  -1.263455   2.002275  -1.787676    1
#  0.582878    -0.595500  -0.823105   0.722036   1.921734  -0.633505  -0.484693  -0.393645   0.503727   0.607787    1
#                                                                                                                  ..
# -0.414721     0.872830  -0.270289   0.722036  -0.118907  -0.633505  -0.484693   0.349724  -0.747115   0.607787    1
# ...

# %%
tar_res.value_counts()
# Out:
# 0    500
# 1    500
# Name: Survived, dtype: int64

# %% [markdown]
# # Finding Best Random State

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.model_selection import train_test_split

# %%
maxaccu=0
maxRs=0
for i in range(0,200):
    fea_res_train,fea_res_test,tar_res_train,tar_res_test=train_test_split(fea_res,tar_res,test_size=.20,random_state=i)
    dt.fit(fea_res_train,tar_res_train)
    pre_train=dt.predict(fea_res_test)
    acc=accuracy_score(tar_res_test,pre_train)
    print('accuracy',acc,'random_state',i)
    
    if acc>maxaccu:
        maxaccu=acc
        maxRs=i
        print('maximum accuracy',maxaccu,'maximum random state',maxRs)
# Out:
# accuracy 0.765 random_state 0
# maximum accuracy 0.765 maximum random state 0
# accuracy 0.725 random_state 1
# accuracy 0.745 random_state 2
# accuracy 0.73 random_state 3
# accuracy 0.765 random_state 4
# accuracy 0.82 random_state 5
# maximum accuracy 0.82 maximum random state 5
# accuracy 0.77 random_state 6
# accuracy 0.8 random_state 7
# accuracy 0.785 random_state 8
# accuracy 0.835 random_state 9
# maximum accuracy 0.835 maximum random state 9
# accuracy 0.78 random_state 10
# accuracy 0.82 random_state 11
# accuracy 0.77 random_state 12
# accuracy 0.785 random_state 13
# accuracy 0.78 random_state 14
# accuracy 0.81 random_state 15
# accuracy 0.76 random_state 16
# accuracy 0.805 random_state 17
# accuracy 0.74 random_state 18
# accuracy 0.77 random_state 19
# accuracy 0.745 random_state 20
# accuracy 0.775 random_state 21
# accuracy 0.8 random_state 22
# accuracy 0.76 random_state 23
# accuracy 0.755 random_state 24
# accuracy 0.725 random_state 25
# ...

# %%
print('best accuracy score',maxaccu ,'on random state',maxRs)
# Out:
# best accuracy score 0.855 on random state 76

# %% [markdown]
# # Create train test split

# %%
fea_res_train,fea_res_test,tar_res_train,tar_res_test=train_test_split(fea_res,tar_res,test_size=.20,random_state=180)

# %%
fea_res_train.shape
# Out:
# (800, 10)

# %%
fea_res_test.shape
# Out:
# (200, 10)

# %%
tar_res_train.shape
# Out:
# (800,)

# %%
tar_res_test.shape
# Out:
# (200,)

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(fea_res_train,tar_res_train)
pre_train=dt.predict(fea_res_test)
print('accuracy',accuracy_score(tar_res_test,pre_train)*100)
print(confusion_matrix(tar_res_test,pre_train))
print(classification_report(tar_res_test,pre_train))
# Out:
# accuracy 80.5
# [[72 16]
#  [23 89]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.82      0.79        88
#            1       0.85      0.79      0.82       112
#
#     accuracy                           0.81       200
#    macro avg       0.80      0.81      0.80       200
# weighted avg       0.81      0.81      0.81       200

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=300)
rf.fit(fea_res_train,tar_res_train)
pre_train=rf.predict(fea_res_test)
print('accuracy',accuracy_score(tar_res_test,pre_train)*100)
print(confusion_matrix(tar_res_test,pre_train))
print(classification_report(tar_res_test,pre_train))
# Out:
# accuracy 85.0
# [[75 13]
#  [17 95]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.85      0.83        88
#            1       0.88      0.85      0.86       112
#
#     accuracy                           0.85       200
#    macro avg       0.85      0.85      0.85       200
# weighted avg       0.85      0.85      0.85       200

# %% [markdown]
# # K Neighbors classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(fea_res_train,tar_res_train)
pre_train=knn.predict(fea_res_test)
print('accuracy',accuracy_score(tar_res_test,pre_train)*100)
print(confusion_matrix(tar_res_test,pre_train))
print(classification_report(tar_res_test,pre_train))
# Out:
# accuracy 84.0
# [[73 15]
#  [17 95]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.83      0.82        88
#            1       0.86      0.85      0.86       112
#
#     accuracy                           0.84       200
#    macro avg       0.84      0.84      0.84       200
# weighted avg       0.84      0.84      0.84       200

# %% [markdown]
# # Cross Validation

# %%
from sklearn.model_selection import cross_val_score
scr=cross_val_score(dt,fea_res,tar_res,cv=9)
print('cross validation score for Decision tree model =', scr.mean())
# Out:
# cross validation score for Decision tree model = 0.6401312026312026

# %%
from sklearn.model_selection import cross_val_score
scr=cross_val_score(rf,fea_res,tar_res,cv=9)
print('cross validation score for Random Forest Classifier  model =', scr.mean())
# Out:
# cross validation score for Random Forest Classifier  model = 0.756041756041756

# %%
from sklearn.model_selection import cross_val_score
scr=cross_val_score(knn,fea_res,tar_res,cv=9)
print('cross validation score for K Neighbors classifiermodel =', scr.mean())
# Out:
# cross validation score for K Neighbors classifiermodel = 0.7980480480480481

# %% [markdown]
# cross validation score of k is better than others so we'll be using KNeighborsClassifier for hyper parameter tuning

# %% [markdown]
# # Hyper parameter tunning

# %%
KNeighborsClassifier()
# Out:
# KNeighborsClassifier()

# %%
from sklearn.model_selection import GridSearchCV
parameters={'n_neighbors' :range(1,30,2), 'weights':['uniform','distance'],'metric':['euclidean','manhattan','minkowski'],
           'leaf_size' :range(1,50)}

# %%
gcv=GridSearchCV(KNeighborsClassifier(),parameters,cv=9,scoring="accuracy")
gcv.fit(fea_res_train,tar_res_train)
gcv.best_params_
# Out:
# {'leaf_size': 1,
#  'metric': 'euclidean',
#  'n_neighbors': 3,
#  'weights': 'distance'}

# %%
gcv.best_estimator_
# Out:
# KNeighborsClassifier(leaf_size=1, metric='euclidean', n_neighbors=3,
#                      weights='distance')

# %%
gcv_pred=gcv.best_estimator_.predict(fea_res_test)
accuracy_score=(tar_res_test,gcv_pred)

# %% [markdown]
# # ROC AUC curve

# %%
from sklearn.metrics import plot_roc_curve
plot_roc_curve(gcv.best_estimator_,fea_res_test,tar_res_test)
plt.title('ROC AUC plot')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# auc is 0.89 here

# %%
import joblib
joblib.dump(gcv.best_estimator_,'titanic1.pkl')
# Out:
# ['titanic1.pkl']
