# %% [markdown]
# # BASEBALL CASE STUDY
# ________________________________________________

# %%
#importing essential libraries that would be required.
import pandas as pd 
import numpy as np

# %%
#reading the csv file and creating dataset in df variable.
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv')

# %%
#this could helps to get the information about the data set in the variable named df.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
#this code tells the data type of the columns present in dataset.
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
#this code tells the no of rows and columns present in the dataset.
df.shape
# Out:
# (30, 17)

# %%
#this gives the column name from the dataset
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# Input variables:
#
# Runs- no of runs made.
#
# At Bats- balls at bat.
#
# Hits- balls that got hit.
#
# Doubles- how many doubles run made on the ball.
#
# Triples -  how many triples made.
#
# Homeruns -  how many homeruns made.
#
# Walks
#
# Strikeouts - how many strikeouts.
#
# Stolen Bases
#
# Runs Allowed -
#
# Earned Runs- Number of runs earned in the game.
#
# Earned Run Average (ERA)
#
# Shutouts- no.of shoutouts in the game.
#
# Saves - how many saves made.
#
# Complete Games
#
# Errors - errors made in the game.
#
# -----------------------------
#
# Output:
#
# Number of predicted wins (W)- Number of predicted wins.

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
#this code gives top five rows from the data
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
#this code give last 5 rows of the dataset.
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
#this gives the sample row from the dataset
df.sample()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO  SB   RA   ER   ERA  CG  SHO  \
# 9  78  748  5640  1495  294  33  161  478  1148  71  753  694  4.31   3   10
#
#    SV   E
# 9  40  97

# %% [markdown]
# # CHECKING FOR THE DUPLICATED VALUES IN THE TABLE OR DATASET

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# there are 0 duplicated values in the dataset

# %% [markdown]
# # CHECKING FOR THE UNIQUE VALUES IN THE TABLE OR DATASET

# %%
df['W'].nunique()
# Out:
# 24

# %%
df['R'].nunique()
# Out:
# 28

# %%
df['AB'].nunique()
# Out:
# 29

# %%
df['H'].nunique()
# Out:
# 29

# %%
df['2B'].nunique()
# Out:
# 22

# %%
df['3B'].nunique()
# Out:
# 23

# %%
df['HR'].nunique()
# Out:
# 27

# %%
df['BB'].nunique()
# Out:
# 29

# %%
df['SO'].nunique()
# Out:
# 29

# %%
df['SB'].nunique()
# Out:
# 27

# %%
df['RA'].nunique()
# Out:
# 30

# %%
df['ER'].nunique()
# Out:
# 30

# %%
df['ERA'].nunique()
# Out:
# 30

# %%
df['CG'].nunique()
# Out:
# 9

# %%
df['SHO'].nunique()
# Out:
# 12

# %%
df['SV'].nunique()
# Out:
# 20

# %%
df['E'].nunique()
# Out:
# 21

# %% [markdown]
# # Checking for the Null Values

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
sns.heatmap(df.isnull())
plt.title('Null Values')
# Out:
# Text(0.5, 1.0, 'Null Values')

# %% [markdown]
# since we can see in the heatmap we do not have any null values present in the data so there is no need of imputation.

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# there are no null values present in the dataset so there is no need of imputation

# %% [markdown]
# # EDA

# %% [markdown]
# # Visualization Of The Data

# %% [markdown]
# important libraries required for the visualization of the data has already been imported earlier.

# %%
sns.pairplot(df)
plt.show()

# %%
df.hist(bins=10,figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'W'}>,
#         <AxesSubplot:title={'center':'R'}>,
#         <AxesSubplot:title={'center':'AB'}>,
#         <AxesSubplot:title={'center':'H'}>],
#        [<AxesSubplot:title={'center':'2B'}>,
#         <AxesSubplot:title={'center':'3B'}>,
#         <AxesSubplot:title={'center':'HR'}>,
#         <AxesSubplot:title={'center':'BB'}>],
#        [<AxesSubplot:title={'center':'SO'}>,
#         <AxesSubplot:title={'center':'SB'}>,
#         <AxesSubplot:title={'center':'RA'}>,
#         <AxesSubplot:title={'center':'ER'}>],
#        [<AxesSubplot:title={'center':'ERA'}>,
#         <AxesSubplot:title={'center':'CG'}>,
#         <AxesSubplot:title={'center':'SHO'}>,
#         <AxesSubplot:title={'center':'SV'}>],
#        [<AxesSubplot:title={'center':'E'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %% [markdown]
# # COUNTPLOT

# %%
sns.countplot(x='W',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='count'>

# %% [markdown]
# this tells the number of wins

# %%
sns.countplot(x='R',data=df)
# Out:
# <AxesSubplot:xlabel='R', ylabel='count'>

# %% [markdown]
# this tells the runs scored in matches

# %%
sns.countplot(x='AB',data=df)
# Out:
# <AxesSubplot:xlabel='AB', ylabel='count'>

# %% [markdown]
# this tells the balls that were at bat

# %%
sns.countplot(x='H',data=df)
# Out:
# <AxesSubplot:xlabel='H', ylabel='count'>

# %% [markdown]
# this tells the data about how many balls were hit by bat

# %%
sns.countplot(x='2B',data=df)
# Out:
# <AxesSubplot:xlabel='2B', ylabel='count'>

# %% [markdown]
# this tell how many double runs made at balls

# %%
sns.countplot(x='3B',data=df)
# Out:
# <AxesSubplot:xlabel='3B', ylabel='count'>

# %% [markdown]
# this tells how many triple runs made at the balls

# %%
sns.countplot(x='HR',data=df)
# Out:
# <AxesSubplot:xlabel='HR', ylabel='count'>

# %% [markdown]
# this tell the data about the home runs hit by bat

# %%
sns.countplot(x='BB',data=df)
# Out:
# <AxesSubplot:xlabel='BB', ylabel='count'>

# %% [markdown]
# this tells the at how many balls only walk was made

# %%
sns.countplot(x='SO',data=df)
# Out:
# <AxesSubplot:xlabel='SO', ylabel='count'>

# %% [markdown]
# this gives the data about the strike outs

# %%
sns.countplot(x='SB',data=df)
# Out:
# <AxesSubplot:xlabel='SB', ylabel='count'>

# %% [markdown]
# number of strike in wins and lose match

# %%
sns.countplot(x='RA',data=df)
# Out:
# <AxesSubplot:xlabel='RA', ylabel='count'>

# %% [markdown]
# runs allowed in the win and lose match

# %%
sns.countplot(x='ER',data=df)
# Out:
# <AxesSubplot:xlabel='ER', ylabel='count'>

# %% [markdown]
# runs earned in the wins and lose match

# %%
sns.countplot(x='ERA',data=df)
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='count'>

# %% [markdown]
# this tells what is the earned run average in the the win and lose match

# %%
sns.countplot(x='CG',data=df)
# Out:
# <AxesSubplot:xlabel='CG', ylabel='count'>

# %%
sns.countplot(x='SHO',data=df)
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='count'>

# %% [markdown]
# this tells the number of shoutouts

# %%
sns.countplot(x='SV',data=df)
# Out:
# <AxesSubplot:xlabel='SV', ylabel='count'>

# %% [markdown]
# this tells the number of saves made in the game

# %%
sns.countplot(x='E',data=df)
# Out:
# <AxesSubplot:xlabel='E', ylabel='count'>

# %% [markdown]
# this tells about the errors made in the game

# %% [markdown]
# # BARPLOT

# %%
sns.barplot(x='R',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='R', ylabel='W'>

# %% [markdown]
# this tells how many runs were made in win and lose matches

# %%
sns.barplot(x='AB',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='AB', ylabel='W'>

# %% [markdown]
# this tells how many balls were at bat in the win and lose matches

# %%
sns.barplot(x='H',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='H', ylabel='W'>

# %% [markdown]
# this tell that how many home runs were made in the win and lose match

# %%
sns.barplot(x='2B',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='2B', ylabel='W'>

# %% [markdown]
# this tells how many doubles were made at a hit in the win and lose match.

# %%
sns.barplot(x='3B',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='3B', ylabel='W'>

# %% [markdown]
# this tells how many 3 runs were made at hits in the win and lose match

# %%
sns.barplot(x='HR',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='HR', ylabel='W'>

# %% [markdown]
# this tells how many homeruns were there in wins and lose match

# %%
sns.countplot(x='BB',data=df)
# Out:
# <AxesSubplot:xlabel='BB', ylabel='count'>

# %% [markdown]
# this tells how many balls were walkes only in win and lose match

# %%
sns.barplot(x='SO',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='SO', ylabel='W'>

# %% [markdown]
# strike outs in win and lose match

# %%
sns.barplot(x='SB',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='SB', ylabel='W'>

# %%
sns.barplot(x='RA',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='RA', ylabel='W'>

# %%
sns.barplot(x='ER',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='ER', ylabel='W'>

# %%
sns.barplot(x='ERA',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='W'>

# %%
sns.barplot(x='CG',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='CG', ylabel='W'>

# %% [markdown]
# number of cg's in the win and lose matchh

# %%
sns.barplot(x='SHO',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='W'>

# %% [markdown]
# this tells the number of shoutouts in the win amtch

# %%
sns.barplot(x='SV',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='SV', ylabel='W'>

# %% [markdown]
# no. of saves in the game made in the win and lose match

# %%
sns.barplot(x='E',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='E', ylabel='W'>

# %% [markdown]
# this shows the errors made in the win and lose match

# %% [markdown]
# # DISTPLOT

# %%
sns.displot(df['W'],kde=True)

# %%
sns.displot(df['R'],kde=True)

# %%
sns.displot(df['AB'],kde=True)

# %%
sns.displot(df['H'],kde=True)

# %%
sns.displot(df['2B'],kde=True)

# %%
sns.displot(df['3B'],kde=True)

# %%
sns.displot(df['HR'],kde=True)

# %%
sns.displot(df['BB'],kde=True)

# %%
sns.displot(df['SO'],kde=True)

# %%
sns.displot(df['SB'],kde=True)

# %%
sns.displot(df['RA'],kde=True)

# %%
sns.displot(df['ER'],kde=True)

# %%
sns.displot(df['ERA'],kde=True)

# %%
sns.displot(df['CG'],kde=True)

# %%
sns.displot(df['SHO'],kde=True)

# %%
sns.displot(df['SV'],kde=True)

# %%
sns.displot(df['E'],kde=True)

# %% [markdown]
# # violinplot

# %%
sns.violinplot(x='W',data=df)
# Out:
# <AxesSubplot:xlabel='W'>

# %% [markdown]
# number of wins is in the range of of 79 to 84

# %%
sns.violinplot(x='R',data=df)
# Out:
# <AxesSubplot:xlabel='R'>

# %% [markdown]
# number of runs made is in the range of 670 to 700

# %%
sns.violinplot(x='AB',data=df)
# Out:
# <AxesSubplot:xlabel='AB'>

# %% [markdown]
# number of balls at bat in each amtch is in the range of 5450 to 5500

# %%
sns.violinplot(x='H',data=df)
# Out:
# <AxesSubplot:xlabel='H'>

# %% [markdown]
# range of homeruns is in between 1350 to 1400

# %%
sns.violinplot(x='2B',data=df)
# Out:
# <AxesSubplot:xlabel='2B'>

# %%
sns.violinplot(x='3B',data=df)
# Out:
# <AxesSubplot:xlabel='3B'>

# %%
sns.violinplot(x='HR',data=df)
# Out:
# <AxesSubplot:xlabel='HR'>

# %%
sns.violinplot(x='BB',data=df)
# Out:
# <AxesSubplot:xlabel='BB'>

# %%
sns.violinplot(x='SO',data=df)
# Out:
# <AxesSubplot:xlabel='SO'>

# %%
sns.violinplot(x='SB',data=df)
# Out:
# <AxesSubplot:xlabel='SB'>

# %% [markdown]
# number of walks at hit is in the range of 70 to 90

# %%
sns.violinplot(x='RA',data=df)
# Out:
# <AxesSubplot:xlabel='RA'>

# %% [markdown]
# runs allowed is in the range of 670 to 730

# %%
sns.violinplot(x='ER',data=df)
# Out:
# <AxesSubplot:xlabel='ER'>

# %% [markdown]
# run earned is in the range of 600 to  700

# %%
sns.violinplot(x='ERA',data=df)
# Out:
# <AxesSubplot:xlabel='ERA'>

# %% [markdown]
# earned run average is between 4 to 4.2

# %%
sns.violinplot(x='CG',data=df)
# Out:
# <AxesSubplot:xlabel='CG'>

# %%
sns.violinplot(x='SHO',data=df)
# Out:
# <AxesSubplot:xlabel='SHO'>

# %% [markdown]
# max shoutouts are in the range of 10 to 13

# %%
sns.violinplot(x='SV',data=df)
# Out:
# <AxesSubplot:xlabel='SV'>

# %% [markdown]
# number of save are in between the range of 39 to 44

# %%
sns.violinplot(x='E',data=df)
# Out:
# <AxesSubplot:xlabel='E'>

# %% [markdown]
# most of the error were in between 88 to 92

# %% [markdown]
# # Describing Data

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df.describe(),annot=True,linewidths=4,linecolor='white',fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Checking correlation of columns with the target variable.

# %%
df.corr()['W'].sort_values()
# Out:
# ERA   -0.819600
# RA    -0.812952
# ER    -0.809435
# 3B    -0.251118
# SB    -0.157234
# E     -0.089485
# AB    -0.087947
# H      0.037612
# CG     0.080533
# SO     0.111850
# HR     0.307407
# 2B     0.427797
# R      0.430751
# SHO    0.471805
# BB     0.484342
# SV     0.666530
# W      1.000000
# Name: W, dtype: float64

# %%
plt.figure(figsize=(14,12))
sns.heatmap(df.corr(),annot=True,linewidths=4,linecolor='black',fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# highest correlated column is saves and the least correlated column is earned runs average

# %% [markdown]
# # Checking the columns which are positively and negatively correlated to the target variable.

# %%
plt.figure(figsize=(12,10))
df.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='bar',color='r')
plt.xlabel('features',fontsize=12)
plt.ylabel('column with target names',fontsize=12)
plt.show()

# %% [markdown]
# # Outliers Checking

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
collist=df.columns.values
ncol=30
nrow=14

# %%
collist
# Out:
# array(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA',
#        'ER', 'ERA', 'CG', 'SHO', 'SV', 'E'], dtype=object)

# %%
for i in range(0,len(collist)):
    print(collist[i])
    break
# Out:
# W

# %%
plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(data = df[collist[i]],color='blue',orient='v')
    plt.tight_layout()

# %%
from scipy.stats import zscore
import numpy as np

# %%
(np.abs(zscore(df))<3).all().all()
# Out:
# False

# %% [markdown]
# As the result is false so there are outliers present in the data set which will be treated.

# %% [markdown]
# # Removing Outliers

# %% [markdown]
# zscore Technique

# %%
z=np.abs(zscore(df))
threshold=3
np.where(z>3)
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df_new
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# ...

# %%
df_new.shape
# Out:
# (29, 17)

# %%
data_loss=((30-29)/30)*100

# %%
data_loss
# Out:
# 3.3333333333333335

# %% [markdown]
# This is the percentage of data lost

# %% [markdown]
# OUTLIERS HAS BEEN REMOVED FROM THE DATA.

# %% [markdown]
# # Seperating features and the target variable

# %%
features=df_new.drop('W',axis=1)
target=df_new['W']

# %%
features
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0   724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1   696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2   669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3   622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4   689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
# 6   764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3    4
# 7   713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0   10
# 8   644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1   12
# 9   748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3   10
# 10  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5    9
# 11  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5   13
# ...

# %%
target
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: W, dtype: int64

# %% [markdown]
# # Checking skewness in Data and Removing it

# %%
features.skew()
# Out:
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %% [markdown]
# keeping -/+0.5 as the range of skewness. Here are the columns that are not in range.

# %% [markdown]
# H , CG , SHO , SV , E

# %%
features.plot(kind='density',subplots=True,layout=(6,11),sharex=False,legend=False,fontsize=2,figsize=(15,13))
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
# ...

# %% [markdown]
# As we can see that skewness is present in the data so we will remove it

# %% [markdown]
# # Removing skewness

# %%
from sklearn.preprocessing import power_transform

# %%
features.skew().sort_values(ascending=False)
# Out:
# CG     0.854980
# E      0.840271
# H      0.783772
# SV     0.627480
# SHO    0.526943
# SB     0.494966
# HR     0.450862
# AB     0.169573
# BB     0.151193
# 3B     0.090124
# ER     0.018461
# RA     0.018155
# ERA    0.016693
# R     -0.215364
# SO    -0.233815
# 2B    -0.335304
# dtype: float64

# %% [markdown]
# we are using YEO JOHNSON method to remove skewness from the data.

# %%
features_n=power_transform(features,method='yeo-johnson')

# %%
pd.DataFrame(features_n,columns=features.columns).skew().sort_values(ascending=False)
# Out:
# AB     0.081092
# E      0.065585
# SO     0.051530
# SHO    0.000529
# HR     0.000448
# H      0.000000
# ERA   -0.000401
# SV    -0.000925
# ER    -0.004988
# BB    -0.008572
# SB    -0.009570
# RA    -0.011974
# R     -0.024842
# CG    -0.045947
# 2B    -0.052793
# 3B    -0.075139
# dtype: float64

# %%
type(features_n)
# Out:
# numpy.ndarray

# %%
features.columns
# Out:
# Index(['R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER', 'ERA',
#        'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
features=pd.DataFrame(features_n,columns=features.columns)

# %%
features.skew().sort_values(ascending=False)
# Out:
# AB     0.081092
# E      0.065585
# SO     0.051530
# SHO    0.000529
# HR     0.000448
# H      0.000000
# ERA   -0.000401
# SV    -0.000925
# ER    -0.004988
# BB    -0.008572
# SB    -0.009570
# RA    -0.011974
# R     -0.024842
# CG    -0.045947
# 2B    -0.052793
# 3B    -0.075139
# dtype: float64

# %% [markdown]
# skewness from the data has been removed

# %% [markdown]
# # Training Process Begins

# %% [markdown]
# # Finding Best Random State and using min max scaler to scale the data

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
for i in range(0,100):
    features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=i)
    lr.fit(features_train,target_train)
    pre_train=lr.predict(features_train)
    pre_test=lr.predict(features_test)
    print(f"at random state {i},the train accuracy is:- {r2_score(target_train,pre_train)}")
    print(f"at random state {i},the testing accuracy is:- {r2_score(target_test,pre_test)}")
    print('\n')
# Out:
# at random state 0,the train accuracy is:- 0.9723886378254356
# at random state 0,the testing accuracy is:- 0.5230154402861422
#
#
# at random state 1,the train accuracy is:- 0.9624303138498057
# at random state 1,the testing accuracy is:- 0.785518121647335
#
#
# at random state 2,the train accuracy is:- 0.956663558152967
# at random state 2,the testing accuracy is:- 0.049365224219704906
#
#
# at random state 3,the train accuracy is:- 0.9503294331955566
# at random state 3,the testing accuracy is:- 0.9000223780625504
#
#
# at random state 4,the train accuracy is:- 0.9632494996067819
# at random state 4,the testing accuracy is:- 0.7457141328933747
#
#
# at random state 5,the train accuracy is:- 0.9642482535125206
# at random state 5,the testing accuracy is:- 0.6210570973913196
#
#
# at random state 6,the train accuracy is:- 0.957689852845223
# at random state 6,the testing accuracy is:- 0.8066355062771648
#
#
# at random state 7,the train accuracy is:- 0.9586663285630452
# ...

# %%
features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=.20,random_state=99)

# %%
features_train.shape
# Out:
# (23, 16)

# %%
features_test.shape
# Out:
# (6, 16)

# %%
target_train.shape
# Out:
# (23,)

# %%
target_test.shape
# Out:
# (6,)

# %% [markdown]
# # Linear regression

# %%
lr.fit(features_train,target_train)
# Out:
# LinearRegression()

# %% [markdown]
# test accuracy

# %%
pre_test=lr.predict(features_test)

# %%
 print(r2_score(target_test,pre_test))
# Out:
# 0.9224358006296649

# %% [markdown]
# train accuracy

# %%
pre_train=lr.predict(features_train)

# %%
print(r2_score(target_train,pre_train))
# Out:
# 0.9483727750341467

# %% [markdown]
# # KNeighborsRegressor

# %%
from sklearn.neighbors import KNeighborsRegressor
knr=KNeighborsRegressor()
knr.fit(features_train,target_train)
# Out:
# KNeighborsRegressor()

# %% [markdown]
# test accuracy

# %%
pre_test=knr.predict(features_test)

# %%
 print(r2_score(target_test,pre_test))
# Out:
# 0.7677348871085216

# %% [markdown]
# train accuracy

# %%
pre_train=knr.predict(features_train)

# %%
print(r2_score(target_train,pre_train))
# Out:
# 0.23145027010331587

# %% [markdown]
# # support vector regression

# %%
from sklearn.svm import SVR
svr=SVR()
svr.fit(features_train,target_train)
# Out:
# SVR()

# %%
pre_train=svr.predict(features_test)

# %%
 print(r2_score(target_test,pre_test))
# Out:
# 0.9224358006296649

# %%
pre_train=svr.predict(features_train)

# %%
print(r2_score(target_train,pre_train))
# Out:
# 0.23145027010331587

# %% [markdown]
# # DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
dtr.fit(features_train,target_train)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# test accuracy

# %%
pre_test=dtr.predict(features_test)

# %%
 print(r2_score(target_test,pre_test))
# Out:
# 0.45812090313182807

# %% [markdown]
# train accuracy

# %%
pre_train=dtr.predict(features_train)

# %%
print(r2_score(target_train,pre_train))
# Out:
# 1.0

# %% [markdown]
# # RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor(n_estimators=300)
rfr.fit(features_train,target_train)
# Out:
# RandomForestRegressor(n_estimators=300)

# %%
pre_test=rfr.predict(features_test)

# %%
 print(r2_score(target_test,pre_test))
# Out:
# 0.6751029618839524

# %%
pre_train=rfr.predict(features_train)

# %%
print(r2_score(target_train,pre_train))
# Out:
# 0.9346655740234142

# %% [markdown]
# # Among all of the above models the best one is linear regression so we will go with it.
# it is best as it is giving a train accuracy of - 0.9483727750341467
# and
# test accuracy of - 0.9224358006296649

# %% [markdown]
# # Cross Validation

# %%
train_accuracy=r2_score(target_train,pre_train)
testing_accuracy=r2_score(target_test,pre_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,features,target,cv=j)
    cv_mean=cv_score.mean()
    print(f"at cross fold {j} the cv score is {cv_mean} and accuracy score for training is {train_accuracy} and accuracy score for testing is {testing_accuracy}")
    print('\n')
# Out:
# at cross fold 2 the cv score is -4.477033246858105 and accuracy score for training is 0.9346655740234142 and accuracy score for testing is 0.6751029618839524
#
#
# at cross fold 3 the cv score is -1.604698214387749 and accuracy score for training is 0.9346655740234142 and accuracy score for testing is 0.6751029618839524
#
#
# at cross fold 4 the cv score is -0.23815457429446182 and accuracy score for training is 0.9346655740234142 and accuracy score for testing is 0.6751029618839524
#
#
# at cross fold 5 the cv score is 0.26137450067161366 and accuracy score for training is 0.9346655740234142 and accuracy score for testing is 0.6751029618839524
#
#
# at cross fold 6 the cv score is 0.03185220800387153 and accuracy score for training is 0.9346655740234142 and accuracy score for testing is 0.6751029618839524
#
#
# at cross fold 7 the cv score is 0.004589720069219062 and accuracy score for training is 0.9346655740234142 and accuracy score for testing is 0.6751029618839524
#
#
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,4))
plt.scatter(x=target_test, y=pre_test, color='r')
plt.plot(target_test,target_test,color='b')
plt.xlabel('actual wins',fontsize=12)
plt.ylabel('predict wins',fontsize=12)
plt.savefig('lr.png')
plt.show()

# %% [markdown]
# this is the LINEAR REGRESSION graph

# %% [markdown]
# # using Gridsearch cv

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import Lasso
parameters ={'alpha':[.0001,.001,.01,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf = GridSearchCV(ls,parameters)
clf.fit(features_train,target_train)
print(clf.best_params_)
# Out:
# {'alpha': 1, 'random_state': 0}

# %% [markdown]
# # Final model training

# %%
ls=Lasso(alpha=1,random_state=0)
ls.fit(features_train,target_train)
ls_score_training=ls.score(features_train,target_train)
pred_ls=ls.predict(features_test)
ls_score_training*100
# Out:
# 86.11060212473652

# %%
pred_ls=ls.predict(features_test)

# %%
lss=r2_score(target_test,pred_ls)
lss*100
# Out:
# 87.14937189431208

# %%
cv_score=cross_val_score(ls,features,target,cv=4)
cv_mean=cv_score.mean()
cv_mean*100
# Out:
# 75.13910932684257

# %% [markdown]
# # Ensemble technique

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
parameters={'criterion':['mse','mae'],'max_features':['auto','sqrt','log2']}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(features_train,target_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'sqrt'}

# %%
rf=RandomForestRegressor(criterion='mae',max_features='auto')
rf.fit(features_train,target_train)
rf.score(features_train,target_train)
prediction_decision=rf.predict(features_test)


rfscore=cross_val_score(rf,features,target,cv=4)
rfc=rfscore.mean()
print('cross val score',rfc*100)
# Out:
# cross val score 52.259950020943876

# %%
rfs=r2_score(target_test,prediction_decision)
print('r2_score is',rfs*100)
# Out:
# r2_score is 66.41193008011656

# %% [markdown]
# # saving the model

# %%
import pickle
filename='baseball.pkl'
pickle.dump(rf,open('baseball.pkl','wb'))

# %% [markdown]
# # loading the model

# %%
l_model=pickle.load(open('baseball.pkl','rb'))
result=l_model.score(features_test,target_test)
print(result*100)
# Out:
# 66.41193008011656
