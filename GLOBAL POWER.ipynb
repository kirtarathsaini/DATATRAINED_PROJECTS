# %% [markdown]
# # GLOBAL POWER PLANT PROJECT

# %%
#importing essential libraries that would be required.
import pandas as pd
import numpy as np

# %%
#reading the csv file and creating dataset in df variable
df=pd.read_csv('https://raw.githubusercontent.com/wri/global-power-plant-database/master/source_databases_csv/database_IND.csv')

# %%
#this could helps to get the information about the data set in the variable named df.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country                   907 non-null    object
#  1   country_long              907 non-null    object
#  2   name                      907 non-null    object
#  3   gppd_idnr                 907 non-null    object
#  4   capacity_mw               907 non-null    float64
#  5   latitude                  861 non-null    float64
#  6   longitude                 861 non-null    float64
#  7   primary_fuel              907 non-null    object
#  8   other_fuel1               198 non-null    object
#  9   other_fuel2               1 non-null      object
#  10  other_fuel3               0 non-null      float64
#  11  commissioning_year        527 non-null    float64
#  12  owner                     342 non-null    object
# ...

# %%
df
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0            2.5   28.1839    73.2407        Solar         NaN         NaN
# ...

# %%
#this code tells the no of rows and columns present in the dataset.
df.shape
# Out:
# (907, 27)

# %%
#this code tells the data type of the columns present in dataset.
df.dtypes
# Out:
# country                      object
# country_long                 object
# name                         object
# gppd_idnr                    object
# capacity_mw                 float64
# latitude                    float64
# longitude                   float64
# primary_fuel                 object
# other_fuel1                  object
# other_fuel2                  object
# other_fuel3                 float64
# commissioning_year          float64
# owner                        object
# source                       object
# url                          object
# geolocation_source           object
# wepp_id                     float64
# year_of_capacity_data       float64
# generation_gwh_2013         float64
# generation_gwh_2014         float64
# generation_gwh_2015         float64
# generation_gwh_2016         float64
# generation_gwh_2017         float64
# generation_gwh_2018         float64
# generation_gwh_2019         float64
# generation_data_source       object
# ...

# %%
#this code gives top five rows from the data
df.head()
# Out:
#   country country_long                      name   gppd_idnr  capacity_mw  \
# 0     IND        India          ACME Solar Tower  WRI1020239          2.5
# 1     IND        India       ADITYA CEMENT WORKS  WRI1019881         98.0
# 2     IND        India  AES Saurashtra Windfarms  WRI1026669         39.2
# 3     IND        India               AGARTALA GT  IND0000001        135.0
# 4     IND        India              AKALTARA TPP  IND0000002       1800.0
#
#    latitude  longitude primary_fuel other_fuel1 other_fuel2  ...  \
# 0   28.1839    73.2407        Solar         NaN         NaN  ...
# 1   24.7663    74.6090         Coal         NaN         NaN  ...
# 2   21.9038    69.3732         Wind         NaN         NaN  ...
# 3   23.8712    91.3602          Gas         NaN         NaN  ...
# 4   21.9603    82.4091         Coal         Oil         NaN  ...
#
#    year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# ...

# %%
#this code give last 5 rows of the dataset.
df.tail()
# Out:
#     country country_long                          name   gppd_idnr  \
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 902       1600.0   16.2949    77.3568         Coal         Oil         NaN
# 903          3.0   12.8932    78.1654        Solar         NaN         NaN
# 904         25.5   15.2758    75.5811         Wind         NaN         NaN
# 905         80.0   24.3500    73.7477         Coal         NaN         NaN
# 906         16.5    9.9344    77.4768         Wind         NaN         NaN
#
#      ...  year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# ...

# %%
#this gives the sample row from the dataset
df.sample()
# Out:
#     country country_long           name   gppd_idnr  capacity_mw  latitude  \
# 158     IND        India  DADRI (NCTPP)  IND0000088       1820.0    28.603
#
#      longitude primary_fuel other_fuel1 other_fuel2  ...  \
# 158    77.6078         Coal         Oil         NaN  ...
#
#      year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# 158                 2019.0                  NaN             11466.0
#
#     generation_gwh_2015 generation_gwh_2016 generation_gwh_2017  \
# 158              9333.0              8197.0              9271.0
#
#      generation_gwh_2018  generation_gwh_2019         generation_data_source  \
# 158             9861.136                  NaN  Central Electricity Authority
#
#      estimated_generation_gwh
# 158                       NaN
#
# [1 rows x 27 columns]

# %%
#this gives the column name from the dataset
df.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'other_fuel1', 'other_fuel2',
#        'other_fuel3', 'commissioning_year', 'owner', 'source', 'url',
#        'geolocation_source', 'wepp_id', 'year_of_capacity_data',
#        'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
#        'generation_gwh_2016', 'generation_gwh_2017', 'generation_gwh_2018',
#        'generation_gwh_2019', 'generation_data_source',
#        'estimated_generation_gwh'],
#       dtype='object')

# %% [markdown]
# # CHECKING FOR THE DUPLICATED VALUES IN THE TABLE OR DATASET

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# there are 0 duplicate values present in the data

# %% [markdown]
# # CHECKING FOR THE UNIQUE VALUES IN THE TABLE OR DATASET

# %% [markdown]
# # checking unique values in the whole dataset

# %%
df.nunique()
# Out:
# country                       1
# country_long                  1
# name                        907
# gppd_idnr                   907
# capacity_mw                 361
# latitude                    836
# longitude                   827
# primary_fuel                  8
# other_fuel1                   3
# other_fuel2                   1
# other_fuel3                   0
# commissioning_year           73
# owner                       280
# source                      191
# url                         304
# geolocation_source            3
# wepp_id                       0
# year_of_capacity_data         1
# generation_gwh_2013           0
# generation_gwh_2014         371
# generation_gwh_2015         396
# generation_gwh_2016         403
# generation_gwh_2017         408
# generation_gwh_2018         410
# generation_gwh_2019           0
# generation_data_source        1
# estimated_generation_gwh      0
# dtype: int64

# %% [markdown]
# # Checking for the Null Values

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
sns.heatmap(df.isnull())
plt.title('Null Values')
# Out:
# Text(0.5, 1.0, 'Null Values')

# %%
df.isnull().sum()
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                     46
# longitude                    46
# primary_fuel                  0
# other_fuel1                 709
# other_fuel2                 906
# other_fuel3                 907
# commissioning_year          380
# owner                       565
# source                        0
# url                           0
# geolocation_source           19
# wepp_id                     907
# year_of_capacity_data       388
# generation_gwh_2013         907
# generation_gwh_2014         509
# generation_gwh_2015         485
# generation_gwh_2016         473
# generation_gwh_2017         467
# generation_gwh_2018         459
# generation_gwh_2019         907
# generation_data_source      458
# estimated_generation_gwh    907
# dtype: int64

# %% [markdown]
# # Treating null values

# %% [markdown]
# Replacing the missing values in the 'latitude' , 'longitude' , 'other_fuel3' , 'commissioning_year' , 'other_fuel3' , 'wepp_id ' , 'year_of_capacity_data' , 'generation_gwh_2013' , 'generation_gwh_2014' , 'generation_gwh_2015' , 'generation_gwh_2016' , 'generation_gwh_2017' , 'generation_gwh_2018' , 'generation_gwh_2019'  , 'estimated_generation_gwh'  column with the mean value

# %%
df['latitude']=df['latitude'].astype(float)

# %%
df['longitude']=df['longitude'].astype(float)

# %%
df['other_fuel3']=df['other_fuel3'].astype(float)

# %%
df['commissioning_year']=df['commissioning_year'].astype(float)

# %%
df['wepp_id']=df['wepp_id'].astype(float)

# %%
df['year_of_capacity_data']=df['year_of_capacity_data'].astype(float)

# %%
df['generation_gwh_2013']=df['generation_gwh_2013'].astype(float)

# %%
df['generation_gwh_2014']=df['generation_gwh_2014'].astype(float)

# %%
df['generation_gwh_2015']=df['generation_gwh_2015'].astype(float)

# %%
df['generation_gwh_2016']=df['generation_gwh_2016'].astype(float)

# %%
df['generation_gwh_2017']=df['generation_gwh_2017'].astype(float)

# %%
df['generation_gwh_2018']=df['generation_gwh_2018'].astype(float)

# %%
df['generation_gwh_2019']=df['generation_gwh_2019'].astype(float)

# %%
df['estimated_generation_gwh']=df['estimated_generation_gwh'].astype(float)

# %%
import numpy as np

# %%
np.mean(df['latitude'])
# Out:
# 21.19791811846691

# %%
np.mean(df['longitude'])
# Out:
# 77.46490720092922

# %%
np.mean(df['other_fuel3'])
# Out:
# nan

# %%
np.mean(df['commissioning_year'])
# Out:
# 1997.0910815939278

# %%
np.mean(df['wepp_id'])
# Out:
# nan

# %%
np.mean(df['year_of_capacity_data'])
# Out:
# 2019.0

# %%
np.mean(df['generation_gwh_2013'])
# Out:
# nan

# %%
np.mean(df['generation_gwh_2014'])
# Out:
# 2431.823590196344

# %%
np.mean(df['generation_gwh_2015'])
# Out:
# 2428.2269459614085

# %%
np.mean(df['generation_gwh_2016'])
# Out:
# 2467.936858634909

# %%
np.mean(df['generation_gwh_2017'])
# Out:
# 2547.759304510204

# %%
np.mean(df['generation_gwh_2018'])
# Out:
# 2600.804098662014

# %%
np.mean(df['generation_gwh_2019'])
# Out:
# nan

# %%
np.mean(df['estimated_generation_gwh'])
# Out:
# nan

# %%
df['latitude'].fillna(df['latitude'].mean(), inplace=True)

# %%
df['longitude'].fillna(df['longitude'].mean(), inplace=True)

# %%
df['other_fuel3'].fillna(df['other_fuel3'].mean(), inplace=True)

# %%
df['commissioning_year'].fillna(df['commissioning_year'].mean(), inplace=True)

# %%
df['wepp_id'].fillna(df['wepp_id'].mean(), inplace=True)

# %%
df['year_of_capacity_data'].fillna(df['year_of_capacity_data'].mean(), inplace=True)

# %%
df['generation_gwh_2013'].fillna(df['generation_gwh_2013'].mean(), inplace=True)

# %%
df['generation_gwh_2014'].fillna(df['generation_gwh_2014'].mean(), inplace=True)

# %%
df['generation_gwh_2015'].fillna(df['generation_gwh_2015'].mean(), inplace=True)

# %%
df['generation_gwh_2016'].fillna(df['generation_gwh_2016'].mean(), inplace=True)

# %%
df['generation_gwh_2017'].fillna(df['generation_gwh_2017'].mean(), inplace=True)

# %%
df['generation_gwh_2018'].fillna(df['generation_gwh_2018'].mean(), inplace=True)

# %%
df['generation_gwh_2019'].fillna(df['generation_gwh_2019'].mean(), inplace=True)

# %%
df['estimated_generation_gwh'].fillna(df['estimated_generation_gwh'].mean(), inplace=True)

# %% [markdown]
# Finding the mode value of the 'other_fuel1' , 'other_fuel2', 'owner' , 'generation_data_source' column as it will have occurred the maximum number of times

# %%
df['other_fuel1'].fillna(df['other_fuel1'].mode()[0], inplace=True)

# %%
df['other_fuel2'].fillna(df['other_fuel2'].mode()[0], inplace=True)

# %%
df['owner'].fillna(df['owner'].mode()[0], inplace=True)

# %%
df['geolocation_source'].fillna(df['geolocation_source'].mode()[0], inplace=True)

# %%
df['generation_data_source'].fillna(df['generation_data_source'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                      0
# longitude                     0
# primary_fuel                  0
# other_fuel1                   0
# other_fuel2                   0
# other_fuel3                 907
# commissioning_year            0
# owner                         0
# source                        0
# url                           0
# geolocation_source            0
# wepp_id                     907
# year_of_capacity_data         0
# generation_gwh_2013         907
# generation_gwh_2014           0
# generation_gwh_2015           0
# generation_gwh_2016           0
# generation_gwh_2017           0
# generation_gwh_2018           0
# generation_gwh_2019         907
# generation_data_source        0
# estimated_generation_gwh    907
# dtype: int64

# %% [markdown]
# THERE ARE STILL SOME COLUMNS WITH NULL VALUES PRESENT. THESE ARE THOSE COLUMNS THAT HAVE NAN VALUES IN ALL THE ROWS SO THERE IS NO USE OF KEEPING THEM SO WE ARE DROPING THESE COLUMNS

# %%
df = df.drop(columns='other_fuel3', axis=1)

# %%
df = df.drop(columns='wepp_id', axis=1)

# %%
df = df.drop(columns='generation_gwh_2013', axis=1)

# %%
df = df.drop(columns='generation_gwh_2019', axis=1)

# %%
df = df.drop(columns='estimated_generation_gwh', axis=1)

# %%
df.isnull().sum()
# Out:
# country                   0
# country_long              0
# name                      0
# gppd_idnr                 0
# capacity_mw               0
# latitude                  0
# longitude                 0
# primary_fuel              0
# other_fuel1               0
# other_fuel2               0
# commissioning_year        0
# owner                     0
# source                    0
# url                       0
# geolocation_source        0
# year_of_capacity_data     0
# generation_gwh_2014       0
# generation_gwh_2015       0
# generation_gwh_2016       0
# generation_gwh_2017       0
# generation_gwh_2018       0
# generation_data_source    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
sns.heatmap(df.isnull())
plt.title('null values')
# Out:
# Text(0.5, 1.0, 'null values')

# %% [markdown]
# Now we can see that the null values or columns has been treated.

# %% [markdown]
# # EDA

# %% [markdown]
# # Visualization Of The Data

# %% [markdown]
# # 1.pairplot

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
sns.pairplot(df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # 2. histogarm

# %%
df.hist(bins=10,figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'country'}>,
#         <AxesSubplot:title={'center':'country_long'}>,
#         <AxesSubplot:title={'center':'name'}>,
#         <AxesSubplot:title={'center':'gppd_idnr'}>,
#         <AxesSubplot:title={'center':'capacity_mw'}>],
#        [<AxesSubplot:title={'center':'latitude'}>,
#         <AxesSubplot:title={'center':'longitude'}>,
#         <AxesSubplot:title={'center':'primary_fuel'}>,
#         <AxesSubplot:title={'center':'other_fuel1'}>,
#         <AxesSubplot:title={'center':'other_fuel2'}>],
#        [<AxesSubplot:title={'center':'commissioning_year'}>,
#         <AxesSubplot:title={'center':'owner'}>,
#         <AxesSubplot:title={'center':'source'}>,
#         <AxesSubplot:title={'center':'url'}>,
#         <AxesSubplot:title={'center':'geolocation_source'}>],
#        [<AxesSubplot:title={'center':'year_of_capacity_data'}>,
#         <AxesSubplot:title={'center':'generation_gwh_2014'}>,
# ...

# %% [markdown]
# # COUNTPLOT

# %%
sns.countplot(x='primary_fuel',data=df)
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='count'>

# %%
sns.countplot(x='generation_data_source',data=df)
# Out:
# <AxesSubplot:xlabel='generation_data_source', ylabel='count'>

# %%
sns.countplot(x='geolocation_source',data=df)
# Out:
# <AxesSubplot:xlabel='geolocation_source', ylabel='count'>

# %%
sns.countplot(x='owner',data=df)
# Out:
# <AxesSubplot:xlabel='owner', ylabel='count'>

# %% [markdown]
# # Describing Data

# %%
df.describe()
# Out:
#        capacity_mw    latitude   longitude  commissioning_year  \
# count   907.000000  907.000000  907.000000          907.000000
# mean    326.223755   21.197918   77.464907         1997.091082
# std     590.085456    6.079148    4.812291           13.016360
# min       0.000000    8.168900   68.644700         1927.000000
# 25%      16.725000   17.072000   74.388900         1997.091082
# 50%      59.200000   21.281800   76.979200         1997.091082
# 75%     385.250000   25.176450   79.206100         2003.000000
# max    4760.000000   34.649000   95.408000         2018.000000
#
#        year_of_capacity_data  generation_gwh_2014  generation_gwh_2015  \
# count                  907.0           907.000000           907.000000
# mean                  2019.0          2431.823590          2428.226946
# std                      0.0          2665.338608          2859.349132
# min                   2019.0             0.000000             0.000000
# ...

# %%
df.describe(include='all')
# Out:
#        country country_long              name   gppd_idnr  capacity_mw  \
# count      907          907               907         907   907.000000
# unique       1            1               907         907          NaN
# top        IND        India  ACME Solar Tower  WRI1020239          NaN
# freq       907          907                 1           1          NaN
# mean       NaN          NaN               NaN         NaN   326.223755
# std        NaN          NaN               NaN         NaN   590.085456
# min        NaN          NaN               NaN         NaN     0.000000
# 25%        NaN          NaN               NaN         NaN    16.725000
# 50%        NaN          NaN               NaN         NaN    59.200000
# 75%        NaN          NaN               NaN         NaN   385.250000
# max        NaN          NaN               NaN         NaN  4760.000000
#
#           latitude   longitude primary_fuel other_fuel1 other_fuel2  ...  \
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,10))
sns.heatmap(df.describe(),annot=True,linewidths=2,linecolor='Black',fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # prediction 1: Primary Fuel correlation

# %% [markdown]
# in this we'll take primary fuel as our target variable

# %% [markdown]
# # Checking correlation

# %%
df.corr()
# Out:
#                        capacity_mw  latitude  longitude  commissioning_year  \
# capacity_mw               1.000000  0.050984   0.195882            0.274292
# latitude                  0.050984  1.000000   0.036362            0.102069
# longitude                 0.195882  0.036362   1.000000            0.092331
# commissioning_year        0.274292  0.102069   0.092331            1.000000
# year_of_capacity_data          NaN       NaN        NaN                 NaN
# generation_gwh_2014       0.694350  0.044321   0.011472            0.133051
# generation_gwh_2015       0.711190  0.036398   0.018818            0.147338
# generation_gwh_2016       0.742221  0.031256   0.039209            0.170644
# generation_gwh_2017       0.757585  0.031212   0.039675            0.170863
# generation_gwh_2018       0.773456  0.031326   0.037780            0.174377
#
#                        year_of_capacity_data  generation_gwh_2014  \
# ...

# %% [markdown]
# # Checking correlation of columns with the target variable.

# %% [markdown]
# before checking the correlation we need to use label encoder to encode the data in order to make the data understandable for the system so that further processing can easily be done

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn import preprocessing

# %%
le= preprocessing.LabelEncoder()

# %%
df['country']= le.fit_transform(df['country'])

# %%
df['country_long']= le.fit_transform(df['country_long'])

# %%
df['name']= le.fit_transform(df['name'])

# %%
df['gppd_idnr']= le.fit_transform(df['gppd_idnr'])

# %%
df['primary_fuel']= le.fit_transform(df['primary_fuel'])

# %%
df['other_fuel1']= le.fit_transform(df['other_fuel1'])

# %%
df['other_fuel2']= le.fit_transform(df['other_fuel2'])

# %%
df['owner']= le.fit_transform(df['owner'])

# %%
df['source']= le.fit_transform(df['source'])

# %%
df['url']= le.fit_transform(df['url'])

# %%
df['geolocation_source']= le.fit_transform(df['geolocation_source'])

# %%
df['generation_data_source']= le.fit_transform(df['generation_data_source'])

# %%
df.corr()['primary_fuel'].sort_values()
# Out:
# geolocation_source       -0.483217
# capacity_mw              -0.380395
# longitude                -0.347948
# generation_gwh_2018      -0.136983
# generation_gwh_2017      -0.132003
# generation_gwh_2016      -0.131051
# commissioning_year       -0.126650
# generation_gwh_2015      -0.124828
# generation_gwh_2014      -0.124769
# latitude                 -0.010204
# other_fuel1               0.004912
# name                      0.040753
# source                    0.053613
# owner                     0.284296
# url                       0.589886
# gppd_idnr                 0.609180
# primary_fuel              1.000000
# country                        NaN
# country_long                   NaN
# other_fuel2                    NaN
# year_of_capacity_data          NaN
# generation_data_source         NaN
# Name: primary_fuel, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(),annot=True,linewidths=2,linecolor='Black',fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # checking the columns which are positively and negatively correlated to the target variable.

# %%
plt.figure(figsize=(12,10))
df.corr()['primary_fuel'].sort_values(ascending=False).drop(['primary_fuel']).plot(kind='bar',color='g')
plt.xlabel('features',fontsize=12)
plt.ylabel('column with target names',fontsize=12)
plt.show()

# %% [markdown]
# # prediction 2: capacity_mw correlation

# %% [markdown]
# in this we'll take capacity_mw as our target variable

# %%
df.corr()['capacity_mw'].sort_values()
# Out:
# primary_fuel             -0.380395
# gppd_idnr                -0.335742
# owner                    -0.311048
# url                      -0.243830
# source                   -0.242122
# other_fuel1               0.003105
# latitude                  0.050984
# name                      0.060240
# longitude                 0.195882
# geolocation_source        0.204865
# commissioning_year        0.274292
# generation_gwh_2014       0.694350
# generation_gwh_2015       0.711190
# generation_gwh_2016       0.742221
# generation_gwh_2017       0.757585
# generation_gwh_2018       0.773456
# capacity_mw               1.000000
# country                        NaN
# country_long                   NaN
# other_fuel2                    NaN
# year_of_capacity_data          NaN
# generation_data_source         NaN
# Name: capacity_mw, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(),annot=True,linewidths=2,linecolor='Black',fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # checking the columns which are positively and negatively correlated to the target variable

# %%
plt.figure(figsize=(12,10))
df.corr()['primary_fuel'].sort_values(ascending=False).drop(['primary_fuel']).plot(kind='bar',color='g')
plt.xlabel('features',fontsize=12)
plt.ylabel('column with target names',fontsize=12)
plt.show()

# %% [markdown]
# # Outliers Checking

# %%
collist=df.columns.values
ncol=30
nrow=14

# %%
collist
# Out:
# array(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'other_fuel1',
#        'other_fuel2', 'commissioning_year', 'owner', 'source', 'url',
#        'geolocation_source', 'year_of_capacity_data',
#        'generation_gwh_2014', 'generation_gwh_2015',
#        'generation_gwh_2016', 'generation_gwh_2017',
#        'generation_gwh_2018', 'generation_data_source'], dtype=object)

# %%
for i in range(0,len(collist)):
    print(collist[i])
    break
# Out:
# country

# %%
plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(data = df[collist[i]],color='red',orient='v')
    plt.tight_layout()

# %%
from scipy.stats import zscore
import numpy as np

# %%
(np.abs(zscore(df))<3).all().all()
# Out:
# False

# %% [markdown]
# As the result is false so there are outliers present in the data set but we won't be treating it beacause the number of rows are very less which will led to huge loss of data percentage which will give a very negative impact while making model.

# %% [markdown]
# # prediction 1: primary fuel

# %% [markdown]
# # seperating features and the target variable

# %%
features=df.drop('primary_fuel',axis=1)
target=df['primary_fuel']

# %% [markdown]
# # checking skewness in Data and Removing it

# %%
features.skew()
# Out:
# country                    0.000000
# country_long               0.000000
# name                       0.000000
# gppd_idnr                  0.000000
# capacity_mw                3.123576
# latitude                  -0.149698
# longitude                  1.141881
# other_fuel1              -20.453120
# other_fuel2                0.000000
# commissioning_year        -1.399359
# owner                      1.364406
# source                     1.827373
# url                        1.510537
# geolocation_source        -2.159841
# year_of_capacity_data      0.000000
# generation_gwh_2014        5.035446
# generation_gwh_2015        5.364134
# generation_gwh_2016        5.068427
# generation_gwh_2017        5.110952
# generation_gwh_2018        4.937907
# generation_data_source     0.000000
# dtype: float64

# %% [markdown]
# keeping -/+0.7 as the range of skewness. Here are the columns that are not in range

# %%
from sklearn.preprocessing import power_transform

# %%
features.skew().sort_values(ascending=False)
# Out:
# generation_gwh_2015        5.364134
# generation_gwh_2017        5.110952
# generation_gwh_2016        5.068427
# generation_gwh_2014        5.035446
# generation_gwh_2018        4.937907
# capacity_mw                3.123576
# source                     1.827373
# url                        1.510537
# owner                      1.364406
# longitude                  1.141881
# year_of_capacity_data      0.000000
# country                    0.000000
# country_long               0.000000
# other_fuel2                0.000000
# gppd_idnr                  0.000000
# name                       0.000000
# generation_data_source     0.000000
# latitude                  -0.149698
# commissioning_year        -1.399359
# geolocation_source        -2.159841
# other_fuel1              -20.453120
# dtype: float64

# %% [markdown]
# we are using YEO JOHNSON

# %%
features_n=power_transform(features,method='yeo-johnson')

# %%
pd.DataFrame(features_n,columns=features.columns).skew().sort_values(ascending=False)
# Out:
# owner                      0.467077
# generation_gwh_2014        0.123226
# generation_gwh_2015        0.074582
# url                        0.064576
# generation_gwh_2016        0.041821
# capacity_mw                0.022164
# generation_gwh_2017        0.018337
# longitude                  0.002926
# generation_gwh_2018        0.000783
# year_of_capacity_data      0.000000
# country                    0.000000
# country_long               0.000000
# other_fuel2                0.000000
# generation_data_source     0.000000
# latitude                  -0.074269
# commissioning_year        -0.080999
# source                    -0.214066
# name                      -0.288179
# gppd_idnr                 -0.288179
# geolocation_source        -2.132728
# other_fuel1              -17.330022
# dtype: float64

# %%
type(features_n)
# Out:
# numpy.ndarray

# %%
features.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'other_fuel1', 'other_fuel2',
#        'commissioning_year', 'owner', 'source', 'url', 'geolocation_source',
#        'year_of_capacity_data', 'generation_gwh_2014', 'generation_gwh_2015',
#        'generation_gwh_2016', 'generation_gwh_2017', 'generation_gwh_2018',
#        'generation_data_source'],
#       dtype='object')

# %%
features=pd.DataFrame(features_n,columns=features.columns)

# %%
features.skew().sort_values(ascending=False)
# Out:
# owner                      0.467077
# generation_gwh_2014        0.123226
# generation_gwh_2015        0.074582
# url                        0.064576
# generation_gwh_2016        0.041821
# capacity_mw                0.022164
# generation_gwh_2017        0.018337
# longitude                  0.002926
# generation_gwh_2018        0.000783
# year_of_capacity_data      0.000000
# country                    0.000000
# country_long               0.000000
# other_fuel2                0.000000
# generation_data_source     0.000000
# latitude                  -0.074269
# commissioning_year        -0.080999
# source                    -0.214066
# name                      -0.288179
# gppd_idnr                 -0.288179
# geolocation_source        -2.132728
# other_fuel1              -17.330022
# dtype: float64

# %% [markdown]
# # Training Process Begins

# %% [markdown]
# # Finding Best Random State and using min max scaler to scale the data

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
for i in range(0,100):
    features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=i)
    lr.fit(features_train,target_train)
    pre_train=lr.predict(features_train)
    pre_test=lr.predict(features_test)
    print(f"at random state {i},the train accuracy is:- {r2_score(target_train,pre_train)}")
    print(f"at random state {i},the testing accuracy is:- {r2_score(target_test,pre_test)}")
    print('\n')
# Out:
# at random state 0,the train accuracy is:- 0.6755760980479593
# at random state 0,the testing accuracy is:- 0.6994163127409916
#
#
# at random state 1,the train accuracy is:- 0.6881534640432074
# at random state 1,the testing accuracy is:- 0.6417717860300034
#
#
# at random state 2,the train accuracy is:- 0.7015110346516795
# at random state 2,the testing accuracy is:- 0.5804659851707563
#
#
# at random state 3,the train accuracy is:- 0.678599181513218
# at random state 3,the testing accuracy is:- 0.686101467263391
#
#
# at random state 4,the train accuracy is:- 0.6869448198536907
# at random state 4,the testing accuracy is:- 0.6592946542172093
#
#
# at random state 5,the train accuracy is:- 0.6889203591196529
# at random state 5,the testing accuracy is:- 0.6444919902406926
#
#
# at random state 6,the train accuracy is:- 0.6859551162043283
# at random state 6,the testing accuracy is:- 0.649247460788615
#
#
# at random state 7,the train accuracy is:- 0.6892041851705615
# ...

# %%
features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=.20,random_state=64)

# %%
features_train.shape
# Out:
# (725, 21)

# %%
features_test.shape
# Out:
# (182, 21)

# %%
target_train.shape
# Out:
# (725,)

# %%
target_test.shape
# Out:
# (182,)

# %% [markdown]
# # Linear regression

# %%
lr.fit(features_train,target_train)
# Out:
# LinearRegression()

# %% [markdown]
# test accuracy

# %%
pre_test=lr.predict(features_test)

# %%
 print(r2_score(target_test,pre_test))
# Out:
# 0.7343030216274729

# %% [markdown]
# train accuracy

# %%
pre_train=lr.predict(features_train)

# %%
print(r2_score(target_train,pre_train))
# Out:
# 0.6651690149726404

# %% [markdown]
# # KNeighborsRegressor

# %%
from sklearn.neighbors import KNeighborsRegressor
knr=KNeighborsRegressor()
knr.fit(features_train,target_train)
# Out:
# KNeighborsRegressor()

# %% [markdown]
# test accuracy

# %%
pre_test=knr.predict(features_test)

# %%
 print(r2_score(target_test,pre_test))
# Out:
# 0.861766839269617

# %% [markdown]
# train accuracy

# %%
pre_train=knr.predict(features_train)

# %%
print(r2_score(target_train,pre_train))
# Out:
# 0.9184949779638822

# %% [markdown]
# # support vector regression

# %%
from sklearn.svm import SVR
svr=SVR()
svr.fit(features_train,target_train)
# Out:
# SVR()

# %% [markdown]
# test accuracy

# %%
pre_train=svr.predict(features_test)

# %%
 print(r2_score(target_test,pre_test))
# Out:
# 0.861766839269617

# %% [markdown]
# train accuracy

# %%
pre_train=svr.predict(features_train)

# %%
print(r2_score(target_train,pre_train))
# Out:
# 0.8841338109126192

# %% [markdown]
# # DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
dtr.fit(features_train,target_train)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# test accuracy

# %%
pre_test=dtr.predict(features_test)

# %%
 print(r2_score(target_test,pre_test))
# Out:
# 0.8845831324290896

# %% [markdown]
# train accuracy

# %%
pre_train=dtr.predict(features_train)

# %%
print(r2_score(target_train,pre_train))
# Out:
# 1.0

# %% [markdown]
# # RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor(n_estimators=300)
rfr.fit(features_train,target_train)
# Out:
# RandomForestRegressor(n_estimators=300)

# %% [markdown]
# test accuracy

# %%
pre_test=rfr.predict(features_test)

# %%
 print(r2_score(target_test,pre_test))
# Out:
# 0.9260309723299535

# %% [markdown]
# train accuracy

# %%
pre_train=rfr.predict(features_train)

# %%
print(r2_score(target_train,pre_train))
# Out:
# 0.9887572505173219

# %% [markdown]
# # Among all of the above models the best one is Random Forest Regressor so we will go with it.

# %% [markdown]
# it is best as it is giving a train accuracy of - 0.9891363001250876 and test accuracy of - 0.9269450442455202

# %% [markdown]
# # Cross Validation

# %%
train_accuracy=r2_score(target_train,pre_train)
testing_accuracy=r2_score(target_test,pre_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(rfr,features,target,cv=j)
    cv_mean=cv_score.mean()
    print(f"at cross fold {j} the cv score is {cv_mean} and accuracy score for training is {train_accuracy} and accuracy score for testing is {testing_accuracy}")
    print('\n')
# Out:
# at cross fold 2 the cv score is 0.8805842994577333 and accuracy score for training is 0.9887572505173219 and accuracy score for testing is 0.9260309723299535
#
#
# at cross fold 3 the cv score is 0.902246360797286 and accuracy score for training is 0.9887572505173219 and accuracy score for testing is 0.9260309723299535
#
#
# at cross fold 4 the cv score is 0.9089660278375868 and accuracy score for training is 0.9887572505173219 and accuracy score for testing is 0.9260309723299535
#
#
# at cross fold 5 the cv score is 0.9142381204012228 and accuracy score for training is 0.9887572505173219 and accuracy score for testing is 0.9260309723299535
#
#
# at cross fold 6 the cv score is 0.911101706930173 and accuracy score for training is 0.9887572505173219 and accuracy score for testing is 0.9260309723299535
#
#
# at cross fold 7 the cv score is 0.9077420677658946 and accuracy score for training is 0.9887572505173219 and accuracy score for testing is 0.9260309723299535
#
#
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,4))
plt.scatter(x=target_test, y=pre_test, color='r')
plt.plot(target_test,target_test,color='b')
plt.xlabel('PRIMARY FUEL',fontsize=12)
plt.ylabel('PREDICTED PRIMARY FUEL',fontsize=12)
plt.savefig('rfr.png')
plt.show()

# %% [markdown]
# this is the RANDOM FOREST REGRESSION graph

# %% [markdown]
# # Using Gridsearch cv

# %%
import warnings
warnings.filterwarnings('ignore')
def Grid_Search_CV_RFR(X_train, y_train):
    from sklearn.model_selection import GridSearchCV
    from sklearn.ensemble import RandomForestRegressor

    estimator = RandomForestRegressor()
    param_grid = { 
            "n_estimators"      : [10,20,30],
            "max_features"      : ["auto", "sqrt", "log2"],
            "min_samples_split" : [2,4,8],
            "bootstrap": [True, False],
            }

    grid = GridSearchCV(estimator, param_grid, n_jobs=-1, cv=8)

    grid.fit(X_train, y_train)

    return grid.best_score_ , grid.best_params_

# %% [markdown]
# # Ensemble technique

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
parameters={'criterion':['mse','mae'],'max_features':['auto','sqrt','log2']}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(features_train,target_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'auto'}

# %%
rf=RandomForestRegressor(criterion='mae',max_features='auto')
rf.fit(features_train,target_train)
rf.score(features_train,target_train)
prediction_decision=rf.predict(features_test)


rfscore=cross_val_score(rf,features,target,cv=8)
rfc=rfscore.mean()
print('cross val score',rfc*100)
# Out:
# cross val score 91.0946269385587

# %%
rfs=r2_score(target_test,prediction_decision)
print('r2_score is',rfs*100)
# Out:
# r2_score is 93.16668235466761

# %% [markdown]
# # Saving the model

# %%
import pickle
filename='global1.pkl'
pickle.dump(rf,open('global1.pkl','wb'))

# %% [markdown]
# # loading the model

# %%
l_model=pickle.load(open('global1.pkl','rb'))
result=l_model.score(features_test,target_test)
print(result*100)
# Out:
# 93.16668235466761

# %% [markdown]
# # Prediction 2: capacity_mw

# %% [markdown]
# # seperating features and the target variable

# %%
features=df.drop('capacity_mw',axis=1)
target=df['capacity_mw']

# %%
features
# Out:
#      country  country_long  name  gppd_idnr  latitude  longitude  \
# 0          0             0     0        657   28.1839    73.2407
# 1          0             0     1        519   24.7663    74.6090
# 2          0             0     2        853   21.9038    69.3732
# 3          0             0     3          0   23.8712    91.3602
# 4          0             0     4          1   21.9603    82.4091
# ..       ...           ...   ...        ...       ...        ...
# 902        0             0   902        491   16.2949    77.3568
# 903        0             0   903        822   12.8932    78.1654
# 904        0             0   904        891   15.2758    75.5811
# 905        0             0   905        539   24.3500    73.7477
# 906        0             0   906        876    9.9344    77.4768
#
#      primary_fuel  other_fuel1  other_fuel2  commissioning_year  ...  source  \
# 0               6            2            0         2011.000000  ...     109
# ...

# %%
target
# Out:
# 0         2.5
# 1        98.0
# 2        39.2
# 3       135.0
# 4      1800.0
#         ...
# 902    1600.0
# 903       3.0
# 904      25.5
# 905      80.0
# 906      16.5
# Name: capacity_mw, Length: 907, dtype: float64

# %% [markdown]
# # Checking skewness in Data and Removing it

# %%
features.skew()
# Out:
# country                    0.000000
# country_long               0.000000
# name                       0.000000
# gppd_idnr                  0.000000
# latitude                  -0.149698
# longitude                  1.141881
# primary_fuel               0.472251
# other_fuel1              -20.453120
# other_fuel2                0.000000
# commissioning_year        -1.399359
# owner                      1.364406
# source                     1.827373
# url                        1.510537
# geolocation_source        -2.159841
# year_of_capacity_data      0.000000
# generation_gwh_2014        5.035446
# generation_gwh_2015        5.364134
# generation_gwh_2016        5.068427
# generation_gwh_2017        5.110952
# generation_gwh_2018        4.937907
# generation_data_source     0.000000
# dtype: float64

# %% [markdown]
# keeping -/+0.5 as the range of skewness. Here are the columns that are not in range.

# %% [markdown]
# # Removing skewness

# %%
from sklearn.preprocessing import power_transform

# %%
features.skew().sort_values(ascending=False)
# Out:
# generation_gwh_2015        5.364134
# generation_gwh_2017        5.110952
# generation_gwh_2016        5.068427
# generation_gwh_2014        5.035446
# generation_gwh_2018        4.937907
# source                     1.827373
# url                        1.510537
# owner                      1.364406
# longitude                  1.141881
# primary_fuel               0.472251
# year_of_capacity_data      0.000000
# country                    0.000000
# country_long               0.000000
# other_fuel2                0.000000
# gppd_idnr                  0.000000
# name                       0.000000
# generation_data_source     0.000000
# latitude                  -0.149698
# commissioning_year        -1.399359
# geolocation_source        -2.159841
# other_fuel1              -20.453120
# dtype: float64

# %% [markdown]
# we are using YEO JOHNSON method to remove skewness from the data.

# %%
features_n=power_transform(features,method='yeo-johnson')

# %%
pd.DataFrame(features_n,columns=features.columns).skew().sort_values(ascending=False)
# Out:
# owner                      0.467077
# generation_gwh_2014        0.123226
# generation_gwh_2015        0.074582
# url                        0.064576
# generation_gwh_2016        0.041821
# generation_gwh_2017        0.018337
# longitude                  0.002926
# generation_gwh_2018        0.000783
# country_long               0.000000
# year_of_capacity_data      0.000000
# country                    0.000000
# other_fuel2                0.000000
# generation_data_source     0.000000
# primary_fuel              -0.047067
# latitude                  -0.074269
# commissioning_year        -0.080999
# source                    -0.214066
# name                      -0.288179
# gppd_idnr                 -0.288179
# geolocation_source        -2.132728
# other_fuel1              -17.330022
# dtype: float64

# %%
type(features_n)
# Out:
# numpy.ndarray

# %%
features.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'latitude', 'longitude',
#        'primary_fuel', 'other_fuel1', 'other_fuel2', 'commissioning_year',
#        'owner', 'source', 'url', 'geolocation_source', 'year_of_capacity_data',
#        'generation_gwh_2014', 'generation_gwh_2015', 'generation_gwh_2016',
#        'generation_gwh_2017', 'generation_gwh_2018', 'generation_data_source'],
#       dtype='object')

# %%
features=pd.DataFrame(features_n,columns=features.columns)

# %%
features.skew().sort_values(ascending=False)
# Out:
# owner                      0.467077
# generation_gwh_2014        0.123226
# generation_gwh_2015        0.074582
# url                        0.064576
# generation_gwh_2016        0.041821
# generation_gwh_2017        0.018337
# longitude                  0.002926
# generation_gwh_2018        0.000783
# country_long               0.000000
# year_of_capacity_data      0.000000
# country                    0.000000
# other_fuel2                0.000000
# generation_data_source     0.000000
# primary_fuel              -0.047067
# latitude                  -0.074269
# commissioning_year        -0.080999
# source                    -0.214066
# name                      -0.288179
# gppd_idnr                 -0.288179
# geolocation_source        -2.132728
# other_fuel1              -17.330022
# dtype: float64

# %% [markdown]
# skewness from the data has been removed

# %% [markdown]
# # Training Process Begins

# %% [markdown]
# # Finding Best Random State and using min max scaler to scale the data

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
for i in range(0,100):
    features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=i)
    lr.fit(features_train,target_train)
    pre_train=lr.predict(features_train)
    pre_test=lr.predict(features_test)
    print(f"at random state {i},the train accuracy is:- {r2_score(target_train,pre_train)}")
    print(f"at random state {i},the testing accuracy is:- {r2_score(target_test,pre_test)}")
    print('\n')
# Out:
# at random state 0,the train accuracy is:- 0.6038592371225975
# at random state 0,the testing accuracy is:- 0.6854700270859706
#
#
# at random state 1,the train accuracy is:- 0.6420959844871779
# at random state 1,the testing accuracy is:- 0.5407402046091383
#
#
# at random state 2,the train accuracy is:- 0.6326749712775342
# at random state 2,the testing accuracy is:- 0.5988030534257458
#
#
# at random state 3,the train accuracy is:- 0.6257573241444495
# at random state 3,the testing accuracy is:- 0.6345535160635976
#
#
# at random state 4,the train accuracy is:- 0.6244011140586365
# at random state 4,the testing accuracy is:- 0.6371181010317005
#
#
# at random state 5,the train accuracy is:- 0.6128460449629016
# at random state 5,the testing accuracy is:- 0.6629903072731721
#
#
# at random state 6,the train accuracy is:- 0.6394750811324172
# at random state 6,the testing accuracy is:- 0.5516115203474439
#
#
# at random state 7,the train accuracy is:- 0.642175984144859
# ...

# %%
features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=.20,random_state=96)

# %%
features_train.shape
# Out:
# (725, 21)

# %%
features_test.shape
# Out:
# (182, 21)

# %%
target_train.shape
# Out:
# (725,)

# %%
target_test.shape
# Out:
# (182,)

# %% [markdown]
# # Linear regression

# %%
lr.fit(features_train,target_train)
# Out:
# LinearRegression()

# %%
pre_test=lr.predict(features_test)

# %%
 print(r2_score(target_test,pre_test))
# Out:
# 0.7268354327596196

# %%
pre_train=lr.predict(features_train)

# %%
print(r2_score(target_train,pre_train))
# Out:
# 0.5876794449426305

# %% [markdown]
# # KNeighborsRegressor

# %%
from sklearn.neighbors import KNeighborsRegressor
knr=KNeighborsRegressor()
knr.fit(features_train,target_train)
# Out:
# KNeighborsRegressor()

# %%
pre_test=knr.predict(features_test)

# %%
 print(r2_score(target_test,pre_test))
# Out:
# 0.911327054776719

# %%
pre_train=knr.predict(features_train)

# %%
print(r2_score(target_train,pre_train))
# Out:
# 0.8420895887800102

# %% [markdown]
# # support vector regression

# %%
from sklearn.svm import SVR
svr=SVR()
svr.fit(features_train,target_train)
# Out:
# SVR()

# %%
pre_train=svr.predict(features_test)

# %%
 print(r2_score(target_test,pre_test))
# Out:
# 0.911327054776719

# %%
pre_train=svr.predict(features_train)

# %%
print(r2_score(target_train,pre_train))
# Out:
# -0.14863673473493288

# %% [markdown]
# # DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
dtr.fit(features_train,target_train)
# Out:
# DecisionTreeRegressor()

# %%
pre_test=dtr.predict(features_test)

# %%
 print(r2_score(target_test,pre_test))
# Out:
# 0.8506377178736009

# %%
pre_train=dtr.predict(features_train)

# %%
print(r2_score(target_train,pre_train))
# Out:
# 1.0

# %% [markdown]
# # RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor(n_estimators=300)
rfr.fit(features_train,target_train)
# Out:
# RandomForestRegressor(n_estimators=300)

# %%
pre_test=rfr.predict(features_test)

# %%
 print(r2_score(target_test,pre_test))
# Out:
# 0.9332230886106164

# %%
pre_train=rfr.predict(features_train)

# %%
print(r2_score(target_train,pre_train))
# Out:
# 0.9775960718389101

# %% [markdown]
# # Among all of the above models the best one is random forest regressor so we will go with it.

# %% [markdown]
# it is best as it is giving a train accuracy of - 0.976550789308006 and test accuracy of - 0.936104312598662

# %% [markdown]
# # Cross Validation

# %%
train_accuracy=r2_score(target_train,pre_train)
testing_accuracy=r2_score(target_test,pre_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(rfr,features,target,cv=j)
    cv_mean=cv_score.mean()
    print(f"at cross fold {j} the cv score is {cv_mean} and accuracy score for training is {train_accuracy} and accuracy score for testing is {testing_accuracy}")
    print('\n')
# Out:
# at cross fold 2 the cv score is 0.7993063780714748 and accuracy score for training is 0.9775960718389101 and accuracy score for testing is 0.9332230886106164
#
#
# at cross fold 3 the cv score is 0.8533794868570211 and accuracy score for training is 0.9775960718389101 and accuracy score for testing is 0.9332230886106164
#
#
# at cross fold 4 the cv score is 0.8468393381094212 and accuracy score for training is 0.9775960718389101 and accuracy score for testing is 0.9332230886106164
#
#
# at cross fold 5 the cv score is 0.8495280861047622 and accuracy score for training is 0.9775960718389101 and accuracy score for testing is 0.9332230886106164
#
#
# at cross fold 6 the cv score is 0.8451543721644975 and accuracy score for training is 0.9775960718389101 and accuracy score for testing is 0.9332230886106164
#
#
# at cross fold 7 the cv score is 0.8570324041080238 and accuracy score for training is 0.9775960718389101 and accuracy score for testing is 0.9332230886106164
#
#
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,4))
plt.scatter(x=target_test, y=pre_test, color='r')
plt.plot(target_test,target_test,color='b')
plt.xlabel('capacity_mw',fontsize=12)
plt.ylabel('predicted capacity_mw',fontsize=12)
plt.savefig('rfr.png')
plt.show()

# %% [markdown]
# this is the RANDOM FOREST REGRESSION graph

# %% [markdown]
# # using Gridsearch cv

# %%
import warnings
warnings.filterwarnings('ignore')
def Grid_Search_CV_RFR(X_train, y_train):
    from sklearn.model_selection import GridSearchCV
    from sklearn.ensemble import RandomForestRegressor

    estimator = RandomForestRegressor()
    param_grid = { 
            "n_estimators"      : [10,20,30],
            "max_features"      : ["auto", "sqrt", "log2"],
            "min_samples_split" : [2,4,8],
            "bootstrap": [True, False],
            }

    grid = GridSearchCV(estimator, param_grid, n_jobs=-1, cv=8)

    grid.fit(X_train, y_train)

    return grid.best_score_ , grid.best_params_

# %% [markdown]
# # Ensemble technique

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
parameters={'criterion':['mse','mae'],'max_features':['auto','sqrt','log2']}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(features_train,target_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'log2'}

# %%
rf=RandomForestRegressor(criterion='mae',max_features='auto')
rf.fit(features_train,target_train)
rf.score(features_train,target_train)
prediction_decision=rf.predict(features_test)


rfscore=cross_val_score(rf,features,target,cv=4)
rfc=rfscore.mean()
print('cross val score',rfc*100)
# Out:
# cross val score 84.88629242374819

# %%
rfs=r2_score(target_test,prediction_decision)
print('r2_score is',rfs*100)
# Out:
# r2_score is 93.94944559584518

# %% [markdown]
# # saving the model

# %%
import pickle
filename='global2.pkl'
pickle.dump(rf,open('global2.pkl','wb'))

# %% [markdown]
# # loading the model

# %%
l_model=pickle.load(open('global2.pkl','rb'))
result=l_model.score(features_test,target_test)
print(result*100)
# Out:
# 93.94944559584518
