# %% [markdown]
# # BIG DATA MART SALES PROJECT

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/bigdatamart_rep/master/bigdatamart_Train.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df.shape
# Out:
# (8523, 12)

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %% [markdown]
# ABOUT THE COLUMNS
#
# 1.COUNTRY- This shows the country name.
#
# 2.REGION- This shows the region in the country.
#
# 3.HAPPINESS RANK- This is the rank for the happiness.
#
# 4.HAPPINESS SCORE- This is the score of happiness.
#
# 5.STANDARD ERROR- This shows the standard error.
#
# 6.ECONOMY(GDP PER CAPITA)- This shows the economy rate (GDP per capita).
#
# 7.FAMILY- This column show the family.
#
# 8.HEALTH (LIFE EXPECTANCY)-This column shows the expectancy of life.
#
# 9.FREEDOM-This shows the freedom of the idividual.
#
# 10.TRUST (GOVERNMENT CORRUPTION)- This shows the trust on the government.
#
# 11.GENEROSITY-This column show the generosity.
#
# 12.DYSTOPIA RESIDUAL-This column show the residual rate

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# ...

# %%
df.sample()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3809           FDK09          NaN          Low Fat         0.160666
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 3809  Snack Foods  227.5352            OUT019                       1985
#
#      Outlet_Size Outlet_Location_Type    Outlet_Type  Item_Outlet_Sales
# 3809       Small               Tier 1  Grocery Store           916.1408

# %% [markdown]
# # Checking for the null values in the dataset

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
sns.heatmap(df.isnull())
plt.title('null values')
# Out:
# Text(0.5, 1.0, 'null values')

# %% [markdown]
# since we can see in the heatmap we have null values present in the data so we'll be treating them

# %% [markdown]
# # Treating null values

# %%
np.mean(df['Item_Weight'])
# Out:
# 12.857645184136183

# %%
df['Item_Weight'].fillna(df['Item_Weight'].mean(), inplace=True)

# %% [markdown]
# Finding the mode value of the “Outlet_Size” column as it will have occurred the maximum number of times

# %%
df['Outlet_Size'].fillna(df['Outlet_Size'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %% [markdown]
# all the null values has been removed

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %% [markdown]
# # Visualization of the data

# %% [markdown]
# # 1- pairplot

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
sns.pairplot(df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # 2- Histogram

# %%
df.hist(bins=10,figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'Item_Weight'}>,
#         <AxesSubplot:title={'center':'Item_Visibility'}>],
#        [<AxesSubplot:title={'center':'Item_MRP'}>,
#         <AxesSubplot:title={'center':'Outlet_Establishment_Year'}>],
#        [<AxesSubplot:title={'center':'Item_Outlet_Sales'}>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# # 3- scatterplot

# %%
sns.scatterplot(x='Item_Identifier',y='Item_Outlet_Sales',data=df)
# Out:
# <AxesSubplot:xlabel='Item_Identifier', ylabel='Item_Outlet_Sales'>

# %%
sns.scatterplot(x='Item_Weight',y='Item_Outlet_Sales',data=df)
# Out:
# <AxesSubplot:xlabel='Item_Weight', ylabel='Item_Outlet_Sales'>

# %%
sns.scatterplot(x='Item_Fat_Content',y='Item_Outlet_Sales',data=df)
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content', ylabel='Item_Outlet_Sales'>

# %%
sns.scatterplot(x='Item_Visibility',y='Item_Outlet_Sales',data=df)
# Out:
# <AxesSubplot:xlabel='Item_Visibility', ylabel='Item_Outlet_Sales'>

# %%
sns.scatterplot(x='Item_Type',y='Item_Outlet_Sales',data=df)
# Out:
# <AxesSubplot:xlabel='Item_Type', ylabel='Item_Outlet_Sales'>

# %%
sns.scatterplot(x='Item_MRP',y='Item_Outlet_Sales',data=df)
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Item_Outlet_Sales'>

# %%
sns.scatterplot(x='Outlet_Identifier',y='Item_Outlet_Sales',data=df)
# Out:
# <AxesSubplot:xlabel='Outlet_Identifier', ylabel='Item_Outlet_Sales'>

# %%
sns.scatterplot(x='Outlet_Establishment_Year',y='Item_Outlet_Sales',data=df)
# Out:
# <AxesSubplot:xlabel='Outlet_Establishment_Year', ylabel='Item_Outlet_Sales'>

# %%
sns.scatterplot(x='Outlet_Size',y='Item_Outlet_Sales',data=df)
# Out:
# <AxesSubplot:xlabel='Outlet_Size', ylabel='Item_Outlet_Sales'>

# %%
sns.scatterplot(x='Outlet_Location_Type',y='Item_Outlet_Sales',data=df)
# Out:
# <AxesSubplot:xlabel='Outlet_Location_Type', ylabel='Item_Outlet_Sales'>

# %%
sns.scatterplot(x='Outlet_Type',y='Item_Outlet_Sales',data=df)
# Out:
# <AxesSubplot:xlabel='Outlet_Type', ylabel='Item_Outlet_Sales'>

# %% [markdown]
# # 4- countplot

# %%
sns.countplot(x='Item_Identifier',data=df)
# Out:
# <AxesSubplot:xlabel='Item_Identifier', ylabel='count'>

# %%
sns.countplot(x='Item_Weight',data=df)
# Out:
# <AxesSubplot:xlabel='Item_Weight', ylabel='count'>

# %%
sns.countplot(x='Item_Fat_Content',data=df)
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content', ylabel='count'>

# %%
sns.countplot(x='Item_Visibility',data=df)
# Out:
# <AxesSubplot:xlabel='Item_Visibility', ylabel='count'>

# %%
sns.countplot(x='Item_Type',data=df)
# Out:
# <AxesSubplot:xlabel='Item_Type', ylabel='count'>

# %%
sns.countplot(x='Item_MRP',data=df)
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='count'>

# %%
sns.countplot(x='Outlet_Identifier',data=df)
# Out:
# <AxesSubplot:xlabel='Outlet_Identifier', ylabel='count'>

# %%
sns.countplot(x='Outlet_Establishment_Year',data=df)
# Out:
# <AxesSubplot:xlabel='Outlet_Establishment_Year', ylabel='count'>

# %%
sns.countplot(x='Outlet_Size',data=df)
# Out:
# <AxesSubplot:xlabel='Outlet_Size', ylabel='count'>

# %%
sns.countplot(x='Outlet_Location_Type',data=df)
# Out:
# <AxesSubplot:xlabel='Outlet_Location_Type', ylabel='count'>

# %%
sns.countplot(x='Outlet_Type',data=df)
# Out:
# <AxesSubplot:xlabel='Outlet_Type', ylabel='count'>

# %% [markdown]
# # 5- displot

# %%
sns.displot(x='Item_Identifier',data=df)

# %%
sns.displot(x='Item_Weight',data=df)

# %%
sns.displot(x='Item_Fat_Content',data=df)

# %%
sns.displot(x='Item_Visibility',data=df)

# %%
sns.displot(x='Item_Type',data=df)

# %%
sns.displot(x='Item_MRP',data=df)

# %%
sns.displot(x='Outlet_Identifier',data=df)

# %%
sns.displot(x='Outlet_Establishment_Year',data=df)

# %%
sns.displot(x='Outlet_Size',data=df)

# %%
sns.displot(x='Outlet_Location_Type',data=df)

# %%
sns.displot(x='Outlet_Type',data=df)

# %% [markdown]
# # Checking the distribution of continuous value of the float data type columns.

# %%
sns.displot(df['Item_Outlet_Sales'],kde=True)

# %% [markdown]
# # Encoding the data

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
en=OrdinalEncoder()

# %%
for i in df.columns:
    if df[i].dtype=='object':
        df[i]=en.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0               156.0        9.300               1.0         0.016047
# 1                 8.0        5.920               2.0         0.019278
# 2               662.0       17.500               1.0         0.016760
# 3              1121.0       19.200               2.0         0.000000
# 4              1297.0        8.930               1.0         0.000000
# ...               ...          ...               ...              ...
# 8518            370.0        6.865               1.0         0.056783
# 8519            897.0        8.380               2.0         0.046982
# 8520           1357.0       10.600               1.0         0.035186
# 8521            681.0        7.210               2.0         0.145221
# 8522             50.0       14.800               1.0         0.044878
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %% [markdown]
# # Describing The Data

# %%
df.describe()
# Out:
#        Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# count      8523.000000  8523.000000       8523.000000      8523.000000
# mean        779.714889    12.857645          1.369354         0.066132
# std         449.222377     4.226124          0.644810         0.051598
# min           0.000000     4.555000          0.000000         0.000000
# 25%         395.500000     9.310000          1.000000         0.026989
# 50%         783.000000    12.857645          1.000000         0.053931
# 75%        1167.000000    16.000000          2.000000         0.094585
# max        1558.000000    21.350000          4.000000         0.328391
#
#          Item_Type     Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# count  8523.000000  8523.000000        8523.000000                8523.000000
# mean      7.226681   140.992782           4.722281                1997.831867
# std       4.209990    62.275067           2.837201                   8.371760
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(df.describe(),annot=True,linewidths=2,linecolor='Black',fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Checking correlation of columns with the target variable.

# %%
df.corr()['Item_Outlet_Sales'].sort_values()
# Out:
# Item_Visibility             -0.128625
# Outlet_Size                 -0.086182
# Outlet_Establishment_Year   -0.049135
# Item_Identifier              0.002869
# Item_Fat_Content             0.009800
# Item_Weight                  0.011550
# Item_Type                    0.017048
# Outlet_Location_Type         0.089367
# Outlet_Identifier            0.162325
# Outlet_Type                  0.401522
# Item_MRP                     0.567574
# Item_Outlet_Sales            1.000000
# Name: Item_Outlet_Sales, dtype: float64

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),annot=True,linewidths=2,linecolor='Black',fmt='0.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # checking the columns which are positively and negatively correlated to the target variable.

# %%
plt.figure(figsize=(10,8))
df.corr()['Item_Outlet_Sales'].sort_values(ascending=False).drop(['Item_Outlet_Sales']).plot(kind='bar',color='c')
plt.xlabel('features',fontsize=12)
plt.ylabel('column with target names',fontsize=12)
plt.show()

# %% [markdown]
# THIS DIAGRAM REPRESENTS THE CORRELATION

# %% [markdown]
# # Outliers Checking

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
collist=df.columns.values
ncol=30
nrow=14

# %%
collist
# Out:
# array(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content',
#        'Item_Visibility', 'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'], dtype=object)

# %%
for i in range(0,len(collist)):
    print(collist[i])
    break
# Out:
# Item_Identifier

# %%
plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(data = df[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %%
from scipy.stats import zscore
import numpy as np

# %%
(np.abs(zscore(df))<3).all().all()
# Out:
# False

# %% [markdown]
# As the result is false so there are outliers present in the data set which will be treated.

# %% [markdown]
# # Removing Outliers

# %% [markdown]
# zscore Technique

# %%
from scipy.stats import zscore

# %%
import numpy as np
z=np.abs(zscore(df))
threshold=3
np.where(z>3)
# Out:
# (array([  49,   81,   83,  108,  130,  145,  151,  174,  199,  276,  304,
#          333,  339,  373,  396,  434,  456,  472,  489,  502,  521,  532,
#          615,  661,  694,  727,  753,  753,  809,  838,  854,  891,  935,
#          991,  997, 1009, 1010, 1034, 1090, 1124, 1133, 1138, 1159, 1183,
#         1209, 1254, 1272, 1291, 1311, 1324, 1372, 1433, 1434, 1450, 1496,
#         1501, 1506, 1512, 1542, 1549, 1560, 1575, 1576, 1615, 1617, 1644,
#         1651, 1684, 1723, 1753, 1769, 1805, 1827, 1841, 1859, 1998, 2062,
#         2088, 2109, 2111, 2122, 2143, 2168, 2173, 2216, 2223, 2238, 2251,
#         2293, 2324, 2331, 2438, 2439, 2445, 2516, 2535, 2552, 2569, 2586,
#         2613, 2660, 2678, 2728, 2776, 2855, 2895, 2905, 2971, 2973, 3011,
#         3017, 3083, 3087, 3098, 3154, 3206, 3225, 3234, 3241, 3242, 3243,
#         3286, 3335, 3367, 3399, 3407, 3458, 3474, 3480, 3488, 3491, 3497,
#         3509, 3540, 3545, 3582, 3602, 3667, 3709, 3720, 3750, 3757, 3767,
# ...

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df_new
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0               156.0        9.300               1.0         0.016047
# 1                 8.0        5.920               2.0         0.019278
# 2               662.0       17.500               1.0         0.016760
# 3              1121.0       19.200               2.0         0.000000
# 4              1297.0        8.930               1.0         0.000000
# ...               ...          ...               ...              ...
# 8518            370.0        6.865               1.0         0.056783
# 8519            897.0        8.380               2.0         0.046982
# 8520           1357.0       10.600               1.0         0.035186
# 8521            681.0        7.210               2.0         0.145221
# 8522             50.0       14.800               1.0         0.044878
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
df_new.shape
# Out:
# (8222, 12)

# %%
data_loss=((8523-8222)/8523)*100

# %%
data_loss
# Out:
# 3.5316203214830457

# %% [markdown]
# This is the percentage of data lost

# %% [markdown]
# # seperating features and the target variable

# %%
features=df_new.drop('Item_Outlet_Sales',axis=1)
target=df_new['Item_Outlet_Sales']

# %% [markdown]
# # Checking and Removing Skewness

# %%
features.skew()
# Out:
# Item_Identifier             -0.011945
# Item_Weight                  0.087821
# Item_Fat_Content             0.291106
# Item_Visibility              0.794506
# Item_Type                    0.094578
# Item_MRP                     0.139153
# Outlet_Identifier           -0.067611
# Outlet_Establishment_Year   -0.420927
# Outlet_Size                 -0.089519
# Outlet_Location_Type        -0.202794
# Outlet_Type                  0.957163
# dtype: float64

# %%
features.plot(kind='density',subplots=True,layout=(6,11),sharex=False,legend=False,fontsize=1,figsize=(15,13))
plt.show()

# %% [markdown]
# keeping -/+0.5 as the range of skewness. Here are the columns that are not in range.

# %%
from sklearn.preprocessing import power_transform

# %%
features=power_transform(features,method='yeo-johnson')

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
features=sc.fit_transform(features)
features
# Out:
# array([[-1.45691592, -0.81766492, -0.55319135, ..., -0.28893369,
#         -1.37620889, -0.13508106],
#        [-2.08876736, -1.72429667,  1.1617017 , ..., -0.28893369,
#          1.0952949 ,  1.05485046],
#        [-0.15559082,  1.07935446, -0.55319135, ..., -0.28893369,
#         -1.37620889, -0.13508106],
#        ...,
#        [ 1.19648612, -0.49341755, -0.55319135, ...,  1.39061522,
#         -0.1266511 , -0.13508106],
#        [-0.11435156, -1.36561856,  1.1617017 , ..., -0.28893369,
#          1.0952949 ,  1.05485046],
#        [-1.85741534,  0.48880913, -0.55319135, ...,  1.39061522,
#         -1.37620889, -0.13508106]])

# %%
features.mean()
# Out:
# 1.482392389086198e-17

# %% [markdown]
# # scaling the data using min max scaler

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
for i in range(0,100):
    fea_train,fea_test,target_train,target_test=train_test_split(fea,target,test_size=0.2,random_state=i)
    lr.fit(fea_train,target_train)
    pre_train=lr.predict(fea_train)
    pre_test=lr.predict(fea_test)
    print(f"at random state {i},the train accuracy is:- {r2_score(target_train,pre_train)}")
    print(f"at random state {i},the testing accuracy is:- {r2_score(target_test,pre_test)}")
    print('\n')
# Out:
# at random state 0,the train accuracy is:- 0.5217942669795085
# at random state 0,the testing accuracy is:- 0.519183844317723
#
#
# at random state 1,the train accuracy is:- 0.5232946253453707
# at random state 1,the testing accuracy is:- 0.5124461648099491
#
#
# at random state 2,the train accuracy is:- 0.5203393155658153
# at random state 2,the testing accuracy is:- 0.5250353112618007
#
#
# at random state 3,the train accuracy is:- 0.5241610670381716
# at random state 3,the testing accuracy is:- 0.5099436475171757
#
#
# at random state 4,the train accuracy is:- 0.5161134522590873
# at random state 4,the testing accuracy is:- 0.5390220153913974
#
#
# at random state 5,the train accuracy is:- 0.5259238757458985
# at random state 5,the testing accuracy is:- 0.5015058508671276
#
#
# at random state 6,the train accuracy is:- 0.511866274183189
# at random state 6,the testing accuracy is:- 0.5574988003263266
#
#
# at random state 7,the train accuracy is:- 0.5251851461079335
# ...

# %%
fea_train,fea_test,target_train,target_test=train_test_split(fea,target,test_size=0.2,random_state=6)

# %%
lr.fit(fea_train,target_train)
# Out:
# LinearRegression()

# %% [markdown]
# test accuracy

# %%
pre_test=lr.predict(fea_test)

# %%
 print(r2_score(target_test,pre_test))
# Out:
# 0.5574988003263266

# %% [markdown]
# train accuracy

# %%
 pre_train=lr.predict(fea_train)

# %%
print(r2_score(target_train,pre_train))
# Out:
# 0.511866274183189

# %%
train_accuracy=r2_score(target_train,pre_train)
testing_accuracy=r2_score(target_test,pre_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,fea,target,cv=j)
    cv_mean=cv_score.mean()
    print(f"at cross fold {j} the cv score is {cv_mean} and accuracy score for training is {train_accuracy} and accuracy score for testing is {testing_accuracy}")
    print('\n')
# Out:
# at cross fold 2 the cv score is 0.5195084184653702 and accuracy score for training is 0.511866274183189 and accuracy score for testing is 0.5574988003263266
#
#
# at cross fold 3 the cv score is 0.5194622036813897 and accuracy score for training is 0.511866274183189 and accuracy score for testing is 0.5574988003263266
#
#
# at cross fold 4 the cv score is 0.51863525827333 and accuracy score for training is 0.511866274183189 and accuracy score for testing is 0.5574988003263266
#
#
# at cross fold 5 the cv score is 0.5193013949897946 and accuracy score for training is 0.511866274183189 and accuracy score for testing is 0.5574988003263266
#
#
# at cross fold 6 the cv score is 0.5196890312570953 and accuracy score for training is 0.511866274183189 and accuracy score for testing is 0.5574988003263266
#
#
# at cross fold 7 the cv score is 0.5198898749849081 and accuracy score for training is 0.511866274183189 and accuracy score for testing is 0.5574988003263266
#
#
# ...

# %% [markdown]
# since the number of fold don't have such impact on accuracy and cv score so cv=7 is selected.

# %% [markdown]
# we have to handle the problem of overfitting and underfitting by checking training and testing score.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,4))
plt.scatter(x=target_test, y=pre_test, color='r')
plt.plot(target_test,target_test,color='b')
plt.xlabel('actual sales',fontsize=12)
plt.ylabel('predict sales',fontsize=12)
plt.savefig('lr.png')
plt.show()

# %% [markdown]
# this is the LINEAR REGRESSION

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import Lasso
parameters ={'alpha':[.0001,.001,.01,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf = GridSearchCV(ls,parameters)
clf.fit(fea_train,target_train)
print(clf.best_params_)
# Out:
# {'alpha': 10, 'random_state': 0}

# %% [markdown]
# # final model training

# %%
ls=Lasso(alpha=1,random_state=0)
ls.fit(fea_train,target_train)
ls_score_training=ls.score(fea_train,target_train)
pred_ls=ls.predict(fea_test)
ls_score_training*100
# Out:
# 51.184935796229695

# %%
pred_ls=ls.predict(fea_test)

# %%
lss=r2_score(target_test,pred_ls)
lss*100
# Out:
# 55.7629622609572

# %%
cv_score=cross_val_score(ls,fea,target,cv=6)
cv_mean=cv_score.mean()
cv_mean*100
# Out:
# 51.97979455461957

# %% [markdown]
# # ensemble technique

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
parameters={'criterion':['mse','mae'],'max_features':['auto','sqrt','log2']}
rf=RandomForestRegressor()
clf=GridSearchCV(rf,parameters)
clf.fit(fea_train,target_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'sqrt'}

# %%
rf=RandomForestRegressor(criterion='mae',max_features='auto')
rf.fit(fea_train,target_train)
rf.score(fea_train,target_train)
prediction_decision=rf.predict(fea_test)

rfs=r2_score(target_test,prediction_decision)
print('r2_score is',rfs*100)

rfscore=cross_val_score(rf,fea,target,cv=6)
rfc=rfscore.mean()
print('cross val score',rfc*100)
# Out:
# r2_score is 60.25378117974732
# cross val score 54.81387174121998

# %%
import pickle
filename='mart_sale.pkl'
pickle.dump(rf,open('mart_sale.pkl','wb'))
